# %% [markdown]
# ## Compare IC/ICIR of time-series betas and firm characteristics

# %%
import pandas as pd
import numpy as np
from scipy import stats
from tqdm import tqdm
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.stats.mstats import spearmanr
from scipy.stats.mstats import winsorize

# %%
def replacer(l,target_val=0,replace_val=np.NaN,repeat_max=10):
    #repeat_max = n (consecutive 0s over 10 times will be replaced with NAs)
    counter = 0
    new_l = []
    for e in l:
        if e == target_val: counter += 1
        else:
            counter = 0

        if counter > repeat_max:
            new_l.append(replace_val)
        else:
            new_l.append(e)

    return new_l

# %% [markdown]
# Import Data

# %%
# Import excessive market return (J203T - Rf)
df_MR = pd.read_csv('df_MR.csv')
df_MR.Dates = df_MR.Dates.apply(lambda x:x[:10])
df_MR.set_index('Dates',inplace=True)

# %% [markdown]
# Import risk-free rate (91-day T-Bill)

# %%
df_RF = pd.read_csv('df_RF.csv',index_col=0)

# %% [markdown]
# Import listed stock returns on the JSE

# %%
df_SR = pd.read_csv('df_SR.csv',index_col=0)
df_SR.index = df_SR.index.to_series().apply(lambda x:x[:10])
df_SR.index = pd.to_datetime(df_SR.index)

# %% [markdown]
# Drop the columns of stock returns that full of 0s or NAs and replace consecutive 0s with NAs

# %%
df_SR = df_SR.loc[:, (df_SR != 0).any(axis=0)].astype(np.float64)
df_SR = df_SR.dropna(axis = 0, how = 'all')
df_SR = df_SR.apply(replacer)

# %% [markdown]
# Calculate the Excess Stock Returns

# %%
df_Ex_SR = df_SR-df_RF.values

# %% [markdown]
# Import the Factor Realizations (Mimicking portfolio returns)

# %%
df_FF3 = pd.read_csv('df_FF3.csv')
df_FF3.Dates = df_FF3.Dates.apply(lambda x: x[:10])
df_FF3.set_index('Dates',inplace=True)
df_FF3.index = pd.to_datetime(df_FF3.index)

# %%
df_FF4 = pd.read_csv('df_FF4.csv')
df_FF4.Dates = df_FF4.Dates.apply(lambda x:x[:10])
df_FF4.set_index('Dates',inplace=True)
df_FF4.index = pd.to_datetime(df_FF4.index)

# %%
df_FF4_tmp = pd.read_csv('df_FF4_tmp.csv')
df_FF4_tmp.Dates = df_FF4_tmp.Dates.apply(lambda x:x[:10])
df_FF4_tmp.set_index('Dates',inplace=True)
df_FF4_tmp.index = pd.to_datetime(df_FF4_tmp.index)
df_FF4_tmp = df_FF4_tmp.apply(lambda x: winsorize(x, (0.01, 0.01)))
df_FF4["WML"] = df_FF4_tmp["WML"].values

# %%
df_FF5 = pd.read_csv('df_FF5.csv')
df_FF5.Dates = df_FF5.Dates.apply(lambda x:x[:10])
df_FF5.set_index('Dates',inplace=True)
df_FF5.index = pd.to_datetime(df_FF5.index)

# %% [markdown]
# Import Firm Characteristics

# %%
df_ln_Size = pd.read_csv('df_ln_Size.csv')
df_ln_Size = df_ln_Size.replace([np.inf, -np.inf], np.nan)
df_ln_Size.Dates = df_ln_Size.Dates.apply(lambda x:x[:10])
df_ln_Size.set_index('Dates',inplace=True)
df_ln_Size.index = pd.to_datetime(df_ln_Size.index)

# %%
df_PB = pd.read_csv('df_std_PB.csv')
df_PB = df_PB.replace([np.inf, -np.inf], np.nan)
df_PB.Dates = df_PB.Dates.apply(lambda x:x[:10])
df_PB.set_index('Dates',inplace=True)
df_PB.index = pd.to_datetime(df_PB.index)
df_BM = 1/df_PB

# %%
df_PE = pd.read_csv('df_std_PE.csv')
df_PE = df_PE.replace([np.inf, -np.inf], np.nan)
df_PE.Dates = df_PE.Dates.apply(lambda x:x[:10])
df_PE.set_index('Dates',inplace=True)
df_PE.index = pd.to_datetime(df_PE.index)
df_EP = 1/df_PE

# %%
df_OP = pd.read_csv('df_std_OP.csv')
df_OP = df_OP.replace([np.inf, -np.inf], np.nan)
df_OP.Dates = df_OP.Dates.apply(lambda x:x[:10])
df_OP.set_index('Dates',inplace=True)
df_OP.index = pd.to_datetime(df_OP.index)

# %%
df_INV = pd.read_csv('df_std_INV.csv')
df_INV = df_INV.replace([np.inf, -np.inf], np.nan)
df_INV.Dates = df_INV.Dates.apply(lambda x:x[:10])
df_INV.set_index('Dates',inplace=True)
df_INV.index = pd.to_datetime(df_INV.index)

# %% [markdown]
# Momentum

# %%
gap = 21
win = 250

# %%
df_Ex_SR_trnct = df_Ex_SR.loc[df_FF4.index,:].dropna(axis = 1)

df_mom = pd.DataFrame()
for i in tqdm(range(len(df_Ex_SR_trnct)-win)):
    for j in range(len(df_Ex_SR_trnct.columns)):
        df_mom.loc[i,j] = df_Ex_SR_trnct.iloc[i:(win-gap)+i,j].sum() # daily basis
df_mom
# Out:
# 100%|██████████| 4500/4500 [00:23<00:00, 191.83it/s]
#             0         1         2         3         4         5         6   \
# 0    -0.400804  0.823653  0.227178  0.511074 -0.050389  0.547038 -0.041364
# 1    -0.386840  0.801498  0.236033  0.503016 -0.076081  0.514361 -0.063285
# 2    -0.396938  0.817657  0.241435  0.516694 -0.067017  0.499535 -0.044404
# 3    -0.445523  0.826240  0.223773  0.520329 -0.127683  0.449904 -0.072621
# 4    -0.421240  0.817732  0.223812  0.533456 -0.141033  0.446500 -0.083913
# ...        ...       ...       ...       ...       ...       ...       ...
# 4495 -0.483264 -0.063301 -0.270634 -0.031915 -0.062133 -0.078604  0.295339
# 4496 -0.442715 -0.018983 -0.218840 -0.009587 -0.036964 -0.037517  0.330429
# 4497 -0.427382 -0.034980 -0.250164 -0.007700 -0.043804 -0.040218  0.367641
# 4498 -0.387582 -0.043522 -0.232853 -0.047435 -0.011028 -0.047871  0.430058
# 4499 -0.377971 -0.056752 -0.249652 -0.052074 -0.018782 -0.049785  0.390735
#
#             7         8         9   ...        36        37        38  \
# 0     0.000506  0.505871  0.727456  ...  0.204530  0.200372  0.222683
# 1    -0.017127  0.491343  0.810340  ...  0.161537  0.251452  0.224283
# 2     0.036640  0.400483  0.782839  ...  0.160430  0.273653  0.192642
# 3     0.024930  0.419181  0.742707  ...  0.130040  0.298628  0.210621
# 4     0.033373  0.396070  0.703523  ...  0.132342  0.329065  0.207458
# ...        ...       ...       ...  ...       ...       ...       ...
# 4495 -0.158043  0.090940  0.284075  ... -0.815502 -0.321286 -0.554796
# 4496 -0.147105  0.149342  0.246082  ... -0.755966 -0.280353 -0.563089
#             GFI.SJ.Equity  ACL.SJ.Equity  ...  TON.SJ.Equity  MRP.SJ.Equity  \
# Dates                                     ...
# 2001-12-05       0.505871       0.727456  ...       0.204530       0.200372
# 2001-12-06       0.491343       0.810340  ...       0.161537       0.251452
# 2001-12-07       0.400483       0.782839  ...       0.160430       0.273653
# 2001-12-10       0.419181       0.742707  ...       0.130040       0.298628
# 2001-12-11       0.396070       0.703523  ...       0.132342       0.329065
# ...                   ...            ...  ...            ...            ...
# 2019-02-27       0.090940       0.284075  ...      -0.815502      -0.321286
# 2019-02-28       0.149342       0.246082  ...      -0.755966      -0.280353
# 2019-03-01       0.169797       0.224080  ...      -0.729859      -0.276012
# 2019-03-04       0.157727       0.128328  ...      -0.725318      -0.280029
# 2019-03-05       0.140096       0.239335  ...      -0.725283      -0.264564
#
#             APN.SJ.Equity  AFX.SJ.Equity  SUR.SJ.Equity  DRD.SJ.Equity  \
# Dates
# 2001-12-05       0.222683       0.132532       0.056333       0.693014
# 2001-12-06       0.224283       0.123618       0.056366       0.694540
# 2001-12-07       0.192642       0.122842       0.056399       0.642849
# 2001-12-10       0.210621       0.115719       0.051568       0.626141
# 2001-12-11       0.207458       0.131632       0.073114       0.587627
# ...                   ...            ...            ...            ...
# 2019-02-27      -0.554796      -0.178665      -0.248943      -0.230299
# 2019-02-28      -0.563089      -0.143590      -0.204220      -0.159807
# 2019-03-01      -0.581044      -0.166758      -0.240660      -0.087826
# 2019-03-04      -0.613819      -0.191130      -0.208222      -0.112951
# 2019-03-05      -0.624163      -0.165844      -0.191284      -0.082118
#
#             GRF.SJ.Equity  SUI.SJ.Equity  WBO.SJ.Equity  SNT.SJ.Equity
# Dates
# 2001-12-05       0.622982      -0.461876       0.452089       0.107056
# 2001-12-06       0.645743      -0.460291       0.444954       0.097301
# 2001-12-07       0.723425      -0.457945       0.444987       0.098278
# 2001-12-10       0.736145      -0.457909       0.445022       0.100622
# 2001-12-11       0.765172      -0.439520       0.443622       0.106201
# ...                   ...            ...            ...            ...
# 2019-02-27      -2.858693       0.006076      -0.199735      -0.110707
# 2019-02-28      -2.698668       0.031856      -0.126606      -0.123050
# 2019-03-01      -2.251789       0.015720      -0.159328      -0.122545
# 2019-03-04      -2.168634      -0.025132      -0.137793      -0.103113
# 2019-03-05      -2.501406      -0.021453      -0.127911      -0.090781
#
# [4500 rows x 46 columns]

# %% [markdown]
# # Winsorization

# %%
df_Ex_SR = df_Ex_SR.apply(lambda x: winsorize(x, (0.01, 0.01)))

# %%
df_FF3 = df_FF3.apply(lambda x: winsorize(x, (0.01, 0.01)))
df_FF4 = df_FF4.apply(lambda x: winsorize(x, (0.01, 0.01)))
df_FF5 = df_FF5.apply(lambda x: winsorize(x, (0.01, 0.01)))
df_MR = df_MR.apply(lambda x: winsorize(x, (0.01, 0.01)))

# %%
len(df_ln_Size)==len(df_PE)==len(df_Ex_SR)==len(df_OP)==len(df_INV)
# Out:
# True

# %%
## Firm characteristics are lagged for 1 month, to show its predicting ability towards stock returns 
Gap = 21

n = 3
holding = 21
rollingW = holding * n *12
lens = len(df_mom)
periods = int((lens - rollingW) / holding) - 1
print(rollingW, periods)
# Out:
# 756 177

# %%
df_Ex_SR_trnct =df_Ex_SR.loc[df_mom.index,df_mom.columns].dropna(axis=1)
df_FF6 = pd.concat([df_FF5, df_FF4["WML"]], axis=1)

all_betas = []

for i in tqdm(range(periods)):

    df_FF6_tmp = df_FF6.iloc[i*holding:i*holding+rollingW,:]
    
    df_Ex_SR_trnct_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []
    for j in df_Ex_SR_trnct.columns:
        ols = sm.OLS(df_Ex_SR_trnct_tmp.loc[:,j].values, df_FF6_tmp.values)
        res = ols.fit()
        b = list(res.params)
        b.append(j)
        betas.append(b)
    df_betas = pd.DataFrame(betas).rename(columns={0:'MKT',1:'SMB',2:'HML',3:'RMW',4:'CMA',5:"WML",6:'stock'}).set_index('stock')
    
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 177/177 [00:07<00:00, 24.81it/s]

# %%
all_betas[0]
# Out:
#                     MKT       SMB       HML       RMW       CMA       WML
# stock
# MTN.SJ.Equity  0.151649  0.333057  0.065985  0.070969 -0.032278 -0.097602
# NTC.SJ.Equity  0.023740 -0.206731 -0.079620 -0.153088 -0.040675 -0.046712
# WHL.SJ.Equity  0.047249  0.140719  0.034660  0.007051 -0.104684 -0.081091
# SOL.SJ.Equity  0.029952  0.143373  0.100312 -0.038441 -0.064505  0.038313
# RMH.SJ.Equity  0.026914  0.106434  0.068889 -0.170704 -0.038586 -0.106490
# SAP.SJ.Equity -0.014506 -0.109463 -0.023348 -0.059194 -0.110190  0.059646
# IMP.SJ.Equity  0.119180  0.070740 -0.095274  0.022423  0.202766  0.067203
# NPK.SJ.Equity  0.032677 -0.043649  0.043653  0.073567 -0.004879 -0.100930
# GFI.SJ.Equity -0.147473 -0.226937  0.039469  0.032928  0.112840  0.159975
# ACL.SJ.Equity -0.019758 -0.120590  0.003942 -0.101556 -0.020592  0.566927
# SAC.SJ.Equity  0.050803  0.035701  0.024563 -0.063958  0.056194 -0.067296
# MUR.SJ.Equity  0.009242 -0.271198 -0.145098  0.240844  0.142951  0.089303
# AVI.SJ.Equity  0.049360  0.005873  0.043383  0.166047  0.226081 -0.178985
# REM.SJ.Equity  0.028311 -0.040381  0.001464  0.027792 -0.088140 -0.019834
# NHM.SJ.Equity  0.006653 -0.263090 -0.231214 -0.113379 -0.023278  0.317136
# TFG.SJ.Equity -0.029864  0.008967  0.048092 -0.069173 -0.129028  0.083997
# PPC.SJ.Equity -0.027280 -0.050232  0.003445 -0.090226 -0.002090  0.195968
# PIK.SJ.Equity  0.036393 -0.061044 -0.115566  0.070476  0.001934 -0.192610
# DTC.SJ.Equity -0.125789 -0.198145 -0.292907 -0.040862 -0.267419 -0.033259
# BAW.SJ.Equity -0.040350 -0.099927  0.017608 -0.097274 -0.087258 -0.087932
# SHP.SJ.Equity -0.050311 -0.144785 -0.009285 -0.106959  0.002209  0.077391
# CLS.SJ.Equity  0.113671 -0.215947 -0.013179  0.002462 -0.086845  0.092527
# MRF.SJ.Equity -0.246700 -0.117061 -0.071701  0.012599  0.081943  0.174125
# TRU.SJ.Equity  0.015140  0.065173  0.135496 -0.211547 -0.055346 -0.181146
# BVT.SJ.Equity  0.014106  0.016158  0.125082  0.015454 -0.007928  0.104206
# IPL.SJ.Equity  0.064827 -0.055556 -0.140242 -0.026278 -0.049751 -0.061867
# TBS.SJ.Equity  0.012070 -0.046703  0.000706 -0.043213  0.000172  0.078150
# NPN.SJ.Equity -0.017627 -0.309963 -0.167332  0.065714  0.160000 -0.105810
# AMS.SJ.Equity  0.024478 -0.084963  0.044325 -0.126125  0.024200  0.116790
# RLO.SJ.Equity  0.018822  0.013658 -0.048530  0.085945  0.128959 -0.100906
# RDF.SJ.Equity  0.017188 -0.080459 -0.099838 -0.078458  0.002705 -0.275965
# ARI.SJ.Equity -0.000259  0.064654  0.062786  0.125932  0.222708 -0.008298
# ANG.SJ.Equity -0.096327 -0.218079  0.005585  0.215844  0.119465  0.004622
# HAR.SJ.Equity -0.151169 -0.197767  0.046643  0.118967  0.164015  0.192298
# AFE.SJ.Equity  0.012691 -0.041249 -0.103584  0.053310  0.072763  0.273529
# DSY.SJ.Equity -0.089675 -0.133062 -0.057894 -0.087983 -0.154048 -0.061656
# TON.SJ.Equity -0.000345 -0.127841  0.086355  0.083439  0.118483  0.116141
# MRP.SJ.Equity  0.060177  0.033594  0.030127 -0.060000 -0.076678 -0.131097
# APN.SJ.Equity -0.075717 -0.220842  0.039577 -0.038475  0.095087 -0.077275
# AFX.SJ.Equity  0.038366  0.027877  0.010867 -0.119900 -0.060212  0.004378
# SUR.SJ.Equity -0.054416 -0.211102  0.026919 -0.017427  0.087795 -0.091022
# DRD.SJ.Equity -0.322114 -0.402033 -0.033580  0.106533  0.335911  0.446647
# GRF.SJ.Equity  0.059701  0.032778 -0.158055  0.122097  0.357278  0.263755
# SUI.SJ.Equity -0.031466 -0.095857 -0.041579 -0.051121 -0.000249 -0.069222
# WBO.SJ.Equity  0.020079 -0.125798  0.021409 -0.026305 -0.018984 -0.114003
# SNT.SJ.Equity -0.027530 -0.113132  0.034610 -0.010062  0.018114  0.021254

# %%
# Keep the size and EP have the same length as stock returns
df_ln_Size_trnct = df_ln_Size.loc[df_Ex_SR_trnct.index,:]
df_BM_trnct = df_BM.loc[df_Ex_SR_trnct.index,:]
df_PE_trnct = df_PE.loc[df_Ex_SR_trnct.index,:]
df_OP_trnct = df_OP.loc[df_Ex_SR_trnct.index,:]
df_INV_trnct = df_INV.loc[df_Ex_SR_trnct.index,:]
df_MOM_trnct = df_mom.loc[df_Ex_SR_trnct.index,:]

# %%
IC_Series = pd.DataFrame()
k_index = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_BM_tmp_T = df_BM_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_OP_tmp_T = df_OP_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_INV_tmp_T = df_INV_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_MOM_tmp_T = df_MOM_trnct.iloc[rollingW:rollingW+periods*holding,:].T

index_times = list(df_Ex_SR_tmp_T.columns)
 
for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
    IC = []

    i = int(index_times.index(k) / holding)

    index_tmp = (all_betas[i].index).intersection(df_ln_Size_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_BM_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_PE_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index).\
                    intersection(df_OP_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_INV_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_MOM_tmp_T.loc[:,k].dropna().index)

    df_TS_CS = pd.concat([all_betas[i].loc[index_tmp,:].astype(np.float64), \
                                         df_ln_Size_tmp_T.loc[index_tmp,k],df_BM_tmp_T.loc[index_tmp,k],\
                                         df_PE_tmp_T.loc[index_tmp,k], df_OP_tmp_T.loc[index_tmp,k],\
                                         df_INV_tmp_T.loc[index_tmp,k], df_MOM_tmp_T.loc[index_tmp,k]],axis = 1)

    if len(index_tmp) > 10:
        for j in range(len(df_TS_CS.columns)):
            ic = list(spearmanr(df_TS_CS.iloc[:,j].values,df_Ex_SR_tmp_T.loc[index_tmp,index_times[index_times.index(k)+Gap]]))[0]
            IC.append(ic)
        k_index.append(k)
    IC_Series = pd.concat([IC_Series, pd.DataFrame(IC)],axis=1)
# Out:
# 100%|██████████| 3696/3696 [01:09<00:00, 53.14it/s]

# %%
spearmanr(df_TS_CS.iloc[:,j].values,df_Ex_SR_tmp_T.loc[index_tmp,index_times[index_times.index(k)+Gap]])
# Out:
# SpearmanrResult(correlation=-0.09456283931610081, pvalue=0.5513890255677264)

# %%
df_TS_CS
# Out:
#                     MKT       SMB       HML       RMW       CMA       WML  \
# MTN.SJ.Equity  0.002018 -0.112764 -0.006761  0.047857  0.158511 -0.306379
# NTC.SJ.Equity -0.005431 -0.025221 -0.063513  0.126490  0.051480 -0.312896
# WHL.SJ.Equity -0.065147 -0.208915 -0.017117 -0.123582 -0.036029 -0.114798
# SOL.SJ.Equity  0.055183 -0.052933  0.048239 -0.061807  0.083484 -0.121443
# RMH.SJ.Equity  0.018323 -0.253793 -0.159147  0.079283  0.076022 -0.138173
# SAP.SJ.Equity  0.084411  0.080603 -0.045152 -0.086407  0.024784 -0.005225
# IMP.SJ.Equity -0.156669 -0.743044 -0.098853 -0.467444 -0.180763 -0.299510
# NPK.SJ.Equity -0.079218 -0.192735  0.041678  0.139838  0.196321 -0.208381
# GFI.SJ.Equity  0.142181  0.098466 -0.260896 -0.158013  0.015628 -0.308650
# ACL.SJ.Equity  0.148999  0.115724  0.385270 -0.077753  0.383411  0.152905
# SAC.SJ.Equity  0.061346 -0.044543 -0.042315  0.056340 -0.039418 -0.060029
# MUR.SJ.Equity  0.136523  0.180487 -0.032172  0.163544 -0.085488 -0.390294
# AVI.SJ.Equity  0.055363 -0.002509 -0.083730  0.091912  0.086732 -0.083264
# REM.SJ.Equity -0.010899 -0.178341 -0.046475 -0.022407  0.048982 -0.079617
# TFG.SJ.Equity -0.179210 -0.514997 -0.180834 -0.050367  0.063500 -0.061567
# PPC.SJ.Equity -0.123403 -0.299620 -0.234794 -0.108780  0.031843 -0.273251
# PIK.SJ.Equity -0.025598 -0.203382 -0.086649  0.012419 -0.041981 -0.433685
# DTC.SJ.Equity -0.066614 -0.310676 -0.049777 -0.007460  0.054495 -0.339368
# BAW.SJ.Equity -0.160603 -0.430563 -0.118721 -0.044740  0.098440 -0.090061
# SHP.SJ.Equity -0.021341 -0.317053 -0.141262 -0.043707  0.012379 -0.082238
# CLS.SJ.Equity -0.005920 -0.253985 -0.087318  0.008666 -0.037966 -0.118073
# MRF.SJ.Equity  0.008371 -0.002986  0.095522 -0.003005  0.243057 -0.024688
# TRU.SJ.Equity -0.202806 -0.514090 -0.257198 -0.032590  0.018469 -0.353071
# RLO.SJ.Equity             0.356124            -0.056648            -0.027828
# RDF.SJ.Equity             0.022630            -0.034726            -0.080101
# ARI.SJ.Equity             0.059418            -0.039017            -0.159047
# ANG.SJ.Equity            -0.051579            -0.366090             0.001082
# HAR.SJ.Equity            -0.834471            -0.201560            -0.059512
# AFE.SJ.Equity             0.083318             0.776622            -0.131008
# MRP.SJ.Equity             0.777259            -0.190510             0.009387
# APN.SJ.Equity             0.006839             0.025693            -0.528383
# AFX.SJ.Equity             0.192287            -0.180053            -0.013286
# SUR.SJ.Equity             0.287893            -0.211707            -0.243766
# DRD.SJ.Equity            -0.221500            -0.185808            -0.307008
# GRF.SJ.Equity            -1.354093            -0.530948            -3.553492
# SUI.SJ.Equity             0.015828            -0.036177            -0.111850
# WBO.SJ.Equity            -0.027559             0.514307            -0.022683

# %%
all_corr = []

index_times = list(df_Ex_SR_tmp_T.columns)
 
for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
    IC = []

    i = int(index_times.index(k) / holding)

    index_tmp = (all_betas[i].index).intersection(df_ln_Size_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_BM_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_PE_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index).\
                    intersection(df_OP_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_INV_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_MOM_tmp_T.loc[:,k].dropna().index)

    df_TS_CS = pd.concat([all_betas[i].loc[index_tmp,:].astype(np.float64), \
                                         df_ln_Size_tmp_T.loc[index_tmp,k],df_BM_tmp_T.loc[index_tmp,k],\
                                         df_OP_tmp_T.loc[index_tmp,k],\
                                         df_INV_tmp_T.loc[index_tmp,k], df_MOM_tmp_T.loc[index_tmp,k]],axis = 1)
    
    corr = df_TS_CS.corr()
    all_corr.append(corr)
# Out:
# 100%|██████████| 3696/3696 [00:11<00:00, 326.22it/s]

# %%
zip(all_corr, all_corr[1:])

# %%
pd.DataFrame(np.add(all_corr[0].values,all_corr[1].values))
# Out:
#           0         1         2         3         4         5         6   \
# 0   2.000000  0.654223 -0.136025  0.274285  0.041678 -0.298966  0.584024
# 1   0.654223  2.000000  0.657834 -0.093354 -0.010147 -0.104099  0.509304
# 2  -0.136025  0.657834  2.000000 -0.714243 -0.682052 -0.256102  0.323512
# 3   0.274285 -0.093354 -0.714243  2.000000  1.283089 -0.074256 -0.399740
# 4   0.041678 -0.010147 -0.682052  1.283089  2.000000  0.200435 -0.656142
# 5  -0.298966 -0.104099 -0.256102 -0.074256  0.200435  2.000000  0.196199
# 6   0.584024  0.509304  0.323512 -0.399740 -0.656142  0.196199  2.000000
# 7   0.004208  0.268151  0.112816 -0.519648 -0.314954 -0.156476 -0.026524
# 8  -1.384666 -0.125344 -0.023183 -0.278509  0.155359  0.193295 -0.482946
# 9  -0.530410  0.485854  0.352711  0.599225  0.674763  0.235946 -0.119441
# 10 -0.158199 -0.145805  0.270718 -0.349425 -0.370396  0.307308 -0.224543
#
#           7         8         9         10
# 0   0.004208 -1.384666 -0.530410 -0.158199
# 1   0.268151 -0.125344  0.485854 -0.145805
# 2   0.112816 -0.023183  0.352711  0.270718
# 3  -0.519648 -0.278509  0.599225 -0.349425
# 4  -0.314954  0.155359  0.674763 -0.370396
# 5  -0.156476  0.193295  0.235946  0.307308
# 6  -0.026524 -0.482946 -0.119441 -0.224543
# 7   2.000000 -0.019112 -0.030505 -0.391603
# 8  -0.019112  2.000000  0.352607 -0.034761
# 9  -0.030505  0.352607  2.000000 -0.695712
# 10 -0.391603 -0.034761 -0.695712  2.000000

# %%
print([sum(all_corr[0:i + 1]) for i in range(len(all_corr))])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [109], in <cell line: 1>()
# ----> 1 print([sum(all_corr[0:i + 1]) for i in range(len(all_corr))])
#
# Input In [109], in <listcomp>(.0)
# ----> 1 print([sum(all_corr[0:i + 1]) for i in range(len(all_corr))])
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:100, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
# --> 100     return self._arith_method(other, operator.add)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:6933, in DataFrame._arith_method(self, other, op)
#    6931 def _arith_method(self, other, op):
#    6932     if ops.should_reindex_frame_op(self, other, op, 1, 1, None, None):
# -> 6933         return ops.frame_arith_method_with_reindex(self, other, op)
#    6935     axis = 1  # only relevant for Series other case
#    6936     other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py:364, in frame_arith_method_with_reindex(left, right, op)
#     359 # GH#31623, only operate on shared columns
#     360 cols, lcols, rcols = left.columns.join(
#     361     right.columns, how="inner", level=None, return_indexers=True
#     362 )
# --> 364 new_left = left.iloc[:, lcols]
#     365 new_right = right.iloc[:, rcols]
#     366 result = op(new_left, new_right)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1462, in _iLocIndexer._getitem_tuple(self, tup)
#    1459 with suppress(IndexingError):
#    1460     return self._getitem_lowerdim(tup)
# -> 1462 return self._getitem_tuple_same_dim(tup)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1511, in _iLocIndexer._getitem_axis(self, key, axis)
#    1509 # a list of integers
#    1510 elif is_list_like_indexer(key):
# -> 1511     return self._get_list_axis(key, axis=axis)
#    1513 # a single integer
#    1514 else:
#    1515     key = item_from_zerodim(key)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1482, in _iLocIndexer._get_list_axis(self, key, axis)
#    1465 """
#    1466 Return Series values by list or array of integers.
#    1467
#    (...)
#    1479 `axis` can only be zero.
#    1480 """
#    1481 try:
# -> 1482     return self.obj._take_with_is_copy(key, axis=axis)
#    1483 except IndexError as err:
#    1484     # re-raise with different error message
#    1485     raise IndexError("positional indexers are out-of-bounds") from err
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:3728, in NDFrame._take_with_is_copy(self, indices, axis)
#    3720 def _take_with_is_copy(self: NDFrameT, indices, axis=0) -> NDFrameT:
#    3721     """
#    3722     Internal version of the `take` method that sets the `_is_copy`
#    3723     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3726     See the docstring of `take` for full explanation of the parameters.
#    3727     """
# -> 3728     result = self.take(indices=indices, axis=axis)
#    3729     # Maybe set copy if we didn't actually change the index.
#    3730     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:3713, in NDFrame.take(self, indices, axis, is_copy, **kwargs)
#    3704     warnings.warn(
#    3705         "is_copy is deprecated and will be removed in a future version. "
#    3706         "'take' always returns a copy, so there is no need to specify this.",
#    3707         FutureWarning,
#    3708         stacklevel=find_stack_level(),
#    3709     )
#    3711 nv.validate_take((), kwargs)
# -> 3713 self._consolidate_inplace()
#    3715 new_data = self._mgr.take(
#    3716     indices, axis=self._get_block_manager_axis(axis), verify=True
#    3717 )
#    3718 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5661, in NDFrame._consolidate_inplace(self)
#    5658 def f():
#    5659     self._mgr = self._mgr.consolidate()
# -> 5661 self._protect_consolidate(f)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5649, in NDFrame._protect_consolidate(self, f)
#    5647     return f()
#    5648 blocks_before = len(self._mgr.blocks)
# -> 5649 result = f()
#    5650 if len(self._mgr.blocks) != blocks_before:
#    5651     self._clear_item_cache()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5659, in NDFrame._consolidate_inplace.<locals>.f()
#    5658 def f():
# -> 5659     self._mgr = self._mgr.consolidate()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py:631, in BaseBlockManager.consolidate(self)
#     629 bm = type(self)(self.blocks, self.axes, verify_integrity=False)
#     630 bm._is_consolidated = False
# --> 631 bm._consolidate_inplace()
#     632 return bm
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py:1685, in BlockManager._consolidate_inplace(self)
#    1683 def _consolidate_inplace(self) -> None:
#    1684     if not self.is_consolidated():
# -> 1685         self.blocks = tuple(_consolidate(self.blocks))
#    1686         self._is_consolidated = True
#    1687         self._known_consolidated = True
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py:2084, in _consolidate(blocks)
#    2082 new_blocks: list[Block] = []
#    2083 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2084     merged_blocks = _merge_blocks(
#    2085         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2086     )
#    2087     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2088 return new_blocks
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py:2111, in _merge_blocks(blocks, dtype, can_consolidate)
#    2104 new_values: ArrayLike
#    2106 if isinstance(blocks[0].dtype, np.dtype):
#    2107     # error: List comprehension has incompatible type List[Union[ndarray,
#    2108     # ExtensionArray]]; expected List[Union[complex, generic,
#    2109     # Sequence[Union[int, float, complex, str, bytes, generic]],
#    2110     # Sequence[Sequence[Any]], SupportsArray]]
# -> 2111     new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    2112 else:
#    2113     bvals = [blk.values for blk in blocks]
#
# File <__array_function__ internals>:5, in vstack(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/shape_base.py:282, in vstack(tup)
#     280 if not isinstance(arrs, list):
#     281     arrs = [arrs]
# --> 282 return _nx.concatenate(arrs, 0)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
L = all_corr
for i, n in enumerate(L[1:]):
    L[i + 1] = L[i + 1] + L[i]
print(L)

# %%
L = all_corr
for i, n in enumerate(L): #It starts at element 0!
    L[i] = n + L[i - 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 L = all_corr
#       2 for i, n in enumerate(L): #It starts at element 0!
#       3     L[i] = n + L[i - 1]
#
# NameError: name 'all_corr' is not defined

# %%
all_corr[0].add(all_corr[1].values, fill_value=0)
# Out:
#                           MKT       SMB       HML       RMW       CMA  \
# MKT                  2.000000  0.654223 -0.136025  0.274285  0.041678
# SMB                  0.654223  2.000000  0.657834 -0.093354 -0.010147
# HML                 -0.136025  0.657834  2.000000 -0.714243 -0.682052
# RMW                  0.274285 -0.093354 -0.714243  2.000000  1.283089
# CMA                  0.041678 -0.010147 -0.682052  1.283089  2.000000
# WML                 -0.298966 -0.104099 -0.256102 -0.074256  0.200435
# 2004-10-28 00:00:00  0.584024  0.509304  0.323512 -0.399740 -0.656142
# 2004-10-28 00:00:00  0.004208  0.268151  0.112816 -0.519648 -0.314954
# 2004-10-28 00:00:00 -1.384666 -0.125344 -0.023183 -0.278509  0.155359
# 2004-10-28 00:00:00 -0.530410  0.485854  0.352711  0.599225  0.674763
# 2004-10-28 00:00:00 -0.158199 -0.145805  0.270718 -0.349425 -0.370396
#
#                           WML  2004-10-28 00:00:00  2004-10-28 00:00:00  \
# MKT                 -0.298966             0.584024             0.004208
# SMB                 -0.104099             0.509304             0.268151
# HML                 -0.256102             0.323512             0.112816
# RMW                 -0.074256            -0.399740            -0.519648
# CMA                  0.200435            -0.656142            -0.314954
# WML                  2.000000             0.196199            -0.156476
# 2004-10-28 00:00:00  0.196199             2.000000            -0.026524
# 2004-10-28 00:00:00 -0.156476            -0.026524             2.000000
# 2004-10-28 00:00:00  0.193295            -0.482946            -0.019112
# 2004-10-28 00:00:00  0.235946            -0.119441            -0.030505
# 2004-10-28 00:00:00  0.307308            -0.224543            -0.391603
#
#                      2004-10-28 00:00:00  2004-10-28 00:00:00  \
# MKT                            -1.384666            -0.530410
# SMB                            -0.125344             0.485854
# HML                            -0.023183             0.352711
# RMW                            -0.278509             0.599225
# CMA                             0.155359             0.674763
# WML                             0.193295             0.235946
# 2004-10-28 00:00:00            -0.482946            -0.119441
# 2004-10-28 00:00:00            -0.019112            -0.030505
# 2004-10-28 00:00:00             2.000000             0.352607
# 2004-10-28 00:00:00             0.352607             2.000000
# 2004-10-28 00:00:00            -0.034761            -0.695712
#
#                      2004-10-28 00:00:00
# MKT                            -0.158199
# SMB                            -0.145805
# HML                             0.270718
# RMW                            -0.349425
# CMA                            -0.370396
# WML                             0.307308
# 2004-10-28 00:00:00            -0.224543
# 2004-10-28 00:00:00            -0.391603
# 2004-10-28 00:00:00            -0.034761
# 2004-10-28 00:00:00            -0.695712
# 2004-10-28 00:00:00             2.000000

# %%
for i in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
# %%
plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
corrMatrix = df_FF5.corr()
sn.heatmap(corrMatrix, annot=True, cmap="viridis")
plt.title('The Correlation Among TS Factors', fontsize=10)
plt.show()

# %%
IC_Series_tmp = IC_Series.T.set_index([pd.Index(pd.Series(range(0,len(IC_Series.T))))])
IC_Series_tmp = pd.concat([IC_Series_tmp, pd.DataFrame(k_index)], axis = 1)
IC_Series_tmp.columns = ['MKT','SMB','HML','RMW','CMA',"WML",'Size',"BM",'PE','OP','INV',"MOM",'Dates']
IC_Series_tmp = IC_Series_tmp.set_index('Dates')
IC_Series_tmp
# Out:
#                  MKT       SMB       HML       RMW       CMA       WML  \
# Dates
# 2004-10-28 -0.413161 -0.129777  0.092934 -0.127394  0.111447 -0.238842
# 2004-10-29  0.012468  0.014668  0.067840 -0.044004 -0.175651 -0.165017
# 2004-11-01 -0.346359 -0.418456 -0.207852 -0.011191  0.354064 -0.105302
# 2004-11-02  0.024399  0.108421  0.120528 -0.018712 -0.238855 -0.106219
# 2004-11-03  0.075021  0.167878  0.194908 -0.214031 -0.046520 -0.017468
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-19  0.123592  0.362833  0.119053 -0.471756 -0.300267 -0.027312
# 2018-12-20  0.177700  0.023742  0.230208  0.009805  0.357426  0.326473
# 2018-12-21  0.251276  0.206223  0.267806  0.248845  0.031035  0.115469
# 2018-12-24 -0.019617  0.200957 -0.051800  0.056907 -0.255269 -0.332117
# 2018-12-27 -0.021473 -0.204765 -0.020825 -0.295519 -0.001540  0.060206
#
#                 Size        BM        PE        OP       INV       MOM
# Dates
# 2004-10-28 -0.312895  0.045825  0.041059  0.347906 -0.100999  0.419027
# 2004-10-29  0.405574 -0.004767 -0.270260 -0.042171 -0.243491  0.328566
# 2004-11-01 -0.264172  0.010457  0.246377  0.087874 -0.337553 -0.224546
# 2004-11-02  0.188039  0.166942 -0.064025  0.044029  0.019446  0.270409
# 2004-11-03  0.060495  0.113819 -0.085502  0.232786  0.234257  0.175233
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-19 -0.416484 -0.070427  0.046600 -0.308534 -0.278548  0.016452
# 2018-12-20  0.066526 -0.178024 -0.070902  0.103476  0.235556  0.049186
# 2018-12-21  0.170570  0.017097 -0.038490 -0.005105 -0.083381 -0.028118
# 2018-12-24 -0.222682 -0.220817  0.077983 -0.088521 -0.063311  0.146806
# 2018-12-27  0.003646 -0.198930 -0.225508 -0.278178  0.011425 -0.094563
#
# [3541 rows x 12 columns]

# %%
IC_Series = IC_Series_tmp
IC_Series
# Out:
#                  MKT       SMB       HML       RMW       CMA       WML  \
# Dates
# 2004-10-28 -0.413161 -0.129777  0.092934 -0.127394  0.111447 -0.238842
# 2004-10-29  0.012468  0.014668  0.067840 -0.044004 -0.175651 -0.165017
# 2004-11-01 -0.346359 -0.418456 -0.207852 -0.011191  0.354064 -0.105302
# 2004-11-02  0.024399  0.108421  0.120528 -0.018712 -0.238855 -0.106219
# 2004-11-03  0.075021  0.167878  0.194908 -0.214031 -0.046520 -0.017468
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-19  0.123592  0.362833  0.119053 -0.471756 -0.300267 -0.027312
# 2018-12-20  0.177700  0.023742  0.230208  0.009805  0.357426  0.326473
# 2018-12-21  0.251276  0.206223  0.267806  0.248845  0.031035  0.115469
# 2018-12-24 -0.019617  0.200957 -0.051800  0.056907 -0.255269 -0.332117
# 2018-12-27 -0.021473 -0.204765 -0.020825 -0.295519 -0.001540  0.060206
#
#                 Size        BM        PE        OP       INV       MOM
# Dates
# 2004-10-28 -0.312895  0.045825  0.041059  0.347906 -0.100999  0.419027
# 2004-10-29  0.405574 -0.004767 -0.270260 -0.042171 -0.243491  0.328566
# 2004-11-01 -0.264172  0.010457  0.246377  0.087874 -0.337553 -0.224546
# 2004-11-02  0.188039  0.166942 -0.064025  0.044029  0.019446  0.270409
# 2004-11-03  0.060495  0.113819 -0.085502  0.232786  0.234257  0.175233
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-19 -0.416484 -0.070427  0.046600 -0.308534 -0.278548  0.016452
# 2018-12-20  0.066526 -0.178024 -0.070902  0.103476  0.235556  0.049186
# 2018-12-21  0.170570  0.017097 -0.038490 -0.005105 -0.083381 -0.028118
# 2018-12-24 -0.222682 -0.220817  0.077983 -0.088521 -0.063311  0.146806
# 2018-12-27  0.003646 -0.198930 -0.225508 -0.278178  0.011425 -0.094563
#
# [3541 rows x 12 columns]

# %%
# Annualized the mean of IC_Series
all_ICs = IC_Series.apply(lambda x: x.mean()*np.sqrt(252), axis = 0) 
all_ICs
# Out:
# MKT     0.086064
# SMB     0.079716
# HML     0.035704
# RMW     0.166590
# CMA     0.089927
# WML     0.048837
# Size    0.070805
# BM      0.085794
# PE     -0.078194
# OP      0.158153
# INV     0.057483
# MOM     0.207792
# dtype: float64

# %%
# Annualized ICIR
all_ICIRs = IC_Series.apply(lambda x: x.mean()/x.std()*np.sqrt(252), axis = 0) 
all_ICIRs
# Out:
# MKT     0.463345
# SMB     0.428246
# HML     0.195422
# RMW     0.899879
# CMA     0.477694
# WML     0.265135
# Size    0.306646
# BM      0.486482
# PE     -0.423264
# OP      0.794572
# INV     0.320360
# MOM     0.931152
# dtype: float64

# %%
## Plot Cumsum IC_Series of MKT
ax = IC_Series[['MKT']].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# MKT  0.086064  0.463345

# %%
## Plot Cumsum IC_Series of WML
ax = IC_Series[['WML',"MOM"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["WML","MOM"]],all_ICIRs[["WML","MOM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# WML  0.048837  0.265135
# MOM  0.207792  0.931152

# %%
## Plot Cumsum IC_Series of SMB & Size
ax = IC_Series[["SMB","Size"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["SMB","Size"]],all_ICIRs[["SMB","Size"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#             IC      ICIR
# SMB   0.079716  0.428246
# Size  0.070805  0.306646

# %%
## Plot Cumsum IC_Series of HML & BM
ax = IC_Series[["HML","BM"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["HML","BM"]],all_ICIRs[["HML","BM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# HML  0.035704  0.195422
# BM   0.085794  0.486482

# %%
## Plot Cumsum IC_Series of HML & PE
ax = IC_Series[["HML","PE"]].cumsum().plot(figsize = (6,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["HML","PE"]],all_ICIRs[["HML","PE"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# HML  0.035704  0.195422
# PE  -0.078194 -0.423264

# %%
## Plot Cumsum IC_Series of RMW & OP
ax = IC_Series[["RMW","OP"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["RMW","OP"]],all_ICIRs[["RMW","OP"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# RMW  0.166590  0.899879
# OP   0.158153  0.794572

# %%
## Plot Cumsum IC_Series of CMA & INV
ax = IC_Series[["CMA","INV"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["CMA","INV"]],all_ICIRs[["CMA","INV"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# CMA  0.089927  0.477694
# INV  0.057483  0.320360

# %%
pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
append(pd.concat([all_ICs[["SMB","Size"]],all_ICIRs[["SMB","Size"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["HML","BM"]],all_ICIRs[["HML","BM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["WML","MOM"]],all_ICIRs[["WML","MOM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["RMW","OP"]],all_ICIRs[["RMW","OP"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["CMA","INV"]],all_ICIRs[["CMA","INV"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}))
# Out:
# <ipython-input-41-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-41-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-41-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-41-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-41-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
#             IC      ICIR
# MKT   0.086064  0.463345
# SMB   0.079716  0.428246
# Size  0.070805  0.306646
# HML   0.035704  0.195422
# BM    0.085794  0.486482
# WML   0.048837  0.265135
# MOM   0.207792  0.931152
# RMW   0.166590  0.899879
# OP    0.158153  0.794572
# CMA   0.089927  0.477694
# INV   0.057483  0.320360

# %%
# Keep the size and EP have the same length as stock returns
df_FF6 = pd.concat([df_FF5, df_FF4["WML"]], axis=1)
df_FF6_trnct = df_FF6.loc[IC_Series.index,:]
df_Ex_SR_trnct = df_Ex_SR.loc[IC_Series.index,:].dropna(axis=1)
df_ln_Size_trnct = df_ln_Size.loc[df_Ex_SR_trnct.index,:]
df_PE_trnct = df_PE.loc[df_Ex_SR_trnct.index,:]
df_OP_trnct = df_OP.loc[df_Ex_SR_trnct.index,:]
df_INV_trnct = df_INV.loc[df_Ex_SR_trnct.index,:]
df_BM_trnct = df_BM.loc[df_Ex_SR_trnct.index,:]
df_MOM_trnct = df_mom.loc[df_Ex_SR_trnct.index,:]

# %%
betas = []
for j in df_Ex_SR_trnct.columns:
    ols = sm.OLS(df_Ex_SR_trnct.loc[:,j].values, df_FF6_trnct.values)
    res = ols.fit()
    b = list(res.params)
    b.append(j)
    betas.append(b)
df_betas = pd.DataFrame(betas).rename(columns={0:'MKT',1:'SMB',2:'HML',3:'RMW',4:'CMA',5:"WML",6:'stock'}).set_index('stock')

# %%
df_betas
# Out:
#                     MKT       SMB       HML       RMW       CMA       WML
# stock
# MTN.SJ.Equity  0.946556 -0.331072 -0.001759  0.203985  0.060914  0.068931
# AEG.SJ.Equity  0.691449 -0.254177  0.140016 -0.285105  0.002726 -0.218690
# NTC.SJ.Equity  0.484339 -0.413950 -0.046218  0.101604  0.038950  0.093699
# WHL.SJ.Equity  0.537553 -0.574269 -0.092894  0.265498  0.095892  0.318106
# SOL.SJ.Equity  1.183829  0.000126 -0.007578 -0.099088  0.032077 -0.171313
# ...                 ...       ...       ...       ...       ...       ...
# HDC.SJ.Equity  0.319564  0.125650  0.066563  0.120160  0.021222 -0.004826
# BEL.SJ.Equity  0.303157  0.329072  0.030264 -0.138725  0.075712  0.180264
# CSB.SJ.Equity  0.261150 -0.022929  0.130004  0.129656 -0.027324  0.216360
# SPP.SJ.Equity  0.353393 -0.451995 -0.130213  0.151726  0.018926  0.192755
# LEW.SJ.Equity  0.431304 -0.380602  0.201238  0.213913  0.088713 -0.088859
#
# [84 rows x 6 columns]

# %%
IC_Series = pd.DataFrame()
k_index = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.T
df_ln_Size_tmp_T = df_ln_Size_trnct.T
df_BM_tmp_T = df_BM_trnct.T
df_PE_tmp_T = df_PE_trnct.T
df_OP_tmp_T = df_OP_trnct.T
df_INV_tmp_T = df_INV_trnct.T
df_MOM_tmp_T = df_MOM_trnct.T

index_times = list(df_Ex_SR_tmp_T.columns)
 
df_TS_CS = pd.DataFrame()
for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
    IC = []

    index_tmp = df_betas.index.intersection(df_ln_Size_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_BM_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_PE_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index).\
                    intersection(df_OP_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_INV_tmp_T.loc[:,k].dropna().index).\
                    intersection(df_MOM_tmp_T.loc[:,k].dropna().index)

    df_TS_CS = pd.concat([df_betas.loc[index_tmp,:].astype(np.float64), \
                                         df_ln_Size_tmp_T.loc[index_tmp,k],df_BM_tmp_T.loc[index_tmp,k],\
                                         df_PE_tmp_T.loc[index_tmp,k], df_OP_tmp_T.loc[index_tmp,k],\
                                         df_INV_tmp_T.loc[index_tmp,k], df_MOM_tmp_T.loc[index_tmp,k]],axis = 1)

    if len(index_tmp) > 10:
        for j in range(len(df_TS_CS.columns)):
            ic = list(spearmanr(df_TS_CS.iloc[:,j].values,df_Ex_SR_tmp_T.loc[index_tmp,index_times[index_times.index(k)]]))[0]
            IC.append(ic)
        k_index.append(k)
    IC_Series = pd.concat([IC_Series, pd.DataFrame(IC)],axis=1)
# Out:
# 100%|██████████| 3520/3520 [01:07<00:00, 52.25it/s]

# %%
df_TS_CS
# Out:
#                     MKT       SMB       HML       RMW       CMA       WML  \
# MTN.SJ.Equity  0.946556 -0.331072 -0.001759  0.203985  0.060914  0.068931
# NTC.SJ.Equity  0.484339 -0.413950 -0.046218  0.101604  0.038950  0.093699
# WHL.SJ.Equity  0.537553 -0.574269 -0.092894  0.265498  0.095892  0.318106
# SOL.SJ.Equity  1.183829  0.000126 -0.007578 -0.099088  0.032077 -0.171313
# RMH.SJ.Equity  0.876346 -0.483033  0.157453  0.187088  0.011087  0.150093
# SAP.SJ.Equity  0.841804 -0.065366 -0.090832 -0.155842  0.028811 -0.166479
# IMP.SJ.Equity  1.345602 -0.344447 -0.391297 -0.305146  0.278478 -0.596359
# NPK.SJ.Equity  0.389613 -0.454414 -0.029836 -0.027060  0.012841 -0.023636
# GFI.SJ.Equity  0.753718 -0.090847 -0.703297 -0.585202  0.375451 -0.941331
# ACL.SJ.Equity  0.948468 -0.368733  0.034461 -0.295608  0.185329 -0.378395
# SAC.SJ.Equity  0.113541 -0.293637  0.122433 -0.203613 -0.262607  0.236827
# MUR.SJ.Equity  0.590957 -0.427216  0.052636 -0.178710 -0.106395 -0.351657
# AVI.SJ.Equity  0.328609 -0.399382  0.028244  0.153085  0.045740  0.229914
# REM.SJ.Equity  0.701036 -0.331080  0.079158  0.067932 -0.040418  0.161778
# TFG.SJ.Equity  0.531497 -0.727016 -0.091416  0.311060  0.083136  0.169023
# PPC.SJ.Equity  0.503797 -0.509060  0.045950  0.049802 -0.002786 -0.097156
# PIK.SJ.Equity  0.378115 -0.571044 -0.085909  0.135195  0.047683  0.156567
# DTC.SJ.Equity  0.584434  0.078963  0.106197 -0.237678 -0.050298  0.090196
# BAW.SJ.Equity  0.701531 -0.492773  0.129699 -0.044157  0.067661  0.141534
# SHP.SJ.Equity  0.463680 -0.572735 -0.112373  0.072739  0.011222  0.248900
# CLS.SJ.Equity  0.373646 -0.581099 -0.162075  0.192730  0.016798  0.275824
# IPL.SJ.Equity            -0.029974            -0.162629            -0.381745
# TBS.SJ.Equity             0.093478            -0.130181            -0.566319
# NPN.SJ.Equity            -0.180191            -0.142109            -0.359251
# AMS.SJ.Equity             0.056358            -0.089124             0.235830
# RLO.SJ.Equity             0.360230            -0.052386             0.016634
# RDF.SJ.Equity             0.027139            -0.030449            -0.106582
# ARI.SJ.Equity             0.063882            -0.034743             0.061836
# ANG.SJ.Equity            -0.046980            -0.362044             0.098695
# HAR.SJ.Equity            -0.828927            -0.197400             0.245123
# AFE.SJ.Equity             0.087753             0.781464             0.015784
# MRP.SJ.Equity             0.780856            -0.186342             0.005296
# APN.SJ.Equity             0.011367             0.030012            -0.718541
# AFX.SJ.Equity             0.196591            -0.175877             0.122371
# SUR.SJ.Equity             0.292081            -0.207554            -0.228738
# DRD.SJ.Equity            -0.216696            -0.181636            -0.076439
# GRF.SJ.Equity            -1.347920            -0.527017            -2.140372
# SUI.SJ.Equity             0.020345            -0.031901             0.053458
# WBO.SJ.Equity            -0.022990             0.518966            -0.012029

# %%
spearmanr(df_TS_CS.iloc[:,j].values,df_Ex_SR_tmp_T.loc[index_tmp,index_times[index_times.index(k)+Gap]])
# Out:
# SpearmanrResult(correlation=0.004780811927720606, pvalue=0.9760285229315551)

# %%
IC_Series_tmp = IC_Series.T.set_index([pd.Index(pd.Series(range(0,len(IC_Series.T))))])
IC_Series_tmp = pd.concat([IC_Series_tmp, pd.DataFrame(k_index)], axis = 1)
IC_Series_tmp.columns = ['MKT','SMB','HML','RMW','CMA',"WML",'Size',"BM",'PE','OP','INV',"MOM",'Dates']
IC_Series_tmp = IC_Series_tmp.set_index('Dates')
IC_Series_tmp
# Out:
#                  MKT       SMB       HML       RMW       CMA       WML  \
# Dates
# 2004-10-28 -0.314883 -0.303152 -0.026760  0.505132 -0.141496  0.388196
# 2004-10-29 -0.356436 -0.381005 -0.380638  0.535387 -0.057572  0.581225
# 2004-11-01  0.353960 -0.194908  0.274158 -0.170085 -0.070056 -0.132942
# 2004-11-02  0.056082 -0.157213  0.289236  0.201527 -0.091754  0.124483
# 2004-11-03 -0.163183 -0.113678  0.069307  0.323066  0.026036  0.278695
# ...              ...       ...       ...       ...       ...       ...
# 2018-11-19  0.441374 -0.033304 -0.392270 -0.165222  0.389028 -0.168625
# 2018-11-20 -0.153721  0.163040  0.196264 -0.120254 -0.266683 -0.035412
# 2018-11-21  0.172676 -0.186938 -0.135889  0.140750  0.189693  0.109635
# 2018-11-22 -0.115145 -0.220809  0.197148  0.240418 -0.140102  0.412041
# 2018-11-23 -0.089863 -0.327121 -0.263755  0.192610  0.264403  0.228101
#
#                 Size        BM        PE        OP       INV       MOM
# Dates
# 2004-10-28  0.027859 -0.004765 -0.412757 -0.087977 -0.315249  0.103006
# 2004-10-29 -0.309498  0.069307  0.100477  0.133847 -0.157316  0.444078
# 2004-11-01  0.415926  0.028868 -0.200976 -0.049830 -0.136987 -0.171004
# 2004-11-02 -0.023168 -0.158684 -0.378967 -0.239773  0.083295  0.281329
# 2004-11-03 -0.089476 -0.279428 -0.033737 -0.061606  0.221856  0.270994
# ...              ...       ...       ...       ...       ...       ...
# 2018-11-19  0.077871  0.180131  0.365367 -0.003160 -0.338303  0.045134
# 2018-11-20 -0.244236 -0.230866 -0.183866 -0.141891 -0.029172 -0.327053
# 2018-11-21  0.116441  0.140588  0.199255  0.102504 -0.114821  0.038003
# 2018-11-22  0.266186  0.256948  0.016449  0.326797 -0.012884 -0.106555
# 2018-11-23  0.298598 -0.111417 -0.007698  0.207358  0.124382 -0.010615
#
# [3520 rows x 12 columns]

# %%
IC_Series = IC_Series_tmp
IC_Series
# Out:
#                  MKT       SMB       HML       RMW       CMA       WML  \
# Dates
# 2004-10-28 -0.314883 -0.303152 -0.026760  0.505132 -0.141496  0.388196
# 2004-10-29 -0.356436 -0.381005 -0.380638  0.535387 -0.057572  0.581225
# 2004-11-01  0.353960 -0.194908  0.274158 -0.170085 -0.070056 -0.132942
# 2004-11-02  0.056082 -0.157213  0.289236  0.201527 -0.091754  0.124483
# 2004-11-03 -0.163183 -0.113678  0.069307  0.323066  0.026036  0.278695
# ...              ...       ...       ...       ...       ...       ...
# 2018-11-19  0.441374 -0.033304 -0.392270 -0.165222  0.389028 -0.168625
# 2018-11-20 -0.153721  0.163040  0.196264 -0.120254 -0.266683 -0.035412
# 2018-11-21  0.172676 -0.186938 -0.135889  0.140750  0.189693  0.109635
# 2018-11-22 -0.115145 -0.220809  0.197148  0.240418 -0.140102  0.412041
# 2018-11-23 -0.089863 -0.327121 -0.263755  0.192610  0.264403  0.228101
#
#                 Size        BM        PE        OP       INV       MOM
# Dates
# 2004-10-28  0.027859 -0.004765 -0.412757 -0.087977 -0.315249  0.103006
# 2004-10-29 -0.309498  0.069307  0.100477  0.133847 -0.157316  0.444078
# 2004-11-01  0.415926  0.028868 -0.200976 -0.049830 -0.136987 -0.171004
# 2004-11-02 -0.023168 -0.158684 -0.378967 -0.239773  0.083295  0.281329
# 2004-11-03 -0.089476 -0.279428 -0.033737 -0.061606  0.221856  0.270994
# ...              ...       ...       ...       ...       ...       ...
# 2018-11-19  0.077871  0.180131  0.365367 -0.003160 -0.338303  0.045134
# 2018-11-20 -0.244236 -0.230866 -0.183866 -0.141891 -0.029172 -0.327053
# 2018-11-21  0.116441  0.140588  0.199255  0.102504 -0.114821  0.038003
# 2018-11-22  0.266186  0.256948  0.016449  0.326797 -0.012884 -0.106555
# 2018-11-23  0.298598 -0.111417 -0.007698  0.207358  0.124382 -0.010615
#
# [3520 rows x 12 columns]

# %%
# Annualized the mean of IC_Series
all_ICs = IC_Series.apply(lambda x: x.mean()*np.sqrt(252), axis = 0) 
all_ICs
# Out:
# MKT    -0.095741
# SMB    -0.095126
# HML     0.116481
# RMW     0.268809
# CMA    -0.199952
# WML     0.368239
# Size    0.041929
# BM      0.178530
# PE      0.224753
# OP      0.153694
# INV     0.024435
# MOM     0.180710
# dtype: float64

# %%
# Annualized ICIR
all_ICIRs = IC_Series.apply(lambda x: x.mean()/x.std()*np.sqrt(252), axis = 0) 
all_ICIRs
# Out:
# MKT    -0.390074
# SMB    -0.395656
# HML     0.540153
# RMW     0.995177
# CMA    -0.892853
# WML     1.342379
# Size    0.175811
# BM      0.991796
# PE      1.192712
# OP      0.752579
# INV     0.132443
# MOM     0.787076
# dtype: float64

# %%
## Plot Cumsum IC_Series of MKT
ax = IC_Series[['MKT']].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# MKT -0.095741 -0.390074

# %%
## Plot Cumsum IC_Series of WML
ax = IC_Series[['WML',"MOM"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[['WML',"MOM"]],all_ICIRs[['WML',"MOM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# WML  0.368239  1.342379
# MOM  0.180710  0.787076

# %%
## Plot Cumsum IC_Series of SMB & Size
# ax = IC_Series[["SMB","Size"]].cumsum().plot(title = 'Cumulative Sum of SMB & Size IC_Series',figsize = (8,4))
ax = IC_Series[["SMB","Size"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["SMB","Size"]],all_ICIRs[["SMB","Size"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#             IC      ICIR
# SMB  -0.095126 -0.395656
# Size  0.041929  0.175811

# %%
## Plot Cumsum IC_Series of HML & BM
ax = IC_Series[["HML","BM"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["HML","BM"]],all_ICIRs[["HML","BM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# HML  0.116481  0.540153
# BM   0.178530  0.991796

# %%
## Plot Cumsum IC_Series of HML & PE
ax = IC_Series[["HML","PE"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["HML","PE"]],all_ICIRs[["HML","PE"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# HML  0.116481  0.540153
# PE   0.224753  1.192712

# %%
## Plot Cumsum IC_Series of RMW & OP
ax = IC_Series[["RMW","OP"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["RMW","OP"]],all_ICIRs[["RMW","OP"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# RMW  0.268809  0.995177
# OP   0.153694  0.752579

# %%
## Plot Cumsum IC_Series of CMA & INV
ax = IC_Series[["CMA","INV"]].cumsum().plot(figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["CMA","INV"]],all_ICIRs[["CMA","INV"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# CMA -0.199952 -0.892853
# INV  0.024435  0.132443

# %%
pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
append(pd.concat([all_ICs[["SMB","Size"]],all_ICIRs[["SMB","Size"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["HML","BM"]],all_ICIRs[["HML","BM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["WML","MOM"]],all_ICIRs[["WML","MOM"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["RMW","OP"]],all_ICIRs[["RMW","OP"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})).\
append(pd.concat([all_ICs[["CMA","INV"]],all_ICIRs[["CMA","INV"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}))
# Out:
# <ipython-input-59-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-59-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-59-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-59-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
# <ipython-input-59-e463d04a53fa>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'}).\
#             IC      ICIR
# MKT  -0.095741 -0.390074
# SMB  -0.095126 -0.395656
# Size  0.041929  0.175811
# HML   0.116481  0.540153
# BM    0.178530  0.991796
# WML   0.368239  1.342379
# MOM   0.180710  0.787076
# RMW   0.268809  0.995177
# OP    0.153694  0.752579
# CMA  -0.199952 -0.892853
# INV   0.024435  0.132443

# %%
plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
corrMatrix = df_FF5.corr()
sn.heatmap(corrMatrix, annot=True, cmap="viridis")
plt.title('The Correlation Among TS Factors', fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 3>()
#       1 plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
#       2 corrMatrix = df_FF5.corr()
# ----> 3 sn.heatmap(corrMatrix, annot=True, cmap="viridis")
#       4 plt.title('The Correlation Among TS Factors', fontsize=10)
#       5 plt.show()
#
# NameError: name 'sn' is not defined
