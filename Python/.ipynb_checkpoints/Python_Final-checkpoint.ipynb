# %% [markdown]
# **Empirical Asset Pricing with Individual Stocks on the JSE: Betas Versus Characteristics**

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Load any required modules

# %%
import linearmodels
import json
import pandas as pd
import numpy as np
import seaborn as sn
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
from datetime import datetime
from scipy import stats
from tqdm import tqdm
from scipy.stats.mstats import spearmanr
from sklearn.linear_model import LinearRegression
from statsmodels.sandbox.regression.gmm import IV2SLS

# %%
plt.rcParams["figure.figsize"] = (5, 3.5) # Define the size of figures

# %% [markdown]
# ## Define Functions

# %% [markdown]
# Define the "replacer" funtion to replace the consecutive 0s with np.NaN in each column

# %%
def replacer(l,target_val=0,replace_val=np.NaN,repeat_max=10):
    #repeat_max = n (consecutive 0s over 10 times will be replaced with NAs)
    counter = 0
    new_l = []
    for e in l:
        if e == target_val: counter += 1
        else:
            counter = 0

        if counter > repeat_max:
            new_l.append(replace_val)
        else:
            new_l.append(e)

    return new_l

# %% [markdown]
# Define Newey-West t-test For Time-Series Data

# %%
def NW_ttest(ret,h0):
  T = len(ret)
  lag = int(4*(T/100)**(2/9))
  vv = np.var(ret)

  for l in range(0,lag):
      cc=np.cov(ret[0:(len(ret)-l)].T,ret[l:len(ret)].T)[0,1]
      vv=vv+2*(1-(l+1)/lag)*cc
      t=(np.mean(ret)-h0)/np.sqrt(vv)*np.sqrt(T)
  
  return t

# %% [markdown]
# Define the unlist function

# %%
def flatten(t):
    return [item for sublist in t for item in sublist]

# %% [markdown]
# GRS test for joint Alpha Distribution

# %%
"""
Function GRS_test(factor, resid, alpha) is to conduct GRS test according 
to Gibbons, Ross & Shanken(1989) to receive GRS-statistic and p-value.

H0: alpha1=alpha2=...=alphaN=0

Parameters:
  T = number of months
  N = number of portfolios/stocks
  L = number of factors

Inputs:
  factor: matrix of FF factors with shape (T, L)
  resid: matrix of residuals with shape (T, N)
  alpha: matrix of intercepts with shape (N, 1)

Outputs:
  f_grs: GRS-statistic
  p_grs: P-value

"""
from scipy.stats import f

def GRS_test(factor, resid, alpha):
    N = resid.shape[1]        
    T = resid.shape[0]       
    L = factor.shape[1]      

    if (T-N-L) < 0:
        print('can not conduct GRS test because T-N-L<0')
        return

    factor = np.asmatrix(factor)                   # factor matrix (T, L)
    resid = np.asmatrix(resid)                     # residual matrix (T, N)
    alpha = np.asmatrix(alpha).reshape(N, 1)       # intercept matrix (N, 1)

    mean_return_factor = (factor.mean(axis=0))

    # covariance matrix of residuals
    cov_resid = (resid.T * resid) / (T-L-1)
    # covariance matrix of factors
    cov_factor = ((factor - mean_return_factor).T * (factor - mean_return_factor)) / (T-1)

    mean_return_factor = mean_return_factor.reshape(L, 1)

    # GRS statistic
    # pinv.linalg.pinv is a pseudoinverse not a real one, for calculating the real inverse we need to use np.linalg.inv
    # However, the structure of resids matrix is oftenly a Singular matrix (one for which a inverse matrix does not exis)
    f_grs = float((T/N) * ((T-N-L)/(T-L-1)) * ((alpha.T * np.linalg.pinv(cov_resid) * alpha) / (1 + mean_return_factor.T * np.linalg.inv(cov_factor) * mean_return_factor)))

    # p-value
    p_grs = 1 - stats.f.cdf(f_grs, N, (T-N-L))

    return f_grs, p_grs

# %%
ols_model = LinearRegression()

# %% [markdown]
# ## Import Data

# %%
# Import excessive market return (J203T - Rf)
df_MR = pd.read_csv('df_MR.csv')
df_MR.Dates = df_MR.Dates.apply(lambda x:x[:10])
df_MR.set_index('Dates',inplace=True)

# %% [markdown]
# Import risk-free rate (91-day T-Bill)

# %%
df_RF = pd.read_csv('df_RF.csv',index_col=0)

# %% [markdown]
# Import listed stock returns on the JSE

# %%
df_SR = pd.read_csv('df_SR.csv',index_col=0)
df_SR.index = df_SR.index.to_series().apply(lambda x:x[:10])

# %% [markdown]
# Drop the columns of stock returns that full of 0s or NAs and replace consecutive 0s with NAs

# %%
df_SR = df_SR.loc[:, (df_SR != 0).any(axis=0)].astype(np.float64)
df_SR = df_SR.dropna(axis = 0, how = 'all')
# df_SR = df_SR.apply(replacer)

# %% [markdown]
# Calculate the Excess Stock Returns

# %%
df_Ex_SR = df_SR-df_RF.values

# %% [markdown]
# Import the Factor Realizations (Mimicking portfolio returns)

# %%
df_FF3 = pd.read_csv('df_FF3.csv')
df_FF3.Dates = df_FF3.Dates.apply(lambda x: x[:10])
df_FF3.set_index('Dates',inplace=True)

# %%
df_FF4 = pd.read_csv('df_FF4.csv')
df_FF4.Dates = df_FF4.Dates.apply(lambda x:x[:10])
df_FF4.set_index('Dates',inplace=True)

# %%
df_FF5 = pd.read_csv('df_FF5.csv')
df_FF5.Dates = df_FF5.Dates.apply(lambda x:x[:10])
df_FF5.set_index('Dates',inplace=True)

# %% [markdown]
# Import Firm Characteristics

# %%
df_ln_Size = pd.read_csv('df_ln_Size.csv')
df_ln_Size.Dates = df_ln_Size.Dates.apply(lambda x:x[:10])
df_ln_Size.set_index('Dates',inplace=True)

# %%
df_PE = pd.read_csv('df_std_PE.csv')
df_PE.Dates = df_PE.Dates.apply(lambda x:x[:10])
df_PE.set_index('Dates',inplace=True)

# %%
df_OP = pd.read_csv('df_std_OP.csv')
df_OP.Dates = df_OP.Dates.apply(lambda x:x[:10])
df_OP.set_index('Dates',inplace=True)

# %%
df_INV = pd.read_csv('df_std_INV.csv')
df_INV.Dates = df_INV.Dates.apply(lambda x:x[:10])
df_INV.set_index('Dates',inplace=True)

# %% [markdown]
# Import 18 double-sorted portfolios returns

# %%
df_18_PR = pd.read_csv('df_18_PR.csv')
df_18_PR.Dates = df_18_PR.Dates.apply(lambda x:x[:10])
df_18_PR.set_index('Dates',inplace=True)

# %% [markdown]
# Import Firm Characteristics of 18 double-sorted portfolios

# %%
df_18_std_Size = pd.read_csv('df_18_std_size.csv')
df_18_std_Size.Dates = df_18_std_Size.Dates.apply(lambda x:x[:10])
df_18_std_Size.set_index('Dates',inplace=True)

# %%
df_18_std_PE = pd.read_csv('df_18_std_PE.csv')
df_18_std_PE.Dates = df_18_std_PE.Dates.apply(lambda x:x[:10])
df_18_std_PE.set_index('Dates',inplace=True)

# %%
df_18_std_OP = pd.read_csv('df_18_std_OP.csv')
df_18_std_OP.Dates = df_18_std_OP.Dates.apply(lambda x:x[:10])
df_18_std_OP.set_index('Dates',inplace=True)

# %%
df_18_std_INV = pd.read_csv('df_18_std_INV.csv')
df_18_std_INV.Dates = df_18_std_INV.Dates.apply(lambda x:x[:10])
df_18_std_INV.set_index('Dates',inplace=True)

# %% [markdown]
# # Simulation (CAPM)

# %% [markdown]
# ## South African Sample (N=500, T=5215days)

# %% [markdown]
# To evaluate the samll sample properties of the IV method, a battery of simulations are conducted using the parameters matched to real data.

# %% [markdown]
# For each stock, we fit CAPM model regressions to esimate constant betas and residual return standard deviation (sigmas);
# Then we match the simulation paramters (mean & standard deviation) to the distribution of these parametes in the real data.

# %%
# the following codes estimate the market beta and the residual return standard deviations (sigmas)
df_Ex_SR_tmp = df_Ex_SR.loc[df_MR.index,:] # keep the length of stock returns equal to market factor returns

all_betas = []
all_sigmas = []

betas = []
sigmas = []
labels = []
# j is listed stock on the JSE
for j in tqdm(df_Ex_SR_tmp.columns):
    # drop the NA returns and only keep the date that have valid returns
    df_index = df_Ex_SR_tmp.loc[:,j].dropna().index
    # the regression will be run only when it has at least 10 observations
    if len(df_index) > 10:
        ols = sm.OLS(df_Ex_SR_tmp.loc[df_index,j].values.astype(np.float64), 
        sm.add_constant(df_MR.loc[df_index,:].values.astype(np.float64)))
        res = ols.fit()
        b = list(res.params)
        s = np.std(res.resid)
        betas.append(b)
        sigmas.append(s)
        labels.append(j)

all_betas.append(pd.DataFrame(betas))
all_sigmas.append(pd.DataFrame(sigmas))
# Out:
# 100%|██████████| 740/740 [00:01<00:00, 598.29it/s]

# %%
# The following are market betas
df_betas = pd.concat([all_betas[0], pd.DataFrame(labels)], axis = 1)
df_betas.columns = ['Intercepts','MKT','Stocks']
df_betas = df_betas.set_index('Stocks')
df_betas = df_betas[(np.abs((df_betas-df_betas.mean())/df_betas.std()) <= 3).all(axis=1)]
df_betas
# Out:
#                   Intercepts       MKT
# Stocks
# ABC.SJ.Equity      -0.003628  0.107916
# ABI.SJ.Equity       0.000074  0.255875
# ABK.SJ.Equity      -0.003187  0.302830
# ABR.SJ.Equity      -0.008640 -0.164395
# ABU.SJ.Equity      -0.000455  0.021532
# ...                      ...       ...
# ZGOVI.SJ.Equity     0.000049  0.046714
# ZPT.SJ.Equity      -0.003152  0.114757
# ZRNHDG.SJ.Equity   -0.000358  0.032715
# ZRR.SJ.Equity      -0.000676  0.286455
# ZSA.SJ.Equity       0.000176  0.021808
#
# [710 rows x 2 columns]

# %%
# The following are residual return standard deviations (sigmas)
df_sigmas = pd.concat([all_sigmas[0], pd.DataFrame(labels)], axis = 1)
df_sigmas.columns = ['sigmas','Stocks']
df_sigmas = df_sigmas.set_index('Stocks')
df_sigmas = df_sigmas[(np.abs((df_sigmas-df_sigmas.mean())/df_sigmas.std()) <= 3).all(axis=1)]
df_sigmas
# Out:
#                     sigmas
# Stocks
# ABC.SJ.Equity     0.063921
# ABI.SJ.Equity     0.011149
# ABK.SJ.Equity     0.077967
# ABR.SJ.Equity     0.079772
# ABU.SJ.Equity     0.018706
# ...                    ...
# ZGOVI.SJ.Equity   0.003672
# ZPT.SJ.Equity     0.089366
# ZRNHDG.SJ.Equity  0.006313
# ZRR.SJ.Equity     0.046410
# ZSA.SJ.Equity     0.011536
#
# [726 rows x 1 columns]

# %%
# The mean and standard deviation of real betas
m_all_betas = np.mean(df_betas.iloc[:,1])
sd_all_betas = np.std(df_betas.iloc[:,1])
print(m_all_betas, sd_all_betas)
# Out:
# 0.2449107484361108 0.25974384879482887

# %%
# # The mean and standard deviation of real sigmas
m_all_sigmas = np.mean(df_sigmas.iloc[:,0].astype('float64'))
sd_all_sigmas = np.std(df_sigmas.iloc[:,0].astype('float64'))
print(m_all_sigmas, sd_all_sigmas)
# Out:
# 0.026870760329904132 0.0199684554616268

# %% [markdown]
# ### Simulated betas and sigmas are fixed during 100 repetitions

# %% [markdown]
# The study conducts simulations with the cross-sectional size of N=500 stocks. We randomly generat daily returns using the following procedures:
#
# Step-1: For each stock, we randomly generate a beta and a standard deviations of return residuals from normal distributions.

# %%
# How many cross-sectional stocks in the simulation sample
N = 500

# %% [markdown]
# Simulate market betas:
# The mean and standard deviation of simulated betas are set to be the same as the real betas

# %%
sim_betas_tmp = []
sim_betas_tmp.append(np.random.normal(loc = m_all_betas,scale = sd_all_betas, size= N ))
np.mean(sim_betas_tmp), np.std(sim_betas_tmp)
# Out:
# (0.2498200346050054, 0.2439746643795157)

# %%
# Print simulated betas
sim_betas = pd.DataFrame(sim_betas_tmp)
sim_betas
# Out:
#         0        1         2         3         4        5         6    \
# 0  0.471097  0.25151  0.417735  0.203669 -0.093943  0.35488  0.256722
#
#         7         8         9    ...       490       491       492       493  \
# 0  0.208648 -0.212561  0.007372  ...  0.207082  0.520577  0.600756  0.775362
#
#         494       495      496       497       498       499
# 0 -0.084572 -0.164296  0.34887 -0.359284  0.514078  0.127867
#
# [1 rows x 500 columns]

# %%
# Simulate the residual return standard deviations (sigmas)
sim_sigmas_tmp = []
sim_sigmas_tmp.append(np.random.normal(loc = m_all_sigmas,scale = sd_all_sigmas, size= N ))
np.mean(sim_sigmas_tmp), np.std(sim_sigmas_tmp)
# Out:
# (0.02579057748631437, 0.020129390551158904)

# %%
# Print simulated sigmas
sim_sig_res = pd.DataFrame(sim_sigmas_tmp).abs()
sim_sig_res
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.014714  0.026213  0.011791  0.004875  0.007947  0.007417  0.032165
#
#         7        8         9    ...       490       491       492     493  \
# 0  0.039737  0.00276  0.045123  ...  0.061252  0.016208  0.023319  0.0437
#
#         494       495      496       497       498       499
# 0  0.039254  0.048446  0.03641  0.016159  0.020989  0.026209
#
# [1 rows x 500 columns]

# %% [markdown]
# ### Simulated market, stock and residual returns are changable during 100 repetitions

# %% [markdown]
# Step-2: For each day, we randomly draw market excess return from a normal distribution with mean and standard deviation equal to the real mean and standard deviation from the sample data

# %%
# Print the mean and standard deviation of real market return
mean_MKT = np.mean(df_MR.iloc[:,0])
sd_MKT = np.std(df_MR.iloc[:,0])
print(mean_MKT, sd_MKT)
# Out:
# 0.0002807670182166827 0.011549088535812713

# %%
# Simulated market factor returns
sim_MKT_tmp = []
sim_MKT_tmp.append(np.random.normal(loc = mean_MKT,scale = sd_MKT, size= len(df_MR)))
print(np.mean(sim_MKT_tmp), np.std(sim_MKT_tmp))
# Out:
# 0.00013439281923030992 0.011396560832112667

# %%
# Print simulated market returns
sim_MKT = pd.DataFrame(sim_MKT_tmp).T
sim_MKT.index = df_MR.index
sim_MKT.columns = ['RM-RF']
sim_MKT
# Out:
#                RM-RF
# Dates
# 2000-01-05  0.000939
# 2000-01-06 -0.012891
# 2000-01-07 -0.011070
# 2000-01-10 -0.002010
# 2000-01-11 -0.017314
# ...              ...
# 2019-12-25  0.001595
# 2019-12-26 -0.017860
# 2019-12-27 -0.002064
# 2019-12-30 -0.004438
# 2019-12-31  0.013052
#
# [5215 rows x 1 columns]

# %% [markdown]
# Step-3: For each stock, we then randomly generate daily residual return from a normal distribution with mean zero and standard deviation equal to the value generate in step-1, i.e. sim_sigmas

# %%
res_return = pd.DataFrame(np.zeros((len(sim_MKT), len(sim_sig_res.columns))))
for j in range(len(sim_sig_res.columns)):
    res_return.iloc[:,j] = np.random.normal(loc = 0,scale = sim_sig_res[j], size= len(sim_MKT))
res_return
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.005714  0.008459  0.012206 -0.014783  0.013147 -0.015898 -0.005164
# 1    -0.026467 -0.032782  0.000005  0.002914  0.008555 -0.007573  0.009387
# 2    -0.019614  0.002574 -0.006377 -0.007690 -0.003110  0.002823  0.024885
# 3    -0.000411  0.001944  0.003685  0.004894 -0.000245 -0.001211 -0.049173
# 4     0.000472 -0.001241  0.003742 -0.000144 -0.001505 -0.001465  0.009092
# ...        ...       ...       ...       ...       ...       ...       ...
# 5210 -0.014394  0.001525 -0.026305  0.006973  0.003774 -0.000249  0.014303
# 5211 -0.005167 -0.026985  0.005631 -0.001430 -0.004763  0.001431  0.025837
# 5212  0.002669  0.000626 -0.001875 -0.004051 -0.011433 -0.004135 -0.014750
# 5213 -0.006884 -0.001012  0.005253  0.006907  0.000688 -0.002650 -0.008478
# 5214 -0.010579  0.013824 -0.026210 -0.005222 -0.020996  0.001115 -0.008232
#
#            7         8         9    ...       490       491       492  \
# 0    -0.006438 -0.003839 -0.055815  ...  0.023519  0.025138  0.037284
# 1     0.002624 -0.003900  0.051077  ... -0.003202 -0.005909 -0.030713
# 2     0.086071 -0.001171  0.026803  ...  0.179446 -0.011529  0.004824
# 3     0.038629 -0.001419  0.044054  ...  0.017844 -0.006457  0.046022
# 4    -0.010984 -0.001134 -0.029501  ...  0.018461 -0.010135  0.030249
# ...        ...       ...       ...  ...       ...       ...       ...
# 5210  0.016834  0.002884 -0.050470  ...  0.002756 -0.012385 -0.032155
# 5211  0.019590  0.000141  0.012647  ...  0.051342  0.008211 -0.007159
# 5212  0.069896  0.001430 -0.020468  ...  0.006454 -0.002597 -0.016886
# 5213  0.007748  0.001742 -0.036236  ... -0.068897  0.018330 -0.017912
# 5214 -0.038221 -0.000821 -0.026144  ...  0.082189  0.001222  0.009693
#
#            493       494       495       496       497       498       499
# 0     0.013591  0.015462  0.068611 -0.008891  0.005144 -0.023444  0.008105
# 1    -0.052780 -0.004898 -0.069973  0.030689  0.017689 -0.000411 -0.023430
# 2     0.086193 -0.057376  0.049558  0.041372 -0.005509 -0.050487  0.021835
# 3    -0.007368 -0.007298  0.065589  0.007927  0.008327 -0.034042 -0.036905
# 4    -0.014201 -0.019831 -0.044148  0.014796  0.022356 -0.025712  0.044457
# ...        ...       ...       ...       ...       ...       ...       ...
# 5210  0.036602  0.045998  0.026315  0.028977  0.004439 -0.040123  0.018718
# 5211 -0.061098  0.000631  0.068095 -0.016588  0.027439 -0.005672 -0.021114
# 5212  0.016275 -0.036424 -0.055859  0.066215  0.004615  0.002811 -0.015686
# 5213  0.000187  0.037902 -0.016878 -0.019590  0.015554  0.016829 -0.010271
# 5214 -0.040995  0.078507  0.020181  0.022309 -0.001663  0.012906  0.011528
#
# [5215 rows x 500 columns]

# %% [markdown]
# Step-4: For stock i, we compute its excess return as beta,i*MKT,t + episiloni,t

# %%
sim_SR = (np.mat(sim_MKT.iloc[:,0]).T*np.mat(sim_betas.iloc[0,:].values)) + res_return
sim_SR = pd.DataFrame(sim_SR)
sim_SR.index = df_Ex_SR.index
sim_SR
# Out:
#                  0         1         2         3         4         5    \
# Dates
# 2000-01-05 -0.005271  0.008695  0.012598 -0.014592  0.013059 -0.015565
# 2000-01-06 -0.032540 -0.036024 -0.005380  0.000288  0.009766 -0.012148
# 2000-01-07 -0.024829 -0.000211 -0.011001 -0.009945 -0.002070 -0.001105
# 2000-01-10 -0.001358  0.001439  0.002845  0.004485 -0.000056 -0.001924
# 2000-01-11 -0.007684 -0.005596 -0.003490 -0.003670  0.000122 -0.007609
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-25 -0.013642  0.001926 -0.025638  0.007298  0.003624  0.000317
# 2019-12-26 -0.013581 -0.031477 -0.001830 -0.005068 -0.003085 -0.004908
# 2019-12-27  0.001697  0.000107 -0.002737 -0.004471 -0.011239 -0.004868
# 2019-12-30 -0.008975 -0.002128  0.003399  0.006003  0.001104 -0.004225
# 2019-12-31 -0.004430  0.017107 -0.020758 -0.002564 -0.022223  0.005747
#
#                  6         7         8         9    ...       490       491  \
# Dates                                               ...
# 2000-01-05 -0.004923 -0.006242 -0.004039 -0.055809  ...  0.023714  0.025626
# 2000-01-06  0.006077 -0.000066 -0.001160  0.050982  ... -0.005872 -0.012619
# 2000-01-07  0.022043  0.083762  0.001182  0.026721  ...  0.177154 -0.017291
# 2000-01-10 -0.049689  0.038209 -0.000992  0.044039  ...  0.017428 -0.007504
# 2000-01-11  0.004647 -0.014596  0.002546 -0.029629  ...  0.014875 -0.019148
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-12-25  0.014712  0.017166  0.002545 -0.050459  ...  0.003087 -0.011555
# 2019-12-26  0.021252  0.015863  0.003937  0.012516  ...  0.047644 -0.001087
# 2019-12-27 -0.015280  0.069465  0.001869 -0.020483  ...  0.006026 -0.003671
# 2019-12-30 -0.009618  0.006822  0.002686 -0.036269  ... -0.069816  0.016020
# 2019-12-31 -0.004881 -0.035498 -0.003596 -0.026048  ...  0.084891  0.008017
#
#                  492       493       494       495       496       497  \
# Dates
# 2000-01-05  0.037848  0.014319  0.015383  0.068456 -0.008563  0.004807
# 2000-01-06 -0.038457 -0.062775 -0.003808 -0.067855  0.026192  0.022320
# 2000-01-07 -0.001826  0.077610 -0.056440  0.051377  0.037510 -0.001532
# 2000-01-10  0.044815 -0.008927 -0.007128  0.065919  0.007226  0.009049
# 2000-01-11  0.019847 -0.027625 -0.018366 -0.041304  0.008756  0.028576
# ...              ...       ...       ...       ...       ...       ...
# 2019-12-25 -0.031197  0.037839  0.045863  0.026053  0.029533  0.003866
# 2019-12-26 -0.017889 -0.074946  0.002141  0.071029 -0.022819  0.033856
# 2019-12-27 -0.018126  0.014674 -0.036250 -0.055520  0.065495  0.005356
# 2019-12-30 -0.020578 -0.003254  0.038278 -0.016149 -0.021138  0.017148
# 2019-12-31  0.017534 -0.030875  0.077403  0.018036  0.026862 -0.006353
#
#                  498       499
# Dates
# 2000-01-05 -0.022961  0.008225
# 2000-01-06 -0.007038 -0.025079
# 2000-01-07 -0.056178  0.020420
# 2000-01-10 -0.035076 -0.037162
# 2000-01-11 -0.034613  0.042243
# ...              ...       ...
# 2019-12-25 -0.039303  0.018922
# 2019-12-26 -0.014853 -0.023397
# 2019-12-27  0.001750 -0.015950
# 2019-12-30  0.014548 -0.010839
# 2019-12-31  0.019616  0.013197
#
# [5215 rows x 500 columns]

# %%
# The study assumes 21 days per month, T = 252 days corresponds to one year
months = []
periods = int(len(sim_SR)/21)+1
mons = pd.date_range(start=sim_SR.index[0], periods = periods, freq='M').astype(str).str[:7]
for i in range(periods): 
    m = mons[i]
    months.append(np.repeat(m,21))

# %% [markdown]
# Sum simulated daily stock returns to monthly returns. They are addable because they are log returns. In line with Jegadeesh et al. (2019), the simulation first estimate beta on a daily basis and then estimate risk premium on a monthly basis.

# %%
# Monthly version of simulated stock returns
m_sim_SR = sim_SR
m_sim_SR['month'] = np.array(flatten(months)[0:len(sim_SR)], dtype = str)
m_sim_SR = m_sim_SR.groupby('month').sum()
sim_SR = sim_SR.drop(['month'], axis = 1)
m_sim_SR = m_sim_SR.iloc[:-1,:]
m_sim_SR
# Out:
#               0         1         2         3         4         5         6    \
# month
# 2000-01 -0.190465  0.011287 -0.077549 -0.068296  0.004788 -0.021945  0.202906
# 2000-02  0.036094  0.034950  0.058678  0.048786  0.042255 -0.034586 -0.077109
# 2000-03  0.038372 -0.031274  0.064740  0.025887  0.020602  0.068991  0.219225
# 2000-04 -0.013618  0.162364 -0.017058  0.003127  0.074159 -0.066937 -0.213739
# 2000-05 -0.036925 -0.134436 -0.024192 -0.014490  0.045043 -0.027147 -0.263018
# ...           ...       ...       ...       ...       ...       ...       ...
# 2020-04 -0.112544  0.157941 -0.089538 -0.054368 -0.023708  0.054672  0.139138
# 2020-05 -0.083565  0.108201 -0.012833 -0.045484  0.016600 -0.003497  0.056637
# 2020-06 -0.117825 -0.187663 -0.114193 -0.030095 -0.051627  0.003825 -0.117618
# 2020-07  0.078422  0.012410  0.006213 -0.019568 -0.037587  0.031246  0.037154
# 2020-08  0.089203 -0.154049 -0.038907 -0.002682 -0.010415  0.017189 -0.426729
#
#               7         8         9    ...       490       491       492  \
# month                                  ...
# 2000-01  0.016117 -0.014479  0.047877  ... -0.003851 -0.104723 -0.103738
# 2000-02  0.171065 -0.022349 -0.047953  ...  0.343997  0.132332 -0.021731
# 2000-03 -0.381093 -0.015832  0.059987  ... -0.146498  0.069595  0.029745
# 2000-04  0.208236  0.003111 -0.212273  ... -0.353289  0.020295 -0.160408
# 2000-05  0.268034  0.010759 -0.152773  ... -0.023501 -0.017273 -0.104815
# ...           ...       ...       ...  ...       ...       ...       ...
# 2020-04 -0.310106  0.014084 -0.138560  ...  0.042450 -0.080921 -0.106755
# 2020-05  0.042524 -0.005863  0.142106  ... -0.189662  0.030993 -0.122978
# 2020-06  0.233158  0.008298  0.192339  ...  0.297220  0.031376 -0.048492
# 2020-07 -0.045052 -0.008220 -0.142629  ...  0.095245 -0.067581  0.005123
# 2020-08 -0.100861 -0.011985  0.097100  ... -0.403234  0.147914  0.048010
#
#               493       494       495       496       497       498       499
# month
# 2000-01  0.133224 -0.235919  0.051661  0.262992 -0.005304 -0.143385  0.243026
# 2000-02 -0.351742  0.351578  0.138734  0.295836 -0.046113  0.144174  0.126199
# 2000-03 -0.023029 -0.188369 -0.480524  0.372822  0.112019  0.156072  0.174683
# 2000-04  0.034962  0.150414 -0.337758 -0.020438 -0.027564 -0.031177 -0.119925
# 2000-05 -0.139309 -0.061849 -0.030290 -0.174031 -0.041997  0.000936  0.040697
# ...           ...       ...       ...       ...       ...       ...       ...
# 2020-04 -0.082771  0.122357  0.093022  0.144842  0.079206 -0.107348 -0.125193
# 2020-05 -0.085879  0.272622 -0.627236 -0.322649 -0.008302  0.058584  0.086568
# 2020-06  0.030838 -0.169829  0.199581  0.129631  0.012712 -0.097777 -0.009692
# 2020-07 -0.231946  0.227275 -0.189870 -0.204265  0.017814 -0.067203 -0.020887
# 2020-08 -0.098072 -0.324627  0.050238 -0.201027 -0.063318 -0.029252  0.013173
#
# [248 rows x 500 columns]

# %%
# Monthly version of simulated stock returns
m_sim_MKT = sim_MKT
m_sim_MKT['month'] = np.array(flatten(months)[0:len(sim_SR)], dtype = str)
m_sim_MKT = m_sim_MKT.groupby('month').sum()
sim_MKT = sim_MKT.drop(['month'], axis = 1)
m_sim_MKT = m_sim_MKT.iloc[:-1,:]
m_sim_MKT
# Out:
#             RM-RF
# month
# 2000-01 -0.026174
# 2000-02  0.094410
# 2000-03  0.064188
# 2000-04 -0.003372
# 2000-05  0.044373
# ...           ...
# 2020-04 -0.048172
# 2020-05 -0.002324
# 2020-06 -0.032466
# 2020-07  0.030145
# 2020-08  0.079101
#
# [248 rows x 1 columns]

# %%
# Monthly version of real market returns
m_MR = df_MR
m_MR['month'] = np.array(flatten(months)[0:len(sim_SR)], dtype = str)
m_MR = m_MR.groupby('month').sum()
df_MR = df_MR.drop(['month'], axis = 1)
m_MR = m_MR.iloc[:-1,:]
m_MR
# Out:
#           MR_RF
# month
# 2000-01  0.0154
# 2000-02 -0.0955
# 2000-03 -0.0024
# 2000-04 -0.0693
# 2000-05 -0.0119
# ...         ...
# 2020-04 -0.0695
# 2020-05  0.0382
# 2020-06 -0.0010
# 2020-07  0.0142
# 2020-08  0.0126
#
# [248 rows x 1 columns]

# %% [markdown]
# ### FM-OLS (Constant Betas)

# %% [markdown]
# Try to run FM OLS (without rolling windows) to estimate risk premiums of market factor. Use the factor model in the linearmodel module, however, this function does not allow for time-varying betas, so the FM two-step regression would yield the same results as cross-sectional regression.

# %%
from linearmodels.asset_pricing.model import LinearFactorModel
model_ols = LinearFactorModel(portfolios=sim_SR, factors= sim_MKT, risk_free = None)
res_ols = model_ols.fit()
res_ols.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                       LinearFactorModel Estimation Summary
# ================================================================================
# No. Test Portfolios:                500   R-squared:                      0.0146
# No. Factors:                          1   J-statistic:                    557.21
# No. Observations:                  5215   P-value                         0.0362
# Date:                  Sun, May 01 2022   Distribution:                chi2(499)
# Time:                          03:22:02
# Cov. Estimator:                  robust
#
#                             Risk Premia Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# RM-RF          0.0002     0.0002     1.0261     0.3048     -0.0002      0.0005
# ==============================================================================
#
# Covariance estimator:
# HeteroskedasticCovariance
# See full_summary for complete results
# """

# %%
# Print the ex-ante and ex-post biases of FM OLS (without rolling windows) regression
print("ex-ante bias(%):" + str(((res_ols.risk_premia-mean_MKT)/mean_MKT*100).values))
print("ex-post bias(%):" + str(((res_ols.risk_premia-np.mean(sim_MKT, axis = 0))/np.mean(sim_MKT, axis = 0)*100).values))
# Out:
# ex-ante bias(%):[-38.56126919]
# ex-post bias(%):[28.3548433]

# %% [markdown]
# ### FM-OLS (Time-Varying Betas)

# %% [markdown]
# Step-5: For the first-stage regression of FM in the simulation, we estimate betas using time series regression of CAPM model

# %%
# how many years in the rolling window periods
n = 3

# %%
# This cell defines the rolling estimation window (n years) and 
# rebalance frequency (monthly) for the first stage of FM regression
holding = 21 # 21 days per month
rollingW = holding * n *12
lens = len(sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 211 756

# %% [markdown]
# The first stage of FM OLS regression (Beta Estimates)

# %%
# Estimate market betas by regressing sim_SR on sim_MKT
all_betas = []

# i is time in periods
for i in tqdm(range(periods)):

    sim_MKT_tmp = sim_MKT.iloc[i*holding:i*holding+rollingW,:]
    sim_SR_tmp = sim_SR.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []
    # j is a listed stock on the JSE
    for j in sim_SR.columns:      
        lag = int(4*((len(sim_SR.loc[:,j]))/100)**(1/9))
        OLS = sm.OLS(sim_SR_tmp.loc[:,j].values.astype(np.float64), sm.add_constant(sim_MKT_tmp.values.astype(np.float64)))
#         res = OLS.fit()
        res = OLS.fit(cov_type='HAC',cov_kwds={'maxlags':lag})
        b = list(res.params)
        betas.append(b)

    df_betas = pd.DataFrame(betas).rename(columns={0:'Intercepts',1:'MKT'})
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 211/211 [00:44<00:00,  4.72it/s]

# %%
# Print the betas and intercepts for one period
all_betas[0]
# Out:
#      Intercepts       MKT
# 0     -0.000328  0.461648
# 1      0.001443  0.132943
# 2      0.000465  0.350679
# 3     -0.000010  0.204933
# 4      0.000031 -0.100848
# ..          ...       ...
# 495    0.000531 -0.249526
# 496   -0.001761  0.405898
# 497    0.000539 -0.329554
# 498    0.000316  0.521511
# 499   -0.000368  0.152613
#
# [500 rows x 2 columns]

# %%
# Test the correlation between estimated betas and simulated betas
corr_betas_true = []

for i in range(len(all_betas)):
    corr = stats.pearsonr(all_betas[i].MKT.values.astype(np.float64).flatten(),sim_betas.iloc[0,:].values.astype(np.float64).flatten())[0]
    corr_betas_true.append(corr)

print(np.mean(corr_betas_true), stats.ttest_1samp(corr_betas_true, 0.0)[0])
# Out:
# 0.9188457811186628 2068.005317747081

# %%
# This cell redefine the daily regression to monthly regression
# by simple change the holding periods from "21 days" to "1 month"
holding = 1 
rollingW = holding *n*12
lens = len(m_sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 211 36

# %% [markdown]
# The second stage of FM OLS regression (factor premium estimates)

# %%
# This cell estimate the risk premiums (lambdas) of market factor and
# the residual returns.
all_lambdas_OLS = []
all_resids_OLS = []

m_sim_SR_tmp_T = m_sim_SR.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
resids = []
index_times = list(m_sim_SR_tmp_T.columns)

for k in tqdm(m_sim_SR_tmp_T.columns):   
    i = int(index_times.index(k)/holding)
    OLS = sm.OLS(m_sim_SR_tmp_T.loc[:,k], 
                 sm.add_constant(all_betas[i].loc[:,"MKT"].astype(np.float64)))
    res = OLS.fit()
    l = list(res.params)
    r = list(res.resid)
    lambdas.append(l)
    resids.append(r)
        
all_lambdas_OLS.append(pd.DataFrame(lambdas))
all_resids_OLS.append(pd.DataFrame(resids))
# Out:
# 100%|██████████| 211/211 [00:00<00:00, 601.92it/s]

# %%
# Print risk premiums of Market factor and the intercepts
all_lambdas_OLS[0].rename(columns={0:'Intercept',1:'MKT'})
# Out:
#      Intercept       MKT
# 0    -0.017479 -0.024159
# 1    -0.007656  0.026816
# 2    -0.004432 -0.013993
# 3     0.002336 -0.029079
# 4     0.016605 -0.007469
# ..         ...       ...
# 206   0.006006 -0.054602
# 207  -0.010656 -0.018351
# 208   0.000514 -0.012886
# 209   0.021318 -0.051078
# 210   0.023548 -0.000209
#
# [211 rows x 2 columns]

# %%
# Print residual returns
all_resids_OLS = pd.DataFrame(all_resids_OLS[0].T)
all_resids_OLS
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.013441 -0.049017  0.165446 -0.082762 -0.144303 -0.046825 -0.013629
# 1    0.059789 -0.148607 -0.001657  0.017282 -0.146440 -0.213878  0.179963
# 2    0.099415 -0.020342  0.049740  0.054372  0.094424  0.081517  0.016043
# 3    0.022403  0.025197 -0.011667  0.020827 -0.006289  0.032432 -0.031347
# 4    0.007631  0.001654 -0.009730  0.011979 -0.067347  0.036314  0.007966
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.025651 -0.021024 -0.280416  0.243583  0.085751 -0.285458  0.002200
# 496  0.166004 -0.125693  0.172813 -0.073952  0.152652 -0.022723 -0.295563
# 497 -0.021645  0.028245  0.026180  0.008417 -0.063782  0.015876  0.057994
# 498 -0.185310  0.053268  0.084460  0.053667 -0.157849 -0.021295 -0.133385
# 499  0.119170  0.037398 -0.072149 -0.112332  0.322417 -0.067280  0.052252
#
#           7         8         9    ...       201       202       203  \
# 0   -0.122455  0.021391  0.086369  ... -0.039329  0.031456  0.036255
# 1   -0.138311 -0.173864  0.012548  ...  0.192930 -0.080393 -0.143754
# 2    0.030319  0.079118  0.074080  ...  0.026516 -0.051600 -0.032395
# 3    0.032124 -0.021360 -0.027467  ...  0.011334  0.031968 -0.020770
# 4    0.017246 -0.063391 -0.018023  ...  0.061589 -0.008111  0.035312
# ..        ...       ...       ...  ...       ...       ...       ...
# 495 -0.043910  0.155862 -0.307567  ... -0.083213  0.212889 -0.094313
# 496  0.208003 -0.142938 -0.358018  ...  0.033606  0.149642  0.065827
# 497 -0.187629  0.035855  0.026524  ... -0.022885  0.091171 -0.032226
# 498 -0.098381 -0.001115  0.110822  ...  0.052845 -0.086508 -0.020620
# 499  0.099714 -0.098000  0.066531  ... -0.032090 -0.116017  0.133297
#
#           204       205       206       207       208       209       210
# 0   -0.063192  0.027625  0.022075 -0.093776 -0.078358 -0.115897  0.054971
# 1   -0.156876 -0.107391 -0.072288  0.175002  0.111692 -0.192435 -0.011071
# 2    0.038738 -0.047635 -0.014940 -0.072068 -0.008511 -0.116536 -0.017258
# 3   -0.034707  0.004139 -0.005280 -0.040090 -0.043384 -0.040922 -0.043073
# 4    0.009872  0.098791  0.000339 -0.014076  0.015429 -0.075462 -0.061144
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.290798 -0.129776 -0.182955  0.097415 -0.632125  0.163642 -0.213462
# 496 -0.257457  0.253562 -0.443058  0.162988 -0.317076  0.130903 -0.227722
# 497  0.051407  0.050450 -0.242591  0.084260 -0.012850 -0.025455 -0.005800
# 498  0.059733  0.011295  0.104449 -0.087046  0.064238 -0.095606 -0.090657
# 499 -0.172185 -0.059630 -0.176304 -0.112207  0.087590 -0.024719 -0.044410
#
# [500 rows x 211 columns]

# %%
# Compute the t-statistics of intercept of market premiums
stats.ttest_1samp(all_lambdas_OLS[0], 0.0)[0]
# Out:
# array([-0.54436676,  0.7645957 ])

# %%
## Print the time-series average of market premiums (monthly)
print(np.mean(all_lambdas_OLS[0].iloc[:,1]))
# Out:
# 0.0029021168529910412

# %%
# Test whether the betas in the second-stage of FM is endougenous
corr_betas_res = []

for i in range(np.shape(all_resids_OLS)[1]):
    corr = stats.pearsonr(all_betas[i].MKT.values.astype(np.float64).flatten(),all_resids_OLS.iloc[:,i].values.astype(np.float64).flatten())[0]
    corr_betas_res.append(corr)

print("Rho:" + str(np.mean(corr_betas_res)), "x is Endogenous" if np.mean(corr_betas_res).round(10)!=0 else "betas are Exogenous")
# Out:
# Rho:3.0933161508828136e-18 betas are Exogenous

# %%
# Calculate the ex-ante and ex-post biases
print("ex-ante bias(%): " + str((np.mean(all_lambdas_OLS[0].iloc[:,1]) - np.mean(m_MR.values))/(np.mean(m_MR.values))*100))
print("ex-post bias(%): " + str((np.mean(all_lambdas_OLS[0].iloc[:,1]) - np.mean(m_sim_MKT.values))/np.mean(m_sim_MKT.values)*100))
# Out:
# ex-ante bias(%): -51.06242064718989
# ex-post bias(%): 3.2444671376020486

# %%
m_MR_tmp = m_MR.iloc[rollingW+1:len(m_MR),:]
m_sim_MKT_tmp = m_sim_MKT.iloc[rollingW+1:len(m_MR),:]

# %%
## Calculate the Ex-ante RMSE
diff = all_lambdas_OLS[0].iloc[:,1]-np.array(m_MR_tmp).flatten()
np.sqrt((diff**2).mean())
# Out:
# 0.07887712887849865

# %%
## Calculate the Ex-post RMSE
diff = all_lambdas_OLS[0].iloc[:,1]-np.array(m_sim_MKT_tmp).flatten()
np.sqrt((diff**2).mean())
# Out:
# 0.07195123990715485

# %%
## Plot the the distribution of estimated market premium time-series
all_lambdas_OLS[0].iloc[:,1].plot(kind='density')
all_lambdas_OLS[0].iloc[:,1].hist()
plt.show()

# %% [markdown]
# ### FM-IV (Time-Varying Betas)

# %%
# this cell define the rolling estimation window (n years) the rebalance frequency (monthly)
# for the first stage of FM regression
holding = 21 # 21 days per month
rollingW = holding * n *12
lens = len(sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(rollingW, periods)
# Out:
# 756 211

# %% [markdown]
# For the IV approach, the study estimate betas within odd months and even months separately. Then we use odd-month betas as instrumental variables and even-month betas as explanatory variables when month t is even and vice versa when month t is odd.

# %% [markdown]
# The first stage of FM IV regression (explanatory and instrumental beta estimates)

# %%
# This cell estimates the explanatory betas and instrumental betas
# These betas will be further used as explanatory variables and instrumental
# variabnles in the second stage to estimate risk premiums of market factor

all_betas_ev = []
all_betas_iv = []

for i in tqdm(range(periods)):

    sim_MKT_tmp = sim_MKT.iloc[i*holding:i*holding+rollingW,:]
    sim_SR_tmp = sim_SR.iloc[i*holding:i*holding+rollingW,:]
    
    # if current i is even-month
    if (i + 1) % 2 == 1:
        # extract all even-months within the rolling window into the explanatory betas estimation 
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        
        for j in sim_SR.columns:
            df_index = rw_odd.index
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev))
        all_betas_ev.append(df_betas_ev)
        
        # extract all odd-months within the rolling window into the instrumental betas estimation 
        rw_even = pd.DataFrame()         
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])
        
        betas_iv = []
        
        for j in sim_SR.columns:
            df_index = rw_even.index   
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_iv.append(b)      
        df_betas_iv = pd.DataFrame(np.array(betas_iv))
        all_betas_iv.append(df_betas_iv)

    # if current i is odd-month
    if (i + 1) % 2 == 0:
        # extract all even-months into the instrumental betas estimation window 
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])

        betas_iv = []
        
        for j in sim_SR.columns:
            df_index = rw_odd.index   
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_iv.append(b)        
        df_betas_iv = pd.DataFrame(np.array(betas_iv))
        all_betas_iv.append(df_betas_iv)
        
        # extract all odd-months into the explanatory betas estimation window 
        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        
        for j in sim_SR.columns:
            df_index = rw_even.index         
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev))
        all_betas_ev.append(df_betas_ev)
# Out:
# 100%|██████████| 211/211 [02:17<00:00,  1.53it/s]

# %%
# Print explanatory betas for one period
all_betas_ev[0]
# Out:
#             0
# 0    0.432963
# 1    0.054911
# 2    0.385655
# 3    0.214774
# 4   -0.138009
# ..        ...
# 495 -0.225250
# 496  0.395418
# 497 -0.342071
# 498  0.597703
# 499  0.059922
#
# [500 rows x 1 columns]

# %%
# Print instrumental betas for one period
all_betas_iv[0]
# Out:
#             0
# 0    0.491792
# 1    0.230083
# 2    0.318444
# 3    0.198573
# 4   -0.067929
# ..        ...
# 495 -0.259508
# 496  0.419555
# 497 -0.318513
# 498  0.447094
# 499  0.226139
#
# [500 rows x 1 columns]

# %%
holding = 1 # 1 month
rollingW = holding * n *12
lens = len(m_sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 211 36

# %% [markdown]
# A rule of thumb is the first stage (i.e., the regression of x on the instrument and any covariates)should have an F statistic of at least 10.

# %%
# This cell test the f-values of the first stage of IV-2SLS (two-stage least squares) regression
fvalues = []

for i in tqdm(range(len(all_betas_ev))):
    ols = sm.OLS(all_betas_ev[i].values.astype(np.float64), sm.add_constant(all_betas_iv[i].values.astype(np.float64)))
    res = ols.fit()
    f = res.fvalue
    fvalues.append(f)
# Out:
# 100%|██████████| 211/211 [00:00<00:00, 2360.86it/s]

# %%
pd.DataFrame(fvalues).describe()
# Out:
#                 0
# count  211.000000
# mean   587.547123
# std     91.974546
# min    428.203635
# 25%    514.647461
# 50%    574.274871
# 75%    650.422737
# max    814.931986

# %% [markdown]
# The second stage of FM IV regression (estimate factor risk premiums)

# %%
all_lambdas_IV = []
all_resids_IV = []
# i is time

m_sim_SR_tmp_T = m_sim_SR.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
resids = []
index_times = list(m_sim_SR_tmp_T.columns)

for k in tqdm(m_sim_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)
    
    iv = IV2SLS(endog = m_sim_SR_tmp_T.loc[:,k].values,exog = sm.add_constant(all_betas_ev[i].values.astype(np.float64)),\
                instrument = sm.add_constant(all_betas_iv[i].values.astype(np.float64)))
    res = iv.fit()
    l = list(res.params)
    r = list(res.resid)
    lambdas.append(l)
    resids.append(r)

all_lambdas_IV.append(pd.DataFrame(lambdas))
all_resids_IV.append(pd.DataFrame(resids))
# Out:
# 0it [00:00, ?it/s]

# %%
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:              dependent   R-squared:                     -0.0059
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.0079
# No. Observations:                 500   F-statistic:                    0.4106
# Date:                Sun, May 01 2022   P-value (F-stat)                0.5217
# Time:                        03:25:06   Distribution:                  chi2(1)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# exog           0.0166     0.0125     1.3255     0.1850     -0.0079      0.0411
# endog          0.0268     0.0419     0.6408     0.5217     -0.0553      0.1090
# ==============================================================================
#
# Endogenous: endog
# Instruments: instruments
# Robust Covariance (Heteroskedastic)
# Debiased: False
# """

# %%
res.wu_hausman()
# Out:
# Wu-Hausman test of exogeneity
# H0: All endogenous variables are exogenous
# Statistic: 3.6856
# P-value: 0.0555
# Distributed: F(1,497)
# WaldTestStatistic, id: 0x7f98363f0be0

# %%
# This cell shows the second way to conduct the IV2SLS regression

# from statsmodels.sandbox.regression.gmm import IV2SLS

# all_lambdas_IV = []
# all_resids_IV = []
# # i is time

# m_sim_SR_tmp_T = m_sim_SR.iloc[rollingW:rollingW+periods*holding,:].T

# lambdas = []
# resids = []
# index_times = list(m_sim_SR_tmp_T.columns)

# for k in tqdm(m_sim_SR_tmp_T.columns):
    
#     i = int(index_times.index(k) / holding)
    
#     iv = IV2SLS(endog = m_sim_SR_tmp_T.loc[:,k].values,exog = sm.add_constant(all_betas_ev[i].values.astype(np.float64)),\
#                 instrument = sm.add_constant(all_betas_iv[i].values.astype(np.float64)))
# #     iv = IV2SLS(endog = m_sim_SR_tmp_T.loc[:,k].values,exog = all_betas_ev[i].values.astype(np.float64),instrument = all_betas_iv[i].values.astype(np.float))
#     res = iv.fit()
#     l = list(res.params)
#     r = list(res.resid)
#     lambdas.append(l)
#     resids.append(r)

# all_lambdas_IV.append(pd.DataFrame(lambdas))
# all_resids_IV.append(pd.DataFrame(resids))

# %%
# # This cell shows the way of using the IV estimator equation to estimate risk premiums
# lam = []
# for i in range(periods):
#     a = np.dot(np.array(all_betas_iv[i]).T,np.array(all_betas_ev[i]))
#     b = np.dot(np.array(all_betas_iv[i]).T, np.array(m_sim_SR_tmp_T.iloc[:,i]))
#     l = np.linalg.inv(a)*b
#     lam.append(l)

# %%
# The following are residual returns
all_resids_IV = pd.DataFrame(all_resids_IV[0].T)
all_resids_IV
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.011968 -0.045954  0.165013 -0.081354 -0.143066 -0.049678 -0.007919
# 1    0.056413 -0.149095 -0.002643  0.014416 -0.147484 -0.212883  0.172971
# 2    0.101968 -0.019614  0.050583  0.057604  0.096128  0.082805  0.026550
# 3    0.022697  0.024416 -0.011421  0.020893 -0.006414  0.033212 -0.032481
# 4    0.003378 -0.002402 -0.010171  0.006422 -0.070707  0.038078 -0.010560
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.029264 -0.027942 -0.278801  0.244330  0.084130 -0.279830 -0.006482
# 496  0.167554 -0.123627  0.172655 -0.072909  0.153269 -0.025085 -0.293306
# 497 -0.027277  0.020893  0.026285  0.001458 -0.068361  0.021600  0.037247
# 498 -0.179710  0.055606  0.085782  0.059804 -0.154937 -0.021129 -0.116460
# 499  0.115489  0.037293 -0.072814 -0.115550  0.320778 -0.067960  0.042794
#
#           7         8         9    ...       201       202       203  \
# 0   -0.121120  0.018058  0.089109  ... -0.036643  0.033860  0.041697
# 1   -0.140210 -0.170004  0.015273  ...  0.195446 -0.081865 -0.142008
# 2    0.034792  0.073629  0.071389  ...  0.026804 -0.049325 -0.028582
# 3    0.031858 -0.020498 -0.027813  ...  0.010555  0.031547 -0.022531
# 4    0.011769 -0.054802 -0.018662  ...  0.056570 -0.010438  0.026975
# ..        ...       ...       ...  ...       ...       ...       ...
# 495 -0.044980  0.160061 -0.313512  ... -0.094314  0.209201 -0.109981
# 496  0.207358 -0.143534 -0.355796  ...  0.047387  0.142521  0.067741
# 497 -0.193088  0.046473  0.024569  ... -0.034482  0.089643 -0.046684
# 498 -0.092472 -0.008181  0.110623  ...  0.055295 -0.083219 -0.012464
# 499  0.094064 -0.091600  0.069085  ... -0.032439 -0.117785  0.129963
#
#           204       205       206       207       208       209       210
# 0   -0.067102  0.035483  0.030564 -0.099868 -0.082684 -0.105660  0.049549
# 1   -0.151585 -0.108056 -0.076866  0.172662  0.110532 -0.189800 -0.012696
# 2    0.031924 -0.040660 -0.004888 -0.076644 -0.011798 -0.106476 -0.021489
# 3   -0.033397  0.001839 -0.007943 -0.038152 -0.042093 -0.044584 -0.041422
# 4    0.014592  0.087099 -0.012772 -0.003398  0.022894 -0.095212 -0.051780
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.294758 -0.147946 -0.196264  0.115258 -0.619576  0.151943 -0.202995
# 496 -0.232393  0.253691 -0.448820  0.159722 -0.320205  0.118541 -0.227014
# 497  0.050846  0.032142 -0.259677  0.102279 -0.000050 -0.054485  0.009838
# 498  0.053223  0.023892  0.121465 -0.097232  0.057651 -0.073639 -0.099229
# 499 -0.165229 -0.065334 -0.183599 -0.107475  0.091024 -0.034337 -0.040067
#
# [500 rows x 211 columns]

# %%
# # Plot the distrubtion of the residualS
# label = all_resids_IV.index
# index = all_resids_IV.columns

# # Get the shape of df_residuals
# shape = all_resids_IV.shape

# plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)

# for j in tqdm(range(shape[1])):
#     plt.plot(all_resids_IV.iloc[:,j],)  

# plt.title('The distrubtion of residuals')
# # plt.xticks(np.arange(min(label), max(label)+1, 12), fontsize = 6)
# plt.xticks([], [])
# plt.yticks(fontsize = 6)
# # plt.xlabel('Stock Labels', fontsize = 10)
# plt.ylabel('Residuals', fontsize = 10)
# plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5, axis='y')
# plt.tight_layout()
# plt.show()

# %%
## test whether beta_iv (instrumental betas) are exogenous
corr_iv_res = []

for i in range(np.shape(all_resids_IV)[1]):
    corr = stats.pearsonr(all_betas_iv[i].values.astype(np.float64).flatten(),all_resids_IV.iloc[:,i].values.astype(np.float64).flatten())[0]
    corr_iv_res.append(corr)

print('mean_Pho = ' + str(np.mean(corr_iv_res)), "IV is Endogenous" if np.mean(corr_iv_res).round(10)!=0 else "IV is Exogenous")
# Out:
# mean_Pho = 1.101981032754698e-17 IV is Exogenous

# %%
## test whether beta_ev (explanatory betas) is endogenous
corr_ev_res = []

for i in range(np.shape(all_resids_IV)[1]):
    corr = stats.pearsonr(all_betas_ev[i].values.astype(np.float64).flatten(),all_resids_IV.iloc[:,i].values.astype(np.float64).flatten())[0]
    corr_ev_res.append(corr) 
    
print('mean_Pho = ' + str(np.mean(corr_ev_res)), "EV is Endogenous" if np.mean(corr_ev_res).round(10)!=0 else "EV is Exogenous")
# Out:
# mean_Pho = 2.834623437213523e-05 EV is Endogenous

# %% [markdown]
# Weak instrument variable test

# %%
corr_ev_iv = []

for i in range(len(all_betas_ev)):
    corr = stats.pearsonr(all_betas_ev[i].values.astype(np.float64).flatten(),all_betas_iv[i].values.astype(np.float64).flatten())[0]
    corr_ev_iv.append(corr)
    
print('mean_Pho = ' + str(np.mean(corr_ev_iv)), "IV is Strong" if np.mean(corr_ev_iv)>0.5 and stats.ttest_1samp(corr_ev_iv, 0.0)[0] > 2 else "IV is Weak")
# Out:
# mean_Pho = 0.7330458573268488 IV is Strong

# %%
# the average correlations between estimated and simulated betas 

corr_ev_true = []

for i in range(len(all_betas_ev)):
    corr = stats.pearsonr(all_betas_ev[i].values.astype(np.float64).flatten(),sim_betas.iloc[0,:].values.astype(np.float64).flatten())[0]
    corr_ev_true.append(corr)

print('mean_Pho = ' + str(np.mean(corr_ev_true)), 'P-value =' + str(stats.ttest_1samp(corr_ev_true, 0.0)[0]))
# Out:
# mean_Pho = 0.846030079558426 P-value =760.0400670422879

# %%
# Print the intercept andrisk premium time-series
all_lambdas_IV[0].rename(columns={0:'Intercept',1:'MKT'})
# Out:
#      Intercept       MKT
# 0    -0.015458 -0.033831
# 1    -0.004376  0.014055
# 2    -0.004422 -0.014685
# 3     0.005265 -0.042696
# 4     0.018568 -0.016061
# ..         ...       ...
# 206   0.014503 -0.088496
# 207  -0.018967  0.014381
# 208  -0.005342  0.010197
# 209   0.034567 -0.101962
# 210   0.016567  0.026848
#
# [211 rows x 2 columns]

# %%
# Calculate the t-statistic of market risk premium under IV approach
stats.ttest_1samp(all_lambdas_IV[0], 0.0)[0]
# Out:
# array([-0.41449312,  0.59060925])

# %%
# Print the time-series mean of market risk premiums
print(np.mean(all_lambdas_IV[0].iloc[:,1]))
# Out:
# 0.0027837944588276218

# %%
print("ex-ante bias(%): " + str((np.mean(all_lambdas_IV[0].iloc[:,1]) - np.mean(m_MR.values))/(np.mean(m_MR.values))*100))
print("ex-post bias(%): " + str((np.mean(all_lambdas_IV[0].iloc[:,1]) - np.mean(m_sim_MKT.values))/np.mean(m_sim_MKT.values)*100))
# Out:
# ex-ante bias(%): -53.057657864333294
# ex-post bias(%): -0.9649197184982179

# %%
## Calculate the Ex-ante RMSE
diff = all_lambdas_IV[0].iloc[:,1]-np.array(m_MR_tmp).flatten()
np.sqrt((diff**2).mean())
# Out:
# 0.08881783816435111

# %%
## Calculate the Ex-post RMSE
diff = all_lambdas_IV[0].iloc[:,1]-np.array(m_sim_MKT_tmp).flatten()
np.sqrt((diff**2).mean())
# Out:
# 0.0826762894003786

# %% [markdown]
# ### Plot the Bias of OLS/IV Estimator (South African Sample)

# %%
## The average of 100 times repetitions
## OLS Estimator Bias and RMSE
## n=1,2,3,5
## ex-ante biases: -27.1393, -20.4629, -12.2368, -2.3749
## ex-post biases: -26.1879, -19.7896, -11.8769, -1.8976

# %%
## IV Estimator Bias and RMSE
## n=1,2,3,5
## ex-ante biases: -16.5125, -11.8083, -6.7241, 2.5237
## ex-post biases: -15.7312, -10.9876, -5.8921, 1.6542

# %%
ea_1 = np.array([-27.1393, -20.4629, -12.2368, -2.3749], dtype = np.float64)
ea_2 = np.array([-16.5125, -11.8083, -6.7241, 2.5237], dtype = np.float64)
ep_1 = np.array([-26.1879, -19.7896, -11.8769, -1.8976], dtype = np.float64)
ep_2 = np.array([-15.7312, -10.9876, -5.8921, 1.6542], dtype = np.float64)
days = np.array([252, 252*2, 252*3, 252*5], dtype = np.float64)

# %%
plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
plt.plot(days, ea_1, linestyle='dashed', marker='o', markerfacecolor='pink', markersize= 5, color='pink', linewidth=3, label = "OLS(ex-ante)")
plt.plot(days, ea_2, marker='D', markerfacecolor='skyblue', markersize= 5, color='skyblue', linewidth=3, label = "IV(ex-ante)")
plt.plot(days, ep_1, linestyle='dashed', marker='h', markerfacecolor='cyan', markersize= 5, color='cyan', linewidth=3, label = "OLS(ex-post)")
plt.plot(days, ep_2, marker='p', markerfacecolor='palegreen', markersize= 5, color='palegreen', linewidth=3, label = "IV(ex-post)")
plt.xlabel('Number of Days to Estimate Betas', fontsize=8)
plt.ylabel('Bias (%)', fontsize=10)
plt. xticks(fontsize=8)
plt. yticks(fontsize=8)
# plt.title('Figuer1: Biases versus Number of Days Used to Estimate Betas', fontsize=10)
plt.legend(loc='lower right', fontsize = 'x-small')
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# Simulation results suggest that using the IV approach in the second stage of FM regression does not outperform the original OLS method. It will therefore be necessary to determine whether this problem is caused by a small sample size in the simulation (N=500, T=5215). This study uses the parameter from Jegadeesh et al. (2019) and then expands the simulation sample size to the same scale as theirs (N=2000, T=14363).

# %% [markdown]
# ## Jegadeesh et al. (2019) Sample

# %% [markdown]
# ### Import the simulation parameters from Jegadeesh et al. (2019)

# %%
# Import the mean and standard deviation of market factor return
mean_MKT = 5.80/100/252
sd_MKT = 15.33/100/np.sqrt(252)
print(mean_MKT, sd_MKT)
# Out:
# 0.00023015873015873014 0.009656992285385755

# %%
# Import the mean and standard deviation of market betas
m_all_betas = 0.95
sd_all_betas = 0.42
print(m_all_betas, sd_all_betas)
# Out:
# 0.95 0.42

# %%
# Import the standard deviation of residual returns 
m_all_sigmas = 58.73/100/252
sd_all_sigmas = 23.81/100/np.sqrt(252)
print(m_all_sigmas, sd_all_sigmas)
# Out:
# 0.0023305555555555553 0.014998890170582832

# %% [markdown]
# ### Simualted betas and sigmas are fixed through 100 repetitions

# %% [markdown]
# The betas and sigmas are generated at the begining of each simulation and keep them constant

# %%
# How many stocks in the simulation sample on cross-section 
N = 2000

# %%
# How many days in the simulation sample on time-series
T = 684 * 21

# %%
# Beta simulation 
sim_betas_tmp = []
sim_betas_tmp.append(np.random.normal(loc = m_all_betas,scale = sd_all_betas, size= N ))
print(np.mean(sim_betas_tmp), np.std(sim_betas_tmp))
# Out:
# 0.9516675638810237 0.42155901813931534

# %%
# Print simulated betas
sim_betas = pd.DataFrame(sim_betas_tmp)
# sim_betas = sim_betas.iloc[sim_betas.index.repeat(len(df_Ex_SR)),:]
# sim_betas = sim_betas.reset_index(drop = True)
sim_betas
# Out:
#        0        1         2         3         4        5         6     \
# 0  0.757209  1.86593  0.706481  1.642439  1.413805  1.68968  0.853805
#
#        7         8         9     ...      1990      1991      1992      1993  \
# 0  0.757774  1.090586  0.165504  ...  0.998313  0.471678  0.989467  0.665329
#
#        1994      1995      1996      1997      1998      1999
# 0  0.141065  0.787905  1.356064  0.867802  2.204505  0.423642
#
# [1 rows x 2000 columns]

# %%
# Residual sigmas simulation
sim_sigmas_tmp = []
sim_sigmas_tmp.append(np.random.normal(loc = m_all_sigmas,scale = sd_all_sigmas, size= N ))
np.mean(sim_sigmas_tmp), np.std(sim_sigmas_tmp)
# Out:
# (0.003118337924304358, 0.015775986405036066)

# %%
# Print simulated the standard deviation of residuals
sim_sig_res = pd.DataFrame(sim_sigmas_tmp).abs()
sim_sig_res
# Out:
#        0         1         2         3         4         5        6     \
# 0  0.002901  0.000493  0.016507  0.007319  0.012458  0.005933  0.00108
#
#        7         8         9     ...      1990      1991      1992      1993  \
# 0  0.013141  0.015962  0.006067  ...  0.018909  0.006068  0.005309  0.014013
#
#        1994      1995      1996      1997     1998      1999
# 0  0.020371  0.012717  0.001223  0.001201  0.01315  0.002235
#
# [1 rows x 2000 columns]

# %%
## sum negative values in sim_sig_res
sim_sig_res.values.flatten()
sum(n < 0 for n in sim_sig_res.values.flatten())
# Out:
# 0

# %% [markdown]
# ### Simulated market, stock and residual returns are changable through 100 repetitions

# %% [markdown]
# Step-2: For each day, we randomly draw market excess return from a normal distribution with mean and standard deviation equal to the sample mean and standard deviation from the data

# %%
# market excess return simulation
sim_MKT_tmp = []
sim_MKT_tmp.append(np.random.normal(loc = mean_MKT,scale = sd_MKT, size= T))
print(np.mean(sim_MKT_tmp), np.std(sim_MKT_tmp))
# Out:
# 0.00031346945868116697 0.00971641184988084

# %%
# Print simulated market returns
sim_MKT = pd.DataFrame(sim_MKT_tmp).T
sim_MKT.index = pd.date_range(start=df_MR.index[0], periods = T, freq='D').astype(str)
sim_MKT.columns = ['RM-RF']
sim_MKT
# Out:
#                RM-RF
# 2000-01-05  0.001574
# 2000-01-06 -0.004080
# 2000-01-07  0.003753
# 2000-01-08 -0.016923
# 2000-01-09 -0.000719
# ...              ...
# 2039-04-29 -0.001346
# 2039-04-30 -0.002618
# 2039-05-01  0.004811
# 2039-05-02 -0.014839
# 2039-05-03  0.000488
#
# [14364 rows x 1 columns]

# %% [markdown]
# Step-3: For each stock, we then randomly generate daily residual return from a normal distribution with mean zero and standard deviation equal to the value generate in step-1, i.e. sim_sigmas

# %%
# Residual returns simulation
res_return = pd.DataFrame(np.zeros((len(sim_MKT), len(sim_sig_res.columns))))
for j in range(len(sim_sig_res.columns)):
    res_return.iloc[:,j] = np.random.normal(loc = 0,scale = sim_sig_res[j], size= len(sim_MKT))
res_return
# Out:
#            0         1         2         3         4         5         6     \
# 0     -0.003441 -0.000159 -0.005337 -0.004508 -0.012879 -0.003176  0.000551
# 1      0.000482 -0.000230  0.028357  0.013734  0.008052 -0.007944  0.001411
# 2      0.003043 -0.000031 -0.009897  0.008741  0.010607 -0.000921  0.000909
# 3      0.003845 -0.000432 -0.004195  0.002575 -0.006447 -0.005824 -0.000247
# 4      0.004700  0.000135 -0.002986  0.004750 -0.006337 -0.006055 -0.000583
# ...         ...       ...       ...       ...       ...       ...       ...
# 14359 -0.001673 -0.000044 -0.031492 -0.002480  0.008757 -0.005950 -0.000427
# 14360  0.001134  0.000974 -0.005830  0.013634  0.018359  0.000507  0.000528
# 14361  0.001123 -0.000398  0.005037  0.004764  0.006721 -0.000472 -0.001140
# 14362 -0.006213 -0.000232 -0.010958  0.007915  0.005949 -0.001053  0.000126
# 14363  0.002833 -0.000052  0.029448 -0.004760 -0.000327 -0.007414  0.000270
#
#            7         8         9     ...      1990      1991      1992  \
# 0      0.006892 -0.001284 -0.008146  ... -0.002490  0.014865 -0.001548
# 1     -0.008916  0.004614 -0.005076  ... -0.009844  0.004297 -0.008477
# 2      0.000393  0.004830  0.009000  ...  0.063808  0.002215 -0.006519
# 3     -0.002727  0.006391 -0.001711  ... -0.006318 -0.004596  0.004127
# 4     -0.007479  0.000708 -0.008242  ...  0.017771 -0.004380  0.004979
# ...         ...       ...       ...  ...       ...       ...       ...
# 14359 -0.026608 -0.020676  0.004532  ... -0.007245 -0.001490 -0.005845
# 14360  0.011881  0.018738  0.000775  ... -0.004884 -0.001675  0.007470
# 14361 -0.012743  0.011067 -0.001830  ...  0.010828 -0.001627 -0.006062
# 14362  0.027452  0.010310 -0.001374  ... -0.015600  0.007152 -0.007921
# 14363 -0.007283  0.013788  0.001700  ... -0.022461  0.009456  0.004344
#
#            1993      1994      1995      1996      1997      1998      1999
# 0      0.005838  0.007184  0.013705  0.000785  0.002295  0.013032  0.001251
# 1      0.017515 -0.022575 -0.008388  0.000579  0.000571 -0.011526 -0.002811
# 2      0.015629  0.005174  0.038945  0.000320 -0.000528 -0.023932 -0.000979
# 3     -0.014936 -0.011953 -0.004371 -0.001046  0.000738  0.005729  0.004482
# 4      0.023148  0.021367  0.000048 -0.000084  0.000337  0.006148 -0.000178
# ...         ...       ...       ...       ...       ...       ...       ...
# 14359 -0.012039  0.026435 -0.004812  0.001902  0.000906  0.011272 -0.001436
# 14360 -0.007025  0.023973  0.011524 -0.003028 -0.001002  0.009346 -0.003039
# 14361 -0.006075 -0.009676  0.010000 -0.000115 -0.000554 -0.007702  0.001986
# 14362 -0.012158  0.007435 -0.007309 -0.001793 -0.001518 -0.021005 -0.003805
# 14363  0.015836 -0.007931 -0.004062 -0.000197 -0.000338  0.000177 -0.001742
#
# [14364 rows x 2000 columns]

# %% [markdown]
# Step-4: For each stock i, we compute its excess return as beta,i*MKT,t + episiloni,,t

# %%
# Stock returns simulation
sim_SR = (np.mat(sim_MKT.iloc[:,0]).T*np.mat(sim_betas.iloc[0,:].values)) + res_return
sim_SR = pd.DataFrame(sim_SR)
sim_SR.index = pd.date_range(start=df_MR.index[0], periods = T, freq='D').astype(str)
sim_SR
# Out:
#                 0         1         2         3         4         5     \
# 2000-01-05 -0.002249  0.002778 -0.004225 -0.001922 -0.010653 -0.000516
# 2000-01-06 -0.002608 -0.007843  0.025475  0.007033  0.002283 -0.014837
# 2000-01-07  0.005884  0.006971 -0.007246  0.014904  0.015912  0.005419
# 2000-01-08 -0.008969 -0.032009 -0.016151 -0.025221 -0.030374 -0.034419
# 2000-01-09  0.004156 -0.001206 -0.003493  0.003570 -0.007353 -0.007270
# ...              ...       ...       ...       ...       ...       ...
# 2039-04-29 -0.002693 -0.002556 -0.032443 -0.004691  0.006854 -0.008224
# 2039-04-30 -0.000848 -0.003911 -0.007679  0.009335  0.014658 -0.003916
# 2039-05-01  0.004766  0.008578  0.008436  0.012665  0.013522  0.007657
# 2039-05-02 -0.017449 -0.027921 -0.021442 -0.016458 -0.015031 -0.026126
# 2039-05-03  0.003202  0.000859  0.029793 -0.003958  0.000363 -0.006589
#
#                 6         7         8         9     ...      1990      1991  \
# 2000-01-05  0.001895  0.008085  0.000433 -0.007886  ... -0.000919  0.015607
# 2000-01-06 -0.002073 -0.012007  0.000164 -0.005751  ... -0.013917  0.002373
# 2000-01-07  0.004113  0.003237  0.008922  0.009621  ...  0.067554  0.003985
# 2000-01-08 -0.014696 -0.015551 -0.012065 -0.004512  ... -0.023213 -0.012578
# 2000-01-09 -0.001197 -0.008024 -0.000075 -0.008361  ...  0.017054 -0.004719
# ...              ...       ...       ...       ...  ...       ...       ...
# 2039-04-29 -0.001577 -0.027628 -0.022144  0.004310  ... -0.008589 -0.002125
# 2039-04-30 -0.001707  0.009897  0.015883  0.000341  ... -0.007498 -0.002910
# 2039-05-01  0.002967 -0.009098  0.016313 -0.001034  ...  0.015631  0.000642
# 2039-05-02 -0.012544  0.016207 -0.005873 -0.003830  ... -0.030415  0.000153
# 2039-05-03  0.000687 -0.006913  0.014320  0.001781  ... -0.021973  0.009686
#
#                 1992      1993      1994      1995      1996      1997  \
# 2000-01-05  0.000010  0.006885  0.007406  0.014945  0.002920  0.003662
# 2000-01-06 -0.012514  0.014801 -0.023151 -0.011603 -0.004954 -0.002969
# 2000-01-07 -0.002806  0.018125  0.005703  0.041902  0.005409  0.002728
# 2000-01-08 -0.012618 -0.026195 -0.014340 -0.017705 -0.023995 -0.013948
# 2000-01-09  0.004268  0.022670  0.021266 -0.000518 -0.001058 -0.000287
# ...              ...       ...       ...       ...       ...       ...
# 2039-04-29 -0.007177 -0.012934  0.026245 -0.005873  0.000076 -0.000262
# 2039-04-30  0.004879 -0.008766  0.023604  0.009462 -0.006578 -0.003273
# 2039-05-01 -0.001302 -0.002875 -0.008998  0.013791  0.006409  0.003621
# 2039-05-02 -0.022604 -0.022032  0.005342 -0.019001 -0.021916 -0.014395
# 2039-05-03  0.004828  0.016161 -0.007863 -0.003677  0.000465  0.000086
#
#                 1998      1999
# 2000-01-05  0.016503  0.001918
# 2000-01-06 -0.020520 -0.004539
# 2000-01-07 -0.015660  0.000611
# 2000-01-08 -0.031578 -0.002688
# 2000-01-09  0.004564 -0.000483
# ...              ...       ...
# 2039-04-29  0.008305 -0.002006
# 2039-04-30  0.003575 -0.004148
# 2039-05-01  0.002904  0.004024
# 2039-05-02 -0.053718 -0.010092
# 2039-05-03  0.001253 -0.001535
#
# [14364 rows x 2000 columns]

# %%
# The study assumes 21 days per month, T = 252 days corresponds to one year
months = []
periods = int(len(sim_SR)/21)+1
mons = pd.date_range(start=sim_SR.index[0], periods = periods, freq='M').astype(str).str[:7]
for i in range(periods):
    m = mons[i]
    months.append(np.repeat(m,21))

# %%
## Sum daily stock returns to monthly returns
## They are addable because they are log returns
m_sim_SR = sim_SR
m_sim_SR['month'] = np.array(flatten(months)[0:len(sim_SR)], dtype = str)
m_sim_SR = m_sim_SR.groupby('month').sum()
sim_SR = sim_SR.drop(['month'], axis = 1)
m_sim_SR = m_sim_SR.iloc[:,:]
m_sim_SR
# Out:
#              0         1         2         3         4         5         6     \
# month
# 2000-01 -0.011179 -0.032615 -0.003326 -0.004701  0.004738 -0.028293 -0.015060
# 2000-02  0.004187 -0.040148 -0.004350 -0.031661 -0.050567 -0.006188 -0.018675
# 2000-03  0.024630  0.063883 -0.017477  0.038485  0.079477  0.000837  0.030279
# 2000-04 -0.017494 -0.031112 -0.020754 -0.006816 -0.090998 -0.058063 -0.012951
# 2000-05 -0.025277 -0.100246 -0.111791 -0.059649 -0.117209 -0.104448 -0.036941
# ...           ...       ...       ...       ...       ...       ...       ...
# 2056-08 -0.068386 -0.179689 -0.048849 -0.188328 -0.107532 -0.104912 -0.080801
# 2056-09  0.053683  0.089436 -0.000152  0.112811  0.136893  0.077701  0.037073
# 2056-10 -0.028783 -0.089271  0.071438 -0.102430 -0.084154 -0.081442 -0.040405
# 2056-11  0.001043 -0.027487 -0.103579 -0.024304 -0.018892 -0.023098 -0.006211
# 2056-12 -0.044106 -0.083111 -0.003466 -0.077479  0.080723 -0.075904 -0.041265
#
#              7         8         9     ...      1990      1991      1992  \
# month                                  ...
# 2000-01  0.136132  0.112477  0.033152  ...  0.065913 -0.043996 -0.088446
# 2000-02  0.018934  0.040088  0.000183  ... -0.080439 -0.000223 -0.015999
# 2000-03  0.000360  0.004860  0.042956  ... -0.026826  0.041141  0.024902
# 2000-04  0.020937 -0.049735 -0.025832  ...  0.051976  0.023297  0.001405
# 2000-05 -0.063071 -0.028728  0.022449  ...  0.097464 -0.041018 -0.059592
# ...           ...       ...       ...  ...       ...       ...       ...
# 2056-08 -0.032754 -0.085342 -0.019079  ... -0.183487 -0.017649 -0.091809
# 2056-09  0.045078  0.011054  0.029629  ...  0.039765  0.037953  0.053695
# 2056-10  0.035300 -0.013202  0.033150  ...  0.018315 -0.046446 -0.050650
# 2056-11  0.046567 -0.051514  0.012005  ...  0.040645 -0.041740  0.020513
# 2056-12 -0.060602  0.052361  0.023467  ... -0.100654  0.037887 -0.036211
#
#              1993      1994      1995      1996      1997      1998      1999
# month
# 2000-01  0.031921 -0.037111  0.017176 -0.016851 -0.011092 -0.123891 -0.012426
# 2000-02 -0.038048  0.045907 -0.060318 -0.033874 -0.023924 -0.018622  0.008057
# 2000-03  0.039108 -0.006291 -0.009175  0.051981  0.031849  0.069239  0.019718
# 2000-04 -0.043594  0.132923 -0.069318 -0.017041 -0.012929 -0.068988  0.000194
# 2000-05 -0.023587 -0.100685 -0.020175 -0.069125 -0.046306 -0.062060 -0.020834
# ...           ...       ...       ...       ...       ...       ...       ...
# 2056-08 -0.127528  0.132257 -0.101050 -0.128092 -0.091601 -0.269988 -0.027664
# 2056-09  0.048366  0.100570  0.046702  0.075674  0.037944  0.120800  0.027697
# 2056-10 -0.052594  0.011717 -0.010932 -0.065851 -0.051142 -0.128087  0.006026
# 2056-11  0.116401  0.024966  0.004968 -0.021756 -0.012761 -0.139058 -0.021495
# 2056-12 -0.094827  0.029058 -0.042482 -0.060013 -0.039132 -0.065843 -0.036130
#
# [684 rows x 2000 columns]

# %%
# Sum daily market factor returns to monthly returns
m_sim_MKT = sim_MKT
m_sim_MKT['month'] = np.array(flatten(months)[0:len(sim_SR)], dtype = str)
m_sim_MKT = m_sim_MKT.groupby('month').sum()
sim_MKT = sim_MKT.drop(['month'], axis = 1)
m_sim_MKT = m_sim_MKT.iloc[:,:]
m_sim_MKT
# Out:
#             RM-RF
# month
# 2000-01 -0.017116
# 2000-02 -0.022750
# 2000-03  0.034334
# 2000-04 -0.017848
# 2000-05 -0.052684
# ...           ...
# 2056-08 -0.097395
# 2056-09  0.048738
# 2056-10 -0.047831
# 2056-11 -0.015648
# 2056-12 -0.043349
#
# [684 rows x 1 columns]

# %% [markdown]
# ### FM-OLS (Constant Betas)

# %% [markdown]
# Try to run FM OLS (without rolling windows) to estimate risk premiums for simulated market factor. Use the factor model in the linearmodel module, however, this function does not allow for time-varying betas, so the FM two-step regression would yield the same results as cross-sectional regression.

# %%
from linearmodels.asset_pricing.model import LinearFactorModel
model_ols = LinearFactorModel(portfolios=sim_SR, factors= sim_MKT, risk_free = None)
res_ols = model_ols.fit()
res_ols.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                       LinearFactorModel Estimation Summary
# ================================================================================
# No. Test Portfolios:               2000   R-squared:                      0.2835
# No. Factors:                          1   J-statistic:                    2358.6
# No. Observations:                 14364   P-value                         0.0000
# Date:                  Sun, May 01 2022   Distribution:               chi2(1999)
# Time:                          03:25:44
# Cov. Estimator:                  robust
#
#                             Risk Premia Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# RM-RF          0.0003  8.113e-05     3.9285     0.0001      0.0002      0.0005
# ==============================================================================
#
# Covariance estimator:
# HeteroskedasticCovariance
# See full_summary for complete results
# """

# %%
# Print the time-series mean of Market factor premiums and its t-statistics.
print(res_ols.risk_premia.values, res_ols.risk_premia_tstats.values)
# Out:
# [0.00031872] [3.92852804]

# %%
# Print the ex-ante and ex-post biases 
print("ex-ante bias(%):" + str(((res_ols.risk_premia-mean_MKT)/mean_MKT*100).values))
print("ex-post bias(%):" + str(((res_ols.risk_premia-sim_MKT.mean())/sim_MKT.mean()*100).values))
# Out:
# ex-ante bias(%):[38.4791836]
# ex-post bias(%):[1.67559284]

# %% [markdown]
# ### FM-OLS (Time-varying Betas)

# %%
# how many years of the rolling estimation window
n = 3

# %%
# Define the length of rolling window and the rebalance frequency
holding = 21 # 1 month
rollingW = holding * n *12
lens = len(sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 647 756

# %% [markdown]
# Step-5: For the first-stage of FM-OLS regression in the simulation, we estimate betas using time series regression below

# %%
all_betas = []

for i in tqdm(range(periods)):

    sim_MKT_tmp = sim_MKT.iloc[i*holding:i*holding+rollingW,:]
    sim_SR_tmp = sim_SR.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []
    # j is cross-sectional stock name
    for j in sim_SR.columns:      
        OLS = sm.OLS(sim_SR_tmp.loc[:,j].values.astype(np.float64), sm.add_constant(sim_MKT_tmp.values.astype(np.float64)))
        res = OLS.fit()
        b = list(res.params)
        s = np.std(res.resid)
        betas.append(b)

    df_betas = pd.DataFrame(betas).rename(columns={0:'Intercepts',1:'MKT'})
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 647/647 [07:45<00:00,  1.39it/s]

# %%
# Print estimated betas and intercepts for one period
all_betas[0]
# Out:
#       Intercepts       MKT
# 0      -0.000104  0.767061
# 1      -0.000002  1.869800
# 2      -0.000133  0.739850
# 3      -0.000570  1.678634
# 4       0.000588  1.368819
# ...          ...       ...
# 1995    0.000310  0.795266
# 1996   -0.000025  1.356177
# 1997    0.000021  0.866850
# 1998    0.000028  2.228872
# 1999    0.000084  0.434172
#
# [2000 rows x 2 columns]

# %%
# Test the correlation between estimated betas and simulated betas
corr_betas_true = []

for i in range(len(all_betas)):
    corr = stats.pearsonr(all_betas[i].MKT.values.astype(np.float64).flatten(),sim_betas.iloc[0,:].values.astype(np.float64).flatten())[0]
    corr_betas_true.append(corr)

print(np.mean(corr_betas_true), stats.ttest_1samp(corr_betas_true, 0.0)[0])
# Out:
# 0.9898587453015959 35546.30560318547

# %%
# This cell redefine the daily regression to monthly regression
# by simple change the holding scale from "21 days" to "1 month"
holding = 1 # 1 month
rollingW = holding *n*12
lens = len(m_sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 647 36

# %%
all_lambdas_OLS = []
all_resids_OLS = []

m_sim_SR_tmp_T = m_sim_SR.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
resids = []
index_times = list(m_sim_SR_tmp_T.columns)

for k in tqdm(m_sim_SR_tmp_T.columns):   
    i = int(index_times.index(k)/holding)
    OLS = sm.OLS(m_sim_SR_tmp_T.loc[:,k], sm.add_constant(all_betas[i].loc[:,"MKT"].astype(np.float64)))
    res = OLS.fit()
    l = list(res.params)
    r = list(res.resid)
    lambdas.append(l)
    resids.append(r)
        
all_lambdas_OLS.append(pd.DataFrame(lambdas))
all_resids_OLS.append(pd.DataFrame(resids))
# Out:
# 100%|██████████| 647/647 [00:01<00:00, 539.73it/s]

# %%
# Print intercepts and market factor premiums for one period
all_lambdas_OLS[0].rename(columns={0:'Intercept',1:'MKT'})
# Out:
#      Intercept       MKT
# 0    -0.005247 -0.078951
# 1    -0.005983  0.013392
# 2     0.002108  0.009629
# 3     0.000729  0.035495
# 4     0.001507  0.047795
# ..         ...       ...
# 642   0.002927 -0.036500
# 643  -0.006166 -0.090424
# 644  -0.004428  0.054028
# 645   0.003559 -0.049164
# 646  -0.005020 -0.012471
#
# [647 rows x 2 columns]

# %%
# Print residuals
all_resids_OLS = pd.DataFrame(all_resids_OLS[0].T)
all_resids_OLS
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.022416 -0.006846  0.002157 -0.013613 -0.004451  0.000026 -0.001864
# 1    -0.001760 -0.004157 -0.001877 -0.004161  0.005531  0.000296 -0.005751
# 2     0.071893 -0.195286 -0.033549  0.023389  0.048190  0.112135 -0.060381
# 3     0.040850 -0.002865 -0.063713 -0.005336 -0.013870  0.021445  0.015672
# 4    -0.060288  0.077494  0.026967 -0.031218 -0.053769 -0.093513 -0.048712
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -0.089158  0.052192  0.003288  0.104926 -0.033526  0.034334 -0.011381
# 1996 -0.003117 -0.004489 -0.005322  0.001176  0.004214  0.006149 -0.012960
# 1997  0.000023  0.005656 -0.000032 -0.001308  0.010574  0.004442  0.002167
# 1998  0.055709  0.009625  0.001015  0.036917  0.035468 -0.045715  0.039200
# 1999  0.014393  0.011634  0.000247  0.002734 -0.013243  0.000766  0.004624
#
#            7         8         9    ...       637       638       639  \
# 0     0.015111  0.026456  0.009748  ... -0.002939  0.002377  0.016589
# 1    -0.002016  0.003578  0.002828  ... -0.000797  0.005553  0.002552
# 2    -0.074576 -0.041314 -0.063668  ...  0.033105  0.009247 -0.027340
# 3    -0.010566  0.025861  0.004206  ...  0.028841  0.004381 -0.020998
# 4     0.041576  0.029268 -0.010055  ...  0.061342 -0.124013  0.095676
# ...        ...       ...       ...  ...       ...       ...       ...
# 1995 -0.119470  0.063108 -0.047298  ...  0.004563 -0.150399 -0.033713
# 1996 -0.003151 -0.009750 -0.000408  ...  0.002152  0.008842 -0.002682
# 1997  0.003027  0.008208  0.001586  ... -0.008378  0.007647  0.002131
# 1998  0.017700  0.021974 -0.030187  ... -0.044575  0.064628 -0.061296
# 1999 -0.005391  0.008301 -0.004338  ... -0.020947 -0.013443 -0.005973
#
#            640       641       642       643       644       645       646
# 0     0.019353  0.009911  0.009474  0.005532  0.017579  0.004528  0.015447
# 1     0.002712 -0.010878  0.000559 -0.004847 -0.006908 -0.001165  0.000786
# 2    -0.097005 -0.094922  0.056233  0.026091 -0.037446  0.105620 -0.089265
# 3    -0.027426 -0.005857 -0.042681 -0.031057  0.026897 -0.023881  0.001590
# 4    -0.016812  0.129959 -0.083262  0.023763  0.066849 -0.020023  0.003428
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.013725  0.008882 -0.022461 -0.024086  0.008987  0.023284  0.019650
# 1996  0.006601 -0.012551  0.001725  0.000970  0.006810 -0.002724  0.000163
# 1997 -0.008986  0.006776 -0.007646 -0.006232 -0.004938 -0.011587  0.003199
# 1998 -0.042075 -0.004481 -0.012354 -0.055387  0.000342 -0.018053 -0.105142
# 1999 -0.008334  0.023879 -0.016596  0.017437  0.008815  0.023791 -0.011124
#
# [2000 rows x 647 columns]

# %%
# Calculate the t-statistics of intercepts and factor premiums
stats.ttest_1samp(all_lambdas_OLS[0], 0.0)[0]
# Out:
# array([1.85299726, 4.21508752])

# %%
## Newey-West t-test for market risk premiums
all_lambdas_OLS[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([1.14440558, 2.608085  ])

# %%
# Print the mean of market risk premiums
print(np.mean(all_lambdas_OLS[0].iloc[:,1]))
# Out:
# 0.007261117779693281

# %%
# Print the ex-ante and ex-post biases for FM-OLS regression
print("ex-ante bias(%): " + str((np.mean(all_lambdas_OLS[0].iloc[:,1]) - np.mean(mean_MKT*21))/(np.mean(mean_MKT*21))*100))
print("ex-post bias(%): " + str((np.mean(all_lambdas_OLS[0].iloc[:,1]) - np.mean(m_sim_MKT.values))/np.mean(m_sim_MKT.values)*100))
# Out:
# ex-ante bias(%): 50.23002302813687
# ex-post bias(%): 10.303413536184863

# %%
# Plot the distribution of market risk premiums
all_lambdas_OLS[0].iloc[:,1].plot(kind='density')
all_lambdas_OLS[0].iloc[:,1].hist()
plt.show()

# %% [markdown]
# ### FM-IV (Time-varying Betas)

# %%
# Define the length of rolling window and rebalance frequency
holding = 21
rollingW = holding * n *12
lens = len(sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(rollingW, periods)
# Out:
# 756 647

# %%
# This cell estimates the explanatory betas and instrumental betas
# These betas will be further used as explanatory variables and instrumental
# variabnles in the second stage to estimate risk premiums of market factor

all_betas_ev = []
all_betas_iv = []


for i in tqdm(range(periods)):

    sim_MKT_tmp = sim_MKT.iloc[i*holding:i*holding+rollingW,:]
    sim_SR_tmp = sim_SR.iloc[i*holding:i*holding+rollingW,:]
    
    # if the current month i is even-month
    if (i + 1) % 2 == 1:
        # extract all the even-month data within the rolling window into explanatory beta estimation
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []

        for j in sim_SR.columns:
            df_index = rw_odd.index
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev))
        all_betas_ev.append(df_betas_ev)
        # extract all the odd-month data within the rolling window into instrumental beta estimation
        rw_even = pd.DataFrame()         
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])
        
        betas_iv = []

        for j in sim_SR.columns:
            df_index = rw_even.index   
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_iv.append(b)      
        df_betas_iv = pd.DataFrame(np.array(betas_iv))
        all_betas_iv.append(df_betas_iv)

    # if the current month i is odd-month
    if (i + 1) % 2 == 0:
        # extract all the even-month data within the rolling window into instrumental beta estimation
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])

        betas_iv = []

        for j in sim_SR.columns:
            df_index = rw_odd.index   
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_iv.append(b)        
        df_betas_iv = pd.DataFrame(np.array(betas_iv))
        all_betas_iv.append(df_betas_iv)
        
        # extract all the odd-month data within the rolling window into explanatory beta estimation
        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,sim_MKT_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        for j in sim_SR.columns:
            df_index = rw_even.index         
            b = list(ols_model.fit(sim_MKT_tmp.loc[df_index,:].values, sim_SR_tmp.loc[df_index,j].values).coef_)
            betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev))
        all_betas_ev.append(df_betas_ev)
# Out:
# 100%|██████████| 647/647 [27:04<00:00,  2.51s/it]

# %%
# Print all of the explanatory betas
all_betas_ev[0]
# Out:
#              0
# 0     0.738804
# 1     1.869217
# 2     0.684306
# 3     1.746698
# 4     1.412203
# ...        ...
# 1995  0.882327
# 1996  1.356952
# 1997  0.863331
# 1998  2.210747
# 1999  0.424296
#
# [2000 rows x 1 columns]

# %%
# Print all of the instrumental betas
all_betas_iv[0]
# Out:
#              0
# 0     0.795493
# 1     1.870190
# 2     0.791984
# 3     1.610955
# 4     1.334154
# ...        ...
# 1995  0.718717
# 1996  1.356157
# 1997  0.869875
# 1998  2.247714
# 1999  0.443702
#
# [2000 rows x 1 columns]

# %% [markdown]
# ### Correlation between iv_errors and ev_errors

# %% [markdown]
# In Jegadeesh et al. (2019), they argue that the IV estimator that they adopt is nearly unbiased and N-consistent, however, we cannot find such attractive property in this study. After reading through econometrics papers that also used IV approach, we double the problem of the puzzling result is due to the time-series correlation of measurement errors. Such an issue happens very often when using lagged exdogenous variables as instrumental variables to solve the endogeneity problem (like EIV problem).  Regardless of sample size, the autocorrelation of measurement errors would cause the IV estimation to be inconsistent.

# %%
# Run this cell to randomly test the covariance of the measurement errors of explanatory and instrumental variables
# If the covariance value is not equal to 0, then there is autocorrelation in the
# measurement errors. As such, the risk premium estimation will be significantly biased and inconsistent.
h = np.random.randint(0,len(all_betas_ev))
print(h)
beta_err_ev = all_betas_ev[h].values - sim_betas.T.values
beta_err_iv = all_betas_iv[h].values - sim_betas.T.values
np.cov(beta_err_ev.flatten(), beta_err_iv.flatten())[0,1]
# Out:
# 294
# -0.00013343687177190457

# %%
# This cell calculates the correlation coefficeints of the measurement errors of explanatory and instrumental variables
corr_errs = []
for i in range(periods):
    beta_err_ev = all_betas_ev[i].values - sim_betas.T.values
    beta_err_iv = all_betas_iv[i].values - sim_betas.T.values
    corr = stats.pearsonr(beta_err_ev.flatten(), beta_err_iv.flatten())[0]
    corr_errs.append(corr)

# %%
# If the average correlation coefficient is not equal to zero, then there is autocorrelation in the measurement errors
pd.DataFrame(corr_errs).describe()
# Out:
#                 0
# count  647.000000
# mean     0.011128
# std      0.039167
# min     -0.085778
# 25%     -0.015922
# 50%      0.010206
# 75%      0.039423
# max      0.110517

# %%
# Plot the distribution of the correlation coefficients of measurement erros
plt.plot(corr_errs)
plt.show()

# %%
# Define the length of rolling window and the rebalance frequency
holding = 1 # 1 month
rollingW = holding * n *12
lens = len(m_sim_MKT)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 647 36

# %%
# This cell uses a two-stage least squares regression to estimate market risk premium by
# using instrumental betas that estimated before as the instrumental variables

all_lambdas_IV = []
all_resids_IV = []

m_sim_SR_tmp_T = m_sim_SR.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
resids = []
index_times = list(m_sim_SR_tmp_T.columns)

for k in tqdm(m_sim_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)
    
    iv = IV2SLS(endog = m_sim_SR_tmp_T.loc[:,k].values,
                exog = sm.add_constant(all_betas_ev[i].values.astype(np.float64)),
                instrument = sm.add_constant(all_betas_iv[i].values.astype(np.float64)))
    
    res = iv.fit()
    l = list(res.params)
    r = list(res.resid)
    lambdas.append(l)
    resids.append(r)

all_lambdas_IV.append(pd.DataFrame(lambdas))
all_resids_IV.append(pd.DataFrame(resids))
# Out:
# 0it [00:00, ?it/s]

# %%
all_resids_IV = pd.DataFrame(all_resids_IV[0].T)
all_resids_IV
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.019523 -0.006585  0.002240 -0.012826 -0.003055 -0.000074 -0.002327
# 1     0.001458 -0.003750 -0.001095 -0.004193  0.004206 -0.000676 -0.004668
# 2     0.066656 -0.194815 -0.033590  0.023477  0.048309  0.112267 -0.060828
# 3     0.049062 -0.003397 -0.063659 -0.007499 -0.018258  0.021438  0.017093
# 4    -0.055186  0.077124  0.026980 -0.032548 -0.056388 -0.093416 -0.047869
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -0.082448  0.051078  0.002445  0.101989 -0.037498  0.035393 -0.010957
# 1996 -0.001571 -0.004341 -0.004988  0.001108  0.003576  0.005727 -0.012470
# 1997 -0.000484  0.005640 -0.000074 -0.001202  0.010869  0.004491  0.002034
# 1998  0.058728  0.010241  0.002052  0.036782  0.032978 -0.046909  0.040652
# 1999  0.011859  0.011511 -0.000109  0.003154 -0.011948  0.001173  0.003891
#
#            7         8         9    ...       637       638       639  \
# 0     0.013236  0.026796  0.010212  ... -0.003062  0.002367  0.016777
# 1     0.000218  0.002677  0.001476  ... -0.001680  0.005655  0.003135
# 2    -0.077976 -0.040748 -0.062797  ...  0.040057  0.008991 -0.034151
# 3    -0.005876  0.024734  0.002574  ...  0.025660  0.004539 -0.018007
# 4     0.043657  0.028657 -0.010852  ...  0.061092 -0.123948  0.097335
# ...        ...       ...       ...  ...       ...       ...       ...
# 1995 -0.116142  0.062827 -0.047646  ...  0.003205 -0.150384 -0.032763
# 1996 -0.002123 -0.010151 -0.001027  ...  0.001890  0.008882 -0.002594
# 1997  0.002514  0.008335  0.001774  ... -0.008484  0.007641  0.002103
# 1998  0.019546  0.020847 -0.032026  ... -0.049672  0.064904 -0.055804
# 1999 -0.007343  0.008919 -0.003438  ... -0.020761 -0.013492 -0.006125
#
#            640       641       642       643       644       645       646
# 0     0.019688  0.009805  0.009503  0.006240  0.017275  0.004712  0.015636
# 1     0.002062 -0.011922  0.002319 -0.003429 -0.008096  0.000221  0.000285
# 2    -0.099825 -0.089381  0.052122  0.018351 -0.032094  0.100446 -0.090041
# 3    -0.026991 -0.008241 -0.040069 -0.026712  0.024087 -0.021141  0.001538
# 4    -0.016370  0.127898 -0.080856  0.029945  0.062685 -0.016094  0.003836
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.014351  0.007935 -0.021775 -0.021025  0.007047  0.024476  0.020012
# 1996  0.006169 -0.012768  0.002359  0.001212  0.006381 -0.002202 -0.000066
# 1997 -0.008892  0.006792 -0.007762 -0.006227 -0.004928 -0.011569  0.003263
# 1998 -0.041015 -0.009820 -0.006635 -0.046427 -0.005181 -0.012610 -0.105170
# 1999 -0.007911  0.024431 -0.017542  0.016747  0.009460  0.023109 -0.010763
#
# [2000 rows x 647 columns]

# %%
## test whether beta_iv (instrumental betas) is exogenous
corr_iv_res = []

for i in range(np.shape(all_resids_IV)[1]):
    corr = stats.pearsonr(all_betas_iv[i].values.astype(np.float64).flatten(),all_resids_IV.iloc[:,i].values.astype(np.float64).flatten())[0]
    corr_iv_res.append(corr)

print("rho = " + str(np.mean(corr_iv_res)), "IV is Endogenous" if np.mean(corr_iv_res).round(10)!=0 else "IV is Exogenous")
# Out:
# rho = -1.3427181989914376e-17 IV is Exogenous

# %%
# test whether beta_ev (explanatory variables) is exogenous
corr_ev_res = []

for i in range(np.shape(all_resids_IV)[1]):
    corr = stats.pearsonr(all_betas_ev[i].values.astype(np.float64).flatten(),all_resids_IV.iloc[:,i].values.astype(np.float64).flatten())[0]
    corr_ev_res.append(corr) 
    
print("rho = " + str(np.mean(corr_ev_res)), "EV is Endogenous" if np.mean(corr_ev_res).round(10)!=0 else "EV is Exogenous")
# Out:
# rho = -0.001554171171553152 EV is Endogenous

# %%
# weak instrument variable test
corr_ev_iv = []

for i in range(len(all_betas_ev)):
    corr = stats.pearsonr(all_betas_ev[i].values.astype(np.float64).flatten(),all_betas_iv[i].values.astype(np.float64).flatten())[0]
    corr_ev_iv.append(corr)
    
print(np.mean(corr_ev_iv), "IV is Strong" if np.mean(corr_ev_iv)>0.5 and stats.ttest_1samp(corr_ev_iv, 0.0)[0] > 2 else "IV is Weak")
# Out:
# 0.9610225889252985 IV is Strong

# %%
# Print the factor premiums and intercepts
all_lambdas_IV[0].rename(columns={0:'Intercept',1:'MKT'})
# Out:
#      Intercept       MKT
# 0    -0.002018 -0.082425
# 1    -0.005552  0.012947
# 2     0.002920  0.008783
# 3     0.000711  0.035556
# 4     0.000206  0.049229
# ..         ...       ...
# 642   0.004584 -0.038299
# 643  -0.005170 -0.091634
# 644  -0.005364  0.055110
# 645   0.004758 -0.050516
# 646  -0.005591 -0.011889
#
# [647 rows x 2 columns]

# %%
# Print the t-statistics of intercept and market risk premium
stats.ttest_1samp(all_lambdas_IV[0], 0.0)[0]
# Out:
# array([1.11655389, 4.20362745])

# %%
# Summarized statistics of intercept and market risk premium
all_lambdas_IV[0].describe()
# Out:
#                 0           1
# count  647.000000  647.000000
# mean     0.000192    0.007389
# std      0.004383    0.044711
# min     -0.015023   -0.153175
# 25%     -0.002956   -0.020173
# 50%      0.000206    0.005356
# 75%      0.003182    0.035916
# max      0.013426    0.146612

# %%
print("ex-ante bias(%): " + str((np.mean(all_lambdas_IV[0].iloc[:,1]) - mean_MKT*21)/(mean_MKT*21)*100))
print("ex-post bias(%): " + str((np.mean(all_lambdas_IV[0].iloc[:,1]) - np.mean(m_sim_MKT.values))/np.mean(m_sim_MKT.values)*100))
# Out:
# ex-ante bias(%): 52.876691259398065
# ex-post bias(%): 12.246677169654511

# %% [markdown]
# ### Plot the Bias of OLS/IV Estimator (Jegadeesh et al. (2019) Sample)

# %%
ea_1 = np.array([-9.0037, -4.1658, -2.5595, -0.6091, 2.4610], dtype = np.float64)
ea_2 = np.array([-5.7519, -3.4048, -2.3114, -0.5500, 1.9114], dtype = np.float64)
ep_1 = np.array([-10.8707, -6.1321, -4.5588, -2.3624, 1.6327], dtype = np.float64)
ep_2 = np.array([-7.6857, -5.3868, -4.3158, -2.3044, 1.0795], dtype = np.float64)
days = np.array([252, 252*3, 252*5, 252*7, 252*10 ], dtype = np.float64)

# %%
plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
plt.plot(days, ea_1, linestyle='dashed', marker='o', markerfacecolor='pink', markersize= 5, color='pink', linewidth=3, label = "OLS(ex-ante)")
plt.plot(days, ea_2, marker='D', markerfacecolor='skyblue', markersize= 5, color='skyblue', linewidth=3, label = "IV(ex-ante)")
plt.plot(days, ep_1, linestyle='dashed', marker='h', markerfacecolor='cyan', markersize= 5, color='cyan', linewidth=3, label = "OLS(ex-post)")
plt.plot(days, ep_2, marker='p', markerfacecolor='palegreen', markersize= 5, color='palegreen', linewidth=3, label = "IV(ex-post)")
plt.xlabel('Number of Days to Estimate Betas', fontsize=8)
plt.ylabel('Bias (%)', fontsize=10)
plt.ylim((-45,5))
plt.xlim((0,3000))
plt. xticks(fontsize=8)
plt. yticks(fontsize=8)
# plt.title('Figuer1: Biases versus Number of Days Used to Estimate Betas', fontsize=10)
plt.legend(loc='lower right', fontsize = 'x-small')
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# # Empirical Results

# %% [markdown]
# This section employs the OLS and IV methods to estimate the premiums for risk factors proposed by prominent asset pricing models.

# %% [markdown]
# ## FM-OLS Regression (Time-Varying Betas)

# %% [markdown]
# This Section first tests whether the risk premiums under the CAPM and the FF3- and FF5-Factor Models are significantly different from zero using the OLS method with individual stocks. For the OLS tests, the regression is fitted with daily return data from month t-36 to month t-1 to estimate beta for month t.

# %% [markdown]
# ### CAPM Model

# %% [markdown]
# How many years in the rolling estimation window?

# %%
n = 3

# %% [markdown]
# Define the length of rolling window and rebalance frequency

# %%
holding = 21
rollingW = holding * n *12
lens = len(df_MR)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 211 756

# %% [markdown]
# This cell is the first stage of FM-OLS regression, which is used to estimate market betas by regressing stock returns on market factor returns

# %%
# Keep the stock returns has the same length as market returns
df_Ex_SR_trnct = df_Ex_SR.loc[df_MR.index,:]

all_betas = []

for i in tqdm(range(periods)):

    df_MR_tmp = df_MR.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []
    for j in df_Ex_SR.columns:
        df_index = df_Ex_SR_tmp.loc[:,j].dropna().index
        
        if len(df_index) > 10:
            b = list(ols_model.fit(df_MR_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
            b.append(j)
            betas.append(b)
    df_betas = pd.DataFrame(np.array(betas)).rename(columns={0:'MKT',1:'stock'}).set_index('stock')
    
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 211/211 [01:38<00:00,  2.13it/s]

# %%
# Print market betas for one period
all_betas[0]
# Out:
#                                 MKT
# stock
# ABC.SJ.Equity   0.06890337112683975
# ABI.SJ.Equity   0.23352855971285957
# ABR.SJ.Equity  -0.13818778126607012
# ACL.SJ.Equity     0.957051285238076
# ACP.SJ.Equity  -0.02694573125717277
# ...                             ...
# WTC.SJ.Equity     0.360477310787068
# YRK.SJ.Equity  -0.04329882197390028
# ZPT.SJ.Equity   0.19615208275356721
# ZRR.SJ.Equity    0.2535478802233808
# ZSA.SJ.Equity   0.04260893235310459
#
# [421 rows x 1 columns]

# %% [markdown]
# This cell is the second stage of FM-OLS regression, which aims to estimate market risk premiums

# %%
all_lambdas = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):
    # k is stock on cross-section
    i = int(index_times.index(k) / holding)
    # i is time in periods
    df_return = df_Ex_SR_tmp_T.loc[all_betas[i].index,k].dropna()
    df_index = df_return.index
    
    if len(df_index) != 0:
        ols = sm.OLS(df_return, sm.add_constant(all_betas[i].loc[df_index,:].astype(np.float64)))
        res = ols.fit()
        l = list(res.params)
        
        lambdas.append(l)
        
all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 4431/4431 [00:09<00:00, 453.12it/s]

# %%
# Print market risk premiums and intercepts
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT'})
# Out:
#       Intercept       MKT
# 0     -0.000307  0.007606
# 1      0.000293  0.004216
# 2      0.000881  0.005596
# 3     -0.000568  0.009103
# 4      0.002481 -0.013106
# ...         ...       ...
# 4426  -0.000153 -0.001191
# 4427   0.000078  0.003805
# 4428  -0.000666  0.011018
# 4429   0.000893  0.003637
# 4430  -0.001414 -0.012057
#
# [4431 rows x 2 columns]

# %%
# Print the time-series mean of market risk premiums and intercepts
print(np.mean(all_lambdas[0], axis = 0)*21*100)
# Out:
# 0   -0.245363
# 1    0.157725
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0], 0)
# Out:
# Ttest_1sampResult(statistic=array([-4.92741028,  0.45160346]), pvalue=array([8.63669385e-07, 6.51576783e-01]))

# %%
# Use the Newey-West t-test to examine market risk premiums and intercepts
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis = 0)
# Out:
# 0   -2.717779
# 1    0.268160
# dtype: float64

# %% [markdown]
# ### —Adding Control Variables

# %% [markdown]
# The significance of factor risk premium estimates may due to an omitted variable bias because the second-stage cross-sectional regressions do not control for corresponding firm charactersitics. For mitigating this potential bias, we add characteristics as control variables in the second stage.

# %%
# Keep the size and PE have the same length as stock returns
df_ln_Size_trnct = df_ln_Size.loc[df_Ex_SR_trnct.index,:]
df_PE_trnct = df_PE.loc[df_Ex_SR_trnct.index,:]

# %%
len(df_ln_Size_trnct)==len(df_PE_trnct)==len(df_Ex_SR_trnct)

# %%
# Stock returns are forward for 21 days compared to firm characteristics 
Gap = 21

# %%
# This cell represents the second stage of FM-OLS regression, which estimates the market risk premiums 
# by controlling for Size and PE characteristics.
all_lambdas = []
all_intercepts = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
intercepts = []
index_times = list(df_Ex_SR_tmp_T.columns)


for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
    # k is date t in len(df_Ex_SR_tmp) days
    i = int(index_times.index(k) / holding)
    # i is time T in 185 periods
    # df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan), the -inf in ln_Size data dataframe would interrupt the regression
    df_index = (((all_betas[i].index).intersection(df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index).\
                   intersection(df_PE_tmp_T.loc[:,k].dropna().index)).\
                    intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index))
    
    if len(df_index) != 0:
        
        l = list(ols_model.fit((pd.concat([all_betas[i].loc[df_index,:], \
                                           df_ln_Size_tmp_T.loc[df_index,k],\
                                           df_PE_tmp_T .loc[df_index,k]],axis = 1).values), \
                               (df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values)).coef_)
        
        h = ols_model.fit((pd.concat([all_betas[i].loc[df_index,:], \
                                      df_ln_Size_tmp_T.loc[df_index,k],\
                                      df_PE_tmp_T .loc[df_index,k]],axis = 1).values), \
                          (df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values)).intercept_
        
        lambdas.append(l)
        intercepts.append(h)
        
all_lambdas.append(pd.DataFrame(lambdas))
all_intercepts.append(pd.DataFrame(intercepts))
# Out:
# 100%|██████████| 4410/4410 [00:21<00:00, 201.34it/s]

# %%
# Print regression intercepts 
all_intercepts[0]
# Out:
#              0
# 0     0.005652
# 1    -0.008008
# 2     0.011105
# 3    -0.000321
# 4    -0.001798
# ...        ...
# 4405 -0.003185
# 4406 -0.002526
# 4407 -0.002783
# 4408  0.002012
# 4409 -0.001982
#
# [4410 rows x 1 columns]

# %%
# Print market risk premiums and the slope coefficients of characteristics
all_lambdas[0].rename(columns={0:'MKT',1:'Size',2:'PE'})
# Out:
#                MKT          Size            PE
# 0     4.760142e-03 -8.311793e-04  3.071736e-03
# 1    -1.749357e-02  1.587276e-03 -4.629646e-03
# 2     5.040778e-03 -1.800801e-03  1.327077e-04
# 3     5.885179e-35 -9.144830e-36 -1.331188e-36
# 4    -5.066241e-03  4.362579e-04 -1.391939e-03
# ...            ...           ...           ...
# 4405 -3.936111e-03  6.137074e-04  8.360527e-04
# 4406  4.720645e-03  2.455590e-04 -2.765701e-03
# 4407  9.944941e-03  2.467517e-04 -6.173282e-04
# 4408  6.320216e-03 -7.996539e-05 -1.068169e-03
# 4409 -1.246380e-02  8.766408e-05 -2.455022e-03
#
# [4410 rows x 3 columns]

# %%
# Print the mean of intercepts
np.mean(all_intercepts[0], axis = 0)*21*100
# Out:
# 0   -0.836576
# dtype: float64

# %%
# Print the mean of market risk premiums
np.mean(all_lambdas[0])*21*100
# Out:
# 0   -0.476476
# 1    0.108517
# 2   -0.506973
# dtype: float64

# %%
# Print the result of ordinary t-test
stats.ttest_1samp(all_intercepts[0], 0.0)[0]
# Out:
# array([-5.10928701])

# %%
# Print the result of ordinary t-test
stats.ttest_1samp(all_lambdas[0], 0.0)[0]
# Out:
# array([-1.23678645,  3.81995033, -8.47653173])

# %%
## Newey-West t-test
all_intercepts[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-3.71056021])

# %%
## Newey-West t-test
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.63526881,  2.51466733, -5.32471764])

# %% [markdown]
# ### FF3-Factor Model

# %%
# How many years in the rolling window
n = 3

# %%
holding = 21
rollingW = holding * n * 12
lens = len(df_FF3)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 189 756

# %% [markdown]
# This cell is the first stage of FM OLS regression under the FF3-Factor Model, which aims to estiamte intercepts and the betas of FF3-Factors

# %%
# Keep the excess stock returns and factor returns have the same length
df_Ex_SR_trnct = df_Ex_SR.loc[df_FF3.index,:]

all_betas = []

for i in tqdm(range(periods)):

    df_FF3_tmp = df_FF3.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []

    for j in df_Ex_SR.columns:
        df_index = df_Ex_SR_tmp.loc[:,j].dropna().index
        
        if len(df_index) != 0:
            b = list(ols_model.fit(df_FF3_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
            b.append(j)
            betas.append(b)
    df_betas = pd.DataFrame(np.array(betas)).rename(columns={0:'MKT',1:'SMB',2:'HML',3:'stock'}).set_index('stock')
    
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 189/189 [01:41<00:00,  1.86it/s]

# %%
# Print the estimated betas for one period
all_betas[0]
# Out:
#                                  MKT                    SMB  \
# stock
# ABC.SJ.Equity   -0.11886881746759886    -0.7129746357980258
# ABI.SJ.Equity    0.25783980152032315  -0.010324300961727153
# ABR.SJ.Equity   -0.21197460481696337      0.778388720466541
# ACL.SJ.Equity     0.9128206343490194     1.3235356352168206
# ACP.SJ.Equity   -0.03951329859901125  -0.061075408168753176
# ...                              ...                    ...
# WTC.SJ.Equity    0.07080044688134128   -0.13632567541626667
# YRK.SJ.Equity    -0.0700711207991542    -0.0839246623936035
# ZPT.SJ.Equity    0.07969652734074247    -0.9069146398011514
# ZRR.SJ.Equity     0.1554158589313682     1.3017774937158952
# ZSA.SJ.Equity  -0.006831970595371532    0.04700429894705574
#
#                                  HML
# stock
# ABC.SJ.Equity      0.875250891422741
# ABI.SJ.Equity  -0.010932559606184007
# ABR.SJ.Equity   -0.34772436567797277
# ACL.SJ.Equity  -0.024148286154124676
# ACP.SJ.Equity    0.14407439092975466
# ...                              ...
# WTC.SJ.Equity   -0.24204855792579677
# YRK.SJ.Equity    0.09238358790580153
# ZPT.SJ.Equity    -0.3695302740365012
# ZRR.SJ.Equity     -0.510526061162279
# ZSA.SJ.Equity   -0.03636169818982443
#
# [427 rows x 3 columns]

# %% [markdown]
# This cell is the second stage of FM OLS regression, which aims to
# estimate intercepts and the risk premiums of the FF3-Factor. It should be noted the regression is performed on a time-series scale

# %%
all_lambdas = []
all_intercepts = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
intercepts = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)

    df_return = df_Ex_SR_tmp_T.loc[all_betas[i].index,k].dropna()
    df_index = df_return.index
    
    if len(df_index) != 0:
        l = list(ols_model.fit(all_betas[i].loc[df_index,:].values, df_return.values).coef_)
        h = ols_model.fit(all_betas[i].loc[df_index,:].values, df_return.values).intercept_
        lambdas.append(l)
        intercepts.append(h)
        
all_lambdas.append(pd.DataFrame(lambdas))
all_intercepts.append(pd.DataFrame(intercepts))
# Out:
# 100%|██████████| 3969/3969 [00:09<00:00, 427.14it/s]

# %%
# Print all the risk premiums of FF3-Factor
all_lambdas[0].rename(columns={0:'MKT',1:'SMB',2:'HML'})
# Out:
#            MKT       SMB       HML
# 0     0.001955 -0.001143 -0.003918
# 1     0.007036 -0.003012  0.004084
# 2    -0.009969 -0.003361  0.010345
# 3     0.001255  0.009913  0.003711
# 4    -0.003232 -0.008978  0.007480
# ...        ...       ...       ...
# 3964  0.003332  0.003186  0.003091
# 3965 -0.004193  0.000156 -0.005368
# 3966  0.007471 -0.000180 -0.007915
# 3967 -0.006167  0.001530  0.004463
# 3968  0.007469  0.004266  0.005154
#
# [3969 rows x 3 columns]

# %%
# Print the time-series average of intercepts
np.mean(all_intercepts[0])*21*100
# Out:
# 0   -0.236118
# dtype: float64

# %%
# Print the time-series average of risk premiums
np.mean(all_lambdas[0], axis = 0)*21*100
# Out:
# 0    0.127375
# 1   -0.137505
# 2   -0.181974
# dtype: float64

# %%
# Print the ordinary t-statistics of intercepts
stats.ttest_1samp(all_intercepts[0], 0.0)
# Out:
# Ttest_1sampResult(statistic=array([-4.47615238]), pvalue=array([7.81334086e-06]))

# %%
# Print the ordinary t-statistics of factor premiums 
stats.ttest_1samp(all_lambdas[0], 0.0)
# Out:
# Ttest_1sampResult(statistic=array([ 0.35009464, -0.75340166, -0.83078615]), pvalue=array([0.72628626, 0.45125328, 0.40614443]))

# %%
## Newey-West t-test For FF3-Factor
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([ 0.20958544, -0.4890191 , -0.53965733])

# %% [markdown]
# ### —Adding Control Variables

# %%
# Keep the size and PE have the same length as stock returns
df_ln_Size_trnct = df_ln_Size.loc[df_Ex_SR_trnct.index,:]
df_PE_trnct = df_PE.loc[df_Ex_SR_trnct.index,:]

# %%
len(df_ln_Size_trnct)==len(df_PE_trnct)==len(df_Ex_SR_trnct)
# Out:
# True

# %%
# Stock returns are forward for 21 days compared to firm characteristics 
Gap = 21

# %% [markdown]
# This cell is the second stage of FM OLS regression under the FF3-Factor model and combined with the firm characteristics as control variables. This aim of this cell is to estimate factor premiums while controlling for omitted-variables bias

# %%
all_lambdas = []
all_intercepts = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
intercepts = []
index_times = list(df_Ex_SR_tmp_T.columns)


for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
    i = int(index_times.index(k) / holding)
    df_index = (((all_betas[i].index).intersection(df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index).\
                   intersection(df_PE_tmp_T.loc[:,k].dropna().index)).\
                    intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index))
    
    if len(df_index) != 0:
        
        l = list(ols_model.fit((pd.concat([all_betas[i].loc[df_index,:], \
                                           df_ln_Size_tmp_T.loc[df_index,k],\
                                           df_PE_tmp_T .loc[df_index,k]],axis = 1).values), \
                               (df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values)).coef_)
        
        h = ols_model.fit((pd.concat([all_betas[i].loc[df_index,:], \
                                      df_ln_Size_tmp_T.loc[df_index,k],\
                                      df_PE_tmp_T .loc[df_index,k]],axis = 1).values), \
                          (df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values)).intercept_
        
        lambdas.append(l)
        intercepts.append(h)
        
all_lambdas.append(pd.DataFrame(lambdas))
all_intercepts.append(pd.DataFrame(intercepts))
# Out:
# 100%|██████████| 3948/3948 [00:21<00:00, 180.71it/s]

# %%
# Print all the intercepts
all_intercepts[0]
# Out:
#              0
# 0     0.005349
# 1     0.002189
# 2    -0.000196
# 3    -0.005162
# 4     0.010692
# ...        ...
# 3943 -0.000163
# 3944 -0.005610
# 3945  0.002769
# 3946 -0.002609
# 3947 -0.001856
#
# [3948 rows x 1 columns]

# %%
# Print all the risk premiums of FF3-Factor and the slope coefficients of firm characteristics
all_lambdas[0].rename(columns={0:'MKT',1:'SMB',2:'HML',3:'Size',4:'PE'})
# Out:
#                MKT           SMB           HML          Size            PE
# 0    -2.443581e-04 -1.937027e-04  6.948444e-03 -4.906601e-04 -1.829970e-03
# 1     6.871871e-03  2.368441e-03 -1.242112e-03 -1.767504e-04 -8.429261e-05
# 2     2.250261e-35  5.350728e-37  3.274130e-36 -3.971912e-36 -2.386607e-36
# 3    -6.177709e-03  2.869045e-03  9.146289e-03  1.274442e-03 -2.933153e-03
# 4     2.332042e-03 -3.264629e-03  1.117515e-02 -1.267048e-03 -4.738028e-03
# ...            ...           ...           ...           ...           ...
# 3943  7.047222e-03  2.564455e-03  3.815938e-03 -1.968646e-04 -1.826724e-04
# 3944 -9.915025e-03  8.336589e-04 -5.430066e-03  6.397295e-04  5.142288e-04
# 3945  7.342885e-03  6.732022e-04 -5.291854e-03 -3.527892e-04  4.368102e-04
# 3946 -5.882946e-03  9.053062e-04  9.634557e-04  1.765721e-04 -2.647578e-03
# 3947  2.284432e-03  4.610209e-03  3.803141e-03  3.273391e-04  1.854042e-03
#
# [3948 rows x 5 columns]

# %%
# Print the time-series average of intercepts (pricing-errors)
np.mean(all_intercepts[0], axis = 0)*21*100
# Out:
# 0   -0.838874
# dtype: float64

# %%
# Print he time-series average of factor premiums 
np.mean(all_lambdas[0])*21*100
# Out:
# 0   -0.522847
# 1   -0.110273
# 2   -0.011830
# 3    0.115174
# 4   -0.524616
# dtype: float64

# %%
# Print the ordinary t-statistics of intercepts
stats.ttest_1samp(all_intercepts[0], 0.0)[0]
# Out:
# array([-5.05136515])

# %%
# Print the ordinary t-statistics of risk premiums
stats.ttest_1samp(all_lambdas[0], 0.0)[0]
# Out:
# array([-1.27323603, -0.53880233, -0.04703861,  3.98794607, -8.28487722])

# %%
## Newey-West t-statistics of factor premiums 
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.77371566, -0.3499228 , -0.03054106,  2.49733885, -5.22513133])

# %% [markdown]
# ### Carhart4-Factor Model

# %%
n = 3
holding = 21
rollingW = holding * n *12
lens = len(df_FF4)
periods = int((lens - rollingW) / holding) - 1

# %% [markdown]
# This cell is the first stage of FM OLS regression under the Carhart4-Factor Model, which aims to estiamte intercepts and the betas of Carhart4-Factors

# %%
# Keep the excess stock returns and factor returns have the same length
df_Ex_SR_trnct = df_Ex_SR.loc[df_FF4.index,:]

all_betas = []

for i in tqdm(range(periods)):

    df_FF4_tmp = df_FF4.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []

    for j in df_Ex_SR.columns:
        df_index = df_Ex_SR_tmp.loc[:,j].dropna().index
        
        if len(df_index) != 0:
            b = list(ols_model.fit(df_FF4_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
            b.append(j)
            betas.append(b)
    df_betas = pd.DataFrame(np.array(betas)).rename(columns={0:'MKT',1:'SMB',2:'HML',3:'WML',4:'stock'}).set_index('stock')
    
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 189/189 [01:38<00:00,  1.92it/s]

# %%
# Print the estimated betas for one period
all_betas[0]
# Out:
#                                  MKT                   SMB  \
# stock
# ABC.SJ.Equity   -0.11912824594681116   -0.7158135966449568
# ABI.SJ.Equity     0.2565406592736406  -0.02454098983150671
# ABR.SJ.Equity   -0.21782838888249048    0.7143299717167659
# ACL.SJ.Equity     0.9163624169149315    1.3622938396494353
# ACP.SJ.Equity   -0.03911198706166802  -0.05342373907668338
# ...                              ...                   ...
# WTC.SJ.Equity    0.06880709440199435  -0.15813920051641667
# YRK.SJ.Equity   -0.07113888790500746  -0.09560938188299126
# ZPT.SJ.Equity    0.07018070220958815   -1.0261899736829472
# ZRR.SJ.Equity     0.1534607993317428    1.2803830127645452
# ZSA.SJ.Equity  -0.006480417314083875   0.05085139393144171
#
#                                   HML                   WML
# stock
# ABC.SJ.Equity      0.8771803416462147   0.02946870859844191
# ABI.SJ.Equity  -0.0012704349782666977   0.14757070777909076
# ABR.SJ.Equity     -0.3041879543800899    0.6649364686134615
# ACL.SJ.Equity   -0.050489623789941485   -0.4023141895245076
# ACP.SJ.Equity       0.141827729168983  -0.03886119462193846
# ...                               ...                   ...
# WTC.SJ.Equity    -0.22722337605522291   0.22642665726679068
# YRK.SJ.Equity     0.10032490370604473   0.12128860250395175
# ZPT.SJ.Equity     -0.2824764496101648    1.2379726804295152
# ZRR.SJ.Equity     -0.4959856753386197   0.22207693545777155
# ZSA.SJ.Equity   -0.038976309196300664  -0.03993324570435006
#
# [427 rows x 4 columns]

# %% [markdown]
# This cell is the second stage of FM OLS regression, which aims to
# estimate intercepts and the risk premiums of the Carhart4-Factor. It should be noted that the regression is performed on a time-series scale

# %%
all_lambdas = []
all_intercepts = []

lambdas = []
intercepts = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)

    df_return = df_Ex_SR_tmp_T.loc[all_betas[i].index,k].dropna()
    df_index = df_return.index
    
    if len(df_index) != 0:
        l = list(ols_model.fit(all_betas[i].loc[df_index,:].values, df_return.values).coef_)
        h = ols_model.fit(all_betas[i].loc[df_index,:].values, df_return.values).intercept_
        lambdas.append(l)
        intercepts.append(h)
        
all_lambdas.append(pd.DataFrame(lambdas))
all_intercepts.append(pd.DataFrame(intercepts))
# Out:
# 100%|██████████| 3969/3969 [00:10<00:00, 367.28it/s]

# %%
# Print all the risk premiums of Carhart4-Factor
all_lambdas[0].rename(columns={0:'MKT',1:'SMB',2:'HML',3:'WML'})
# Out:
#                MKT           SMB           HML           WML             4
# 0    -2.443581e-04 -1.937027e-04  6.948444e-03 -4.906601e-04 -1.829970e-03
# 1     6.871871e-03  2.368441e-03 -1.242112e-03 -1.767504e-04 -8.429261e-05
# 2     2.250261e-35  5.350728e-37  3.274130e-36 -3.971912e-36 -2.386607e-36
# 3    -6.177709e-03  2.869045e-03  9.146289e-03  1.274442e-03 -2.933153e-03
# 4     2.332042e-03 -3.264629e-03  1.117515e-02 -1.267048e-03 -4.738028e-03
# ...            ...           ...           ...           ...           ...
# 3943  7.047222e-03  2.564455e-03  3.815938e-03 -1.968646e-04 -1.826724e-04
# 3944 -9.915025e-03  8.336589e-04 -5.430066e-03  6.397295e-04  5.142288e-04
# 3945  7.342885e-03  6.732022e-04 -5.291854e-03 -3.527892e-04  4.368102e-04
# 3946 -5.882946e-03  9.053062e-04  9.634557e-04  1.765721e-04 -2.647578e-03
# 3947  2.284432e-03  4.610209e-03  3.803141e-03  3.273391e-04  1.854042e-03
#
# [3948 rows x 5 columns]

# %%
# Print the time-series average of intercepts
np.mean(all_intercepts[0], axis = 0)*21*100
# Out:
# 0   -0.236261
# dtype: float64

# %%
# Print the time-series average of the risk premiums of Carhart4-Factor
np.mean(all_lambdas[0])*21*100
# Out:
# 0    0.121567
# 1   -0.098281
# 2   -0.248484
# 3    0.391282
# dtype: float64

# %%
stats.ttest_1samp(all_intercepts[0], 0.0)[0]
# Out:
# array([-4.50058507])

# %%
stats.ttest_1samp(all_lambdas[0], 0.0)[0]
# Out:
# array([ 0.3335853 , -0.5406387 , -1.13460925,  1.41726389])

# %%
## Newey-West t-test
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([ 0.19976031, -0.34924499, -0.73775458,  0.92569667])

# %% [markdown]
# ### FF5-Factor Model

# %%
# How many years in the rolling window
n = 3

# %%
holding = 21
rollingW = holding * n *12
lens = len(df_FF5)
periods = int((lens - rollingW) / holding) - 1
periods
# Out:
# 189

# %%
df_Ex_SR_trnct = df_Ex_SR.loc[df_FF5.index,:]

all_betas = []

for i in tqdm(range(periods)):

    df_FF5_tmp = df_FF5.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []

    for j in df_Ex_SR.columns:
        df_index = df_Ex_SR_tmp.loc[:,j].dropna().index
        
        if len(df_index) != 0:
            b = list(ols_model.fit(df_FF5_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
            b.append(j)
            betas.append(b)
            
    df_betas = pd.DataFrame(np.array(betas)).rename(columns={0:'MKT',1:'SMB',2:'HML',3:'RMW',4:'CMA',5:'stock'}).set_index('stock')    
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 189/189 [01:49<00:00,  1.72it/s]

# %%
all_betas[0]
# Out:
#                                   MKT                   SMB  \
# stock
# ABC.SJ.Equity    -0.12684314175843783   -0.4747666761772388
# ABI.SJ.Equity      0.2568059377395592  0.013582960066952803
# ABR.SJ.Equity    -0.20345491310869732    1.4536405780562263
# ACL.SJ.Equity      0.9172582003475669    1.4801805116834983
# ACP.SJ.Equity    -0.04278501334108567  -0.02231944821105888
# ...                               ...                   ...
# WTC.SJ.Equity     0.07144911622729312   -0.1758173153409281
# YRK.SJ.Equity    -0.06833335577077126  -0.10984197789850345
# ZPT.SJ.Equity      0.0894525745998114    -0.749087074199933
# ZRR.SJ.Equity     0.17509759346923093    1.2205346094481033
# ZSA.SJ.Equity  -0.0069811797658123715   0.04671695047592998
#
#                                  HML                    RMW  \
# stock
# ABC.SJ.Equity     0.9340936741121489      0.629364769541842
# ABI.SJ.Equity  -0.004555384126351262  0.0012329445968705206
# ABR.SJ.Equity   -0.29444796730080713     0.4699693131563349
# ACL.SJ.Equity  -0.016990196125848733    -0.0190039663277225
# ACP.SJ.Equity    0.15343313918459275   -0.06594424784471697
# ...                              ...                    ...
# WTC.SJ.Equity   -0.25078383483772393  -0.012935098781311063
# YRK.SJ.Equity    0.08154567245046475   0.017796460491906793
# ZPT.SJ.Equity    -0.3843523851471269   -0.14929578511987876
# ZRR.SJ.Equity    -0.6037710833603119  -0.009355592057283535
# ZSA.SJ.Equity  -0.034587984470292224  -0.027733080348995708
#
#                                 CMA
# stock
# ABC.SJ.Equity   0.06586391442173273
# ABI.SJ.Equity   0.07458054315664174
# ABR.SJ.Equity    -0.138600293501439
# ACL.SJ.Equity    0.2150234672803638
# ACP.SJ.Equity   0.09385929485194006
# ...                             ...
# WTC.SJ.Equity  -0.09924446984188118
# YRK.SJ.Equity  -0.15821319042337367
# ZPT.SJ.Equity    -0.584526876394319
# ZRR.SJ.Equity   -0.9114673836069638
# ZSA.SJ.Equity   0.04081003277310897
#
# [427 rows x 5 columns]

# %%
all_lambdas = []
all_intercepts = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
intercepts = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)

    df_return = df_Ex_SR_tmp_T.loc[all_betas[i].index,k].dropna()
    df_index = df_return.index
    
    if len(df_index) != 0:
        l = list(ols_model.fit(all_betas[i].loc[df_index,:].values, df_return.values).coef_)
        h = ols_model.fit(all_betas[i].loc[df_index,:].values, df_return.values).intercept_
        lambdas.append(l)
        intercepts.append(h)
        
all_lambdas.append(pd.DataFrame(lambdas))
all_intercepts.append(pd.DataFrame(intercepts))
# Out:
# 100%|██████████| 3969/3969 [00:12<00:00, 323.39it/s]

# %%
all_lambdas[0].rename(columns={0:'MKT',1:'SMB',2:'HML',3:'RMW',4:'CMA'})
# Out:
#            MKT       SMB       HML       RMW       CMA
# 0    -0.000381  0.004222 -0.007688 -0.001174  0.009319
# 1     0.004985 -0.002915  0.003290  0.000749 -0.011222
# 2    -0.008746 -0.015659  0.011880 -0.012019 -0.006924
# 3    -0.003722  0.014616  0.000693  0.000921 -0.000565
# 4    -0.006892 -0.005973  0.005879 -0.002973 -0.014842
# ...        ...       ...       ...       ...       ...
# 3964  0.003014  0.004512  0.002668 -0.007995 -0.001342
# 3965 -0.005252 -0.001686 -0.005987 -0.001229  0.011652
# 3966  0.008473 -0.001796 -0.006293  0.015537 -0.004169
# 3967 -0.005881 -0.000858  0.005454  0.007234 -0.000533
# 3968  0.006971  0.005211  0.004952 -0.004932  0.001123
#
# [3969 rows x 5 columns]

# %%
np.mean(all_intercepts[0], axis = 0)*21*100
# Out:
# 0   -0.231454
# dtype: float64

# %%
np.mean(all_lambdas[0])*21*100
# Out:
# 0    0.136948
# 1   -0.180271
# 2   -0.249565
# 3   -0.070606
# 4    0.031000
# dtype: float64

# %%
stats.ttest_1samp(all_intercepts[0], 0.0)[0]
# Out:
# array([-4.42786266])

# %%
stats.ttest_1samp(all_lambdas[0], 0.0)[0]
# Out:
# array([ 0.37484371, -0.94537521, -1.15067376, -0.30647434,  0.14281048])

# %%
all_intercepts[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-2.41650817])

# %%
## Newey-West t-test 
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([ 0.22492417, -0.61510588, -0.74646464, -0.19895197,  0.09305202])

# %% [markdown]
# ### —Adding Control Variables

# %%
df_OP_trnct = df_OP.loc[df_FF5.index,:]
df_INV_trnct = df_INV.loc[df_FF5.index,:]

# %%
len(df_ln_Size_trnct)==len(df_PE_trnct)==len(df_Ex_SR_trnct)==len(df_OP_trnct)==len(df_INV_trnct)==len(df_FF5)
# Out:
# True

# %%
Gap = 21

# %%
all_lambdas = []
all_intercepts = []


df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_OP_tmp_T = df_OP_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_INV_tmp_T = df_INV_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
intercepts = []
index_times = list(df_Ex_SR_tmp_T.columns)

# If Gap >0, the following should be 'for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):''
for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
    # k is time t in 3885 days
    i = int(index_times.index(k) / holding)
    # i is time T in 185 periods
    
    df_index = ((((all_betas[i].index).intersection(df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index).\
                 intersection(df_PE_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index)).\
                  intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index)).\
                   intersection(df_OP_tmp_T.loc[:,k].dropna().index)).\
                    intersection(df_INV_tmp_T.loc[:,k].dropna().index)
    
    if len(df_index) != 0:
        
        l = list(ols_model.fit((pd.concat([all_betas[i].loc[df_index,:], df_ln_Size_tmp_T.loc[df_index,k],\
                                           df_PE_tmp_T.loc[df_index,k], df_OP_tmp_T.loc[df_index,k],\
                                           df_INV_tmp_T.loc[df_index,k]],axis = 1).values), \
                               (df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values)).coef_)
        
        h = ols_model.fit((pd.concat([all_betas[i].loc[df_index,:], df_ln_Size_tmp_T.loc[df_index,k],\
                                           df_PE_tmp_T.loc[df_index,k], df_OP_tmp_T.loc[df_index,k],\
                                           df_INV_tmp_T.loc[df_index,k]],axis = 1).values), \
                               (df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values)).intercept_
        
        lambdas.append(l)
        intercepts.append(h)
        
all_lambdas.append(pd.DataFrame(lambdas))
all_intercepts.append(pd.DataFrame(intercepts))
# Out:
# 100%|██████████| 3948/3948 [00:32<00:00, 122.77it/s]

# %%
all_lambdas[0].rename(columns={0:'MKT',1:'SMB',2:'HML',3:'RMW',4:'CMA',5:'Size',6:'PE',7:'OP',8:'INV'})
# Out:
#            MKT       SMB       HML       RMW       CMA      Size        PE  \
# 0     0.003803 -0.004234  0.004522 -0.006366  0.004634 -0.001122 -0.000203
# 1     0.007574 -0.000852 -0.002914  0.000272 -0.002199 -0.000765 -0.001765
# 2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    -0.005724  0.001385  0.010815 -0.005783  0.008348  0.001585 -0.003001
# 4     0.010729 -0.011782  0.005250 -0.031956 -0.018611 -0.001423 -0.003307
# ...        ...       ...       ...       ...       ...       ...       ...
# 3943  0.006427  0.004787  0.002292 -0.010401 -0.000122 -0.000036 -0.000572
# 3944 -0.010068 -0.000716 -0.005093 -0.000179  0.009322  0.000583  0.000605
# 3945  0.008914 -0.003308 -0.003575  0.017496 -0.003012 -0.000465  0.000623
# 3946 -0.005389 -0.000352  0.001496  0.002851 -0.000085  0.000270 -0.002761
# 3947  0.002364  0.005896  0.002337 -0.006728 -0.000716  0.000348  0.001571
#
#             OP       INV
# 0     0.003908 -0.000636
# 1     0.001610 -0.004180
# 2     0.000000  0.000000
# 3     0.001137  0.001949
# 4    -0.000846  0.000576
# ...        ...       ...
# 3943  0.000199 -0.001150
# 3944 -0.000037 -0.000063
# 3945  0.000264 -0.000397
# 3946 -0.001076 -0.003189
# 3947  0.000460  0.000503
#
# [3948 rows x 9 columns]

# %%
np.mean(all_intercepts[0], axis = 0)*21*100
# Out:
# 0   -0.765054
# dtype: float64

# %%
np.mean(all_lambdas[0])*21*100
# Out:
# 0   -0.542505
# 1   -0.114601
# 2   -0.027734
# 3    0.042531
# 4   -0.044879
# 5    0.111585
# 6   -0.525114
# 7    0.215474
# 8    0.121425
# dtype: float64

# %%
stats.ttest_1samp(all_intercepts[0], 0.0)[0]
# Out:
# array([-4.01540444])

# %%
stats.ttest_1samp(all_lambdas[0], 0.0)[0]
# Out:
# array([-1.30515344, -0.53219324, -0.11126441,  0.15155002, -0.17652084,
#         3.41459207, -7.79984051,  2.95807841,  1.9309824 ])

# %%
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.79696989, -0.34540985, -0.07224609,  0.09848026, -0.11488431,
#         2.14111556, -4.91050715,  1.87119942,  1.21796888])

# %%
all_intercepts[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-2.52745967])

# %% [markdown]
# ## FM-IV Regression (Time-Varying Betas)

# %% [markdown]
# This section tests whether the risk premiums under the CAPM and the FF3- and FF5-Factor Models are significantly different from zero using the IV method with individual stocks. For the IV tests, the regression is fitted with daily return data from month t-36 to month t-1 to estimate beta for month t. Especially, we estimate odd- and even-month betas separately using returns on days belonging to odd and even months within this rolling window, repectively. Then we use odd-month betas as instrumental variabels and even-month vetas as explanatory variables when month t is even and vice versa when month t is odd. Thus the measurement errors in the instrumental variables and explanatory variables are not cross-sectionally correlated.

# %% [markdown]
# ### The CAPM Model

# %% [markdown]
# How many years in the rolling estimation window?

# %%
n = 3

# %% [markdown]
# Define the length of rolling window and rebalance frequency

# %%
holding = 21
rollingW = holding * n *12
lens = len(df_MR)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 211 756

# %% [markdown]
# This cell is the first stage of FM-IV regression, which is used to estimate market betas by regressing stock returns on market factor returns. Specifically, we use odd-month betas as instrumental variables and even-month betas as explanatory variables when month t is even and vive versa when month t is odd.

# %%
df_Ex_SR_trnct = df_Ex_SR.loc[df_MR.index,:]

all_betas_ev = []
all_betas_iv = []

for i in tqdm(range(periods)):

    df_MR_tmp = df_MR.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    
    # if current i is even-month
    if (i + 1) % 2 == 1:
        # extract all even-months within the rolling window into the explanatory betas estimation
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_MR_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_MR_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)

        # extract all odd-months within the rolling window into the instrumental betas estimation 
        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_MR_tmp.iloc[21*k:21*(k+1),:]])
        
        betas_iv = []

        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_MR_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)

    # if current i is odd-month
    if (i + 1) % 2 == 0:
        # extract all even-months into the instrumental betas estimation window
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_MR_tmp.iloc[21*k:21*(k+1),:]])

        betas_iv = []

        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_MR_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)
        
        # extract all odd-months into the explanatory betas estimation window
        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_MR_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []

        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_MR_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)
# Out:
# 100%|██████████| 211/211 [02:56<00:00,  1.19it/s]

# %%
# Print all explanatory betas for one period
all_betas_ev[0]
# Out:
#                                beta_1
# stock
# ABC.SJ.Equity    0.020752036332654343
# ABI.SJ.Equity      0.1960923076113216
# ABR.SJ.Equity     0.25699255481558286
# ACL.SJ.Equity       1.097261797813182
# ACP.SJ.Equity     -0.0360787349375643
# ...                               ...
# WTC.SJ.Equity      0.4319673313768428
# YRK.SJ.Equity  -0.0019644100899250823
# ZPT.SJ.Equity   -0.019458893419979854
# ZRR.SJ.Equity      0.1641413659846572
# ZSA.SJ.Equity     0.07982134703931368
#
# [421 rows x 1 columns]

# %%
# Print all instrumental betas for one period
all_betas_iv[0]
# Out:
#                              beta_1
# stock
# ABC.SJ.Equity   0.18634512037646847
# ABI.SJ.Equity   0.26394166816019343
# ABR.SJ.Equity  -0.49513207627973765
# ACL.SJ.Equity    0.8444968851727168
# ACP.SJ.Equity  -0.02282582272470314
# ...                             ...
# WTC.SJ.Equity    1.3597652644226035
# YRK.SJ.Equity   -0.1576001205867271
# ZPT.SJ.Equity     0.431477228031045
# ZRR.SJ.Equity    0.3640802104135971
# ZSA.SJ.Equity  0.029591852277496895
#
# [421 rows x 1 columns]

# %% [markdown]
# This cell is the second stage of FM-IV regression, which aims to estimate market risk premiums

# %%
all_lambdas = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)

    df_index = ((all_betas_iv[i].index).intersection(all_betas_ev[i].index)).intersection(df_Ex_SR.loc[k,:].dropna().index)
    
    if len(df_index) != 0:
        iv = IV2SLS(endog = df_Ex_SR_tmp_T.loc[df_index,k].values,exog = sm.add_constant(all_betas_ev[i].loc[df_index,:].values.astype(np.float64)),instrument = sm.add_constant(all_betas_iv[i].loc[df_index,:].values.astype(np.float64)))
        res = iv.fit()
        l = list(res.params)
        lambdas.append(l)
all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 4431/4431 [00:08<00:00, 497.69it/s]

# %%
# Print market risk premiums and intercepts
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT'})
# Out:
#       Intercept       MKT
# 0     -0.004259  0.023874
# 1      0.004750 -0.010384
# 2     -0.000105  0.012696
# 3     -0.001016  0.012151
# 4      0.006704 -0.026393
# ...         ...       ...
# 4426  -0.000695  0.000513
# 4427   0.001149  0.001897
# 4428  -0.001743  0.012511
# 4429   0.004971 -0.003894
# 4430  -0.004354 -0.008946
#
# [4431 rows x 2 columns]

# %%
# Print the time-series mean of market risk premiums and intercepts
np.mean(all_lambdas[0], axis = 0)*100*21
# Out:
# 0   -0.164184
# 1   -0.069573
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0].dropna(), 0.0)[0]
# Out:
# array([-0.96015648, -0.11472312])

# %%
## Newey-West t-test 
all_lambdas[0].dropna().apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.55928491, -0.07010451])

# %% [markdown]
# ### Adding Control Variables

# %% [markdown]
# The significance of factor risk premium estimates may due to an omitted variable bias because the second-stage cross-sectional regressions do not control for corresponding firm charactersitics. For mitigating this potential bias, we add characteristics as control variables in the second stage.

# %%
# Keep the size and PE have the same length as stock returns
df_ln_Size_trnct = df_ln_Size.loc[df_Ex_SR_trnct.index,:]
df_PE_trnct = df_PE.loc[df_Ex_SR_trnct.index,:]

# %%
len(df_ln_Size_trnct)==len(df_PE_trnct)==len(df_Ex_SR_trnct)
# Out:
# True

# %%
# Stock returns are forward for 21 days compared to firm characteristics 
Gap = 21

# %%
all_lambdas = []

df_Ex_SR_tmp_T = df_Ex_SR.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []

index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):

    i = int(index_times.index(k) / holding)

    df_index =  (((((all_betas_ev[i].index).intersection(all_betas_iv[i].index)).\
                 intersection(df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index)).\
                 intersection(df_PE_tmp_T.loc[:,k].dropna().index)).\
                 intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index))
    
    if len(df_index) != 0:
        iv = IV2SLS(endog = df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values,\
                    exog = sm.add_constant(pd.concat([all_betas_ev[i].loc[df_index,:],\
                                                      df_ln_Size_tmp_T.loc[df_index,k],\
                                                      df_PE_tmp_T.loc[df_index,k]],axis = 1).values.astype(np.float64)),\
                    instrument = sm.add_constant(pd.concat([all_betas_iv[i].loc[df_index,:],\
                                                           df_ln_Size_tmp_T.loc[df_index,k],\
                                                           df_PE_tmp_T.loc[df_index,k]],axis = 1).values.astype(np.float64)))
        res = iv.fit()
        l = list(res.params)     
        lambdas.append(l)

all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 4410/4410 [00:19<00:00, 221.20it/s]

# %%
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT',2:'Size',3:'PE'})
# Out:
#       Intercept           MKT          Size            PE
# 0      0.014977  1.246038e-02 -2.172922e-03  4.930722e-03
# 1     -0.020515 -4.429158e-02  4.362669e-03 -6.135628e-03
# 2      0.022709  2.748081e-03 -3.158640e-03  5.990199e-04
# 3     -0.000321  1.548371e-18 -1.257511e-18 -1.390203e-19
# 4     -0.003028 -8.040285e-03  7.374690e-04 -1.699848e-03
# ...         ...           ...           ...           ...
# 4405  -0.018540 -1.885284e-02  3.231134e-03  1.261862e-03
# 4406  -0.014663  3.589335e-03  1.567106e-03 -4.134712e-03
# 4407  -0.016686  9.564938e-03  1.746665e-03 -1.051621e-03
# 4408   0.018309  3.964590e-03 -1.661896e-03 -8.451565e-04
# 4409  -0.021443 -1.804838e-02  2.385643e-03 -4.968374e-03
#
# [4410 rows x 4 columns]

# %%
np.mean(all_lambdas[0], axis = 0)*21*100
# Out:
# 0   -1.675010
# 1   -1.693742
# 2    0.254655
# 3   -0.647732
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0].dropna(), 0.0)[0]
# Out:
# array([-1.37414654, -0.50439014,  0.87696445, -7.42466172])

# %%
## Newey-West t-test
all_lambdas[0].dropna().apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.88298823, -0.32517109,  0.56486033, -4.73297713])

# %% [markdown]
# ### The FF3-Factor Model

# %%
# How many years in the rolling window
n = 3

# %%
holding = 21
rollingW = holding * n * 12
lens = len(df_FF3)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 189 756

# %% [markdown]
# This cell is the first stage of FM IV regression under the FF3-Factor Model, which aims to estiamte intercepts and the betas of FF3-Factors

# %%
# Keep the excess stock returns and factor returns have the same length
df_Ex_SR_trnct = df_Ex_SR.loc[df_FF3.index,:]

all_betas_ev = []
all_betas_iv = []

for i in tqdm(range(periods)):

    df_FF3_tmp = df_FF3.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    

    if (i + 1) % 2 == 1:
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_FF3_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF3_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)


        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_FF3_tmp.iloc[21*k:21*(k+1),:]])
        
        betas_iv = []

        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF3_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)


    if (i + 1) % 2 == 0:
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_FF3_tmp.iloc[21*k:21*(k+1),:]])

        betas_iv = []

        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF3_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)

        rw_even = pd.DataFrame()  
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_FF3_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF3_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)
# Out:
# 100%|██████████| 189/189 [03:32<00:00,  1.12s/it]

# %%
# Print the estimated betas for one period
all_betas_ev[0]
# Out:
#                               beta_1                beta_2  \
# stock
# ABC.SJ.Equity    -0.3268531755110442   -0.6124245989848942
# ABI.SJ.Equity    0.24617730235525837   0.05425134648046361
# ABR.SJ.Equity     0.1010109731125653  -0.34507237181482997
# ACL.SJ.Equity     1.0668768540336409    1.5465407429547147
# ACP.SJ.Equity   -0.06303301722658639  -0.10388120490467742
# ...                              ...                   ...
# WTC.SJ.Equity    0.08829694059751701  -0.23470768343869003
# YRK.SJ.Equity   -0.06685682467539814  -0.07086800152369618
# ZPT.SJ.Equity     0.1284458132594861   -0.8697247063803566
# ZRR.SJ.Equity  -0.024711260687379596     1.861073057068256
# ZSA.SJ.Equity    -0.0345652473513432  -0.10054857135182307
#
#                                beta_3
# stock
# ABC.SJ.Equity      0.5184193635149579
# ABI.SJ.Equity      0.0422217378258441
# ABR.SJ.Equity     -0.5898301921449686
# ACL.SJ.Equity      0.5948677602591734
# ACP.SJ.Equity      0.1043280940176547
# ...                               ...
# WTC.SJ.Equity     -0.1276217050250745
# YRK.SJ.Equity  -0.0005126169970859351
# ZPT.SJ.Equity      -0.668607414250201
# ZRR.SJ.Equity     -1.0941560241410766
# ZSA.SJ.Equity     0.01676759067321748
#
# [426 rows x 3 columns]

# %% [markdown]
# This cell is the second stage of FM IV regression, which aims to
# estimate intercepts and the risk premiums of the FF3-Factor. It should be noted the regression is performed on a time-series scale

# %%
all_lambdas = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):

    i = int(index_times.index(k) / holding)

    df_index = ((all_betas_iv[i].index).intersection(all_betas_ev[i].index)).intersection(df_Ex_SR.loc[k,:].dropna().index)
    
    if len(df_index) != 0:
        iv = IV2SLS(endog = df_Ex_SR_tmp_T.loc[df_index,k].values,
                    exog = sm.add_constant(all_betas_ev[i].loc[df_index,:].values.astype(np.float64)),
                    instrument = sm.add_constant(all_betas_iv[i].loc[df_index,:].values.astype(np.float64)))
        
        res = iv.fit()
        l = list(res.params)
        lambdas.append(l)
        
all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 3969/3969 [00:15<00:00, 253.54it/s]

# %% [markdown]
# One of the issues that often arise with IV estimators is that for any finite stock amount N, there is a very small change that the cross-products of the matrixes of (B_IV ) and (B_EV ) might be singular, which will cause the parameter estimates too large to be trusted. To avoid this potential problem in finite samples, the monthly risk premium estimates that deviate three or more standard deviations of the corresponding factor realizations from their sample average as missing values. For each column, it first computes the Z-score of each value in the column, relative to the column mean and standard deviation. It then takes the absolute Z-score because the direction does not matter, only if it is below the threshold. All(axis=1) ensures that each row satisfies the constraint. Finally, the result of this condition is used to index the dataframe.

# %%
all_lambdas[0] = all_lambdas[0][(np.abs((all_lambdas[0]-all_lambdas[0].mean())/all_lambdas[0].std()) <= 3).all(axis=1)]
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT',2:'SMB',3:'HML'})
# Out:
#       Intercept       MKT       SMB       HML
# 0      0.002567  0.000881 -0.007161 -0.015952
# 1      0.000735  0.014544 -0.026231  0.119196
# 2     -0.007442  0.056679 -0.160149  0.260119
# 3      0.006640 -0.040072  0.110945  0.054684
# 4     -0.000471 -0.003414 -0.015844  0.067162
# ...         ...       ...       ...       ...
# 3964  -0.001295  0.003374  0.005633  0.007013
# 3965  -0.001954 -0.005498 -0.002275 -0.005888
# 3966   0.000279  0.007539  0.005092 -0.008241
# 3967  -0.000569 -0.008376 -0.001591  0.008292
# 3968  -0.000043  0.007721  0.004572 -0.001285
#
# [3906 rows x 4 columns]

# %%
np.mean(all_lambdas[0], axis = 0)*21*100
# Out:
# 0   -0.185591
# 1   -0.159011
# 2   -0.426359
# 3   -0.073523
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0].dropna(), 0.0)[0]
# Out:
# array([-0.71212559, -0.65089469, -0.36721433,  1.21622638])

# %%
all_lambdas[0].dropna().apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.43563001, -0.41292625, -0.23858463,  0.75141129])

# %% [markdown]
# ### Adding Control Variables

# %%
# Keep the size and PE have the same length as stock returns
df_ln_Size_trnct = df_ln_Size.loc[df_Ex_SR_trnct.index,:]
df_PE_trnct = df_PE.loc[df_Ex_SR_trnct.index,:]

# %%
len(df_ln_Size_trnct)==len(df_PE_trnct)==len(df_Ex_SR_trnct)
# Out:
# True

# %% [markdown]
# This cell is the second stage of FM OLS regression under the FF3-Factor model and combined with the firm characteristics as control variables. This aim of this cell is to estimate factor premiums while controlling for omitted-variables bias

# %%
all_lambdas = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []

index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):

    i = int(index_times.index(k) / holding)

    df_index =  (((((all_betas_ev[i].index).intersection(all_betas_iv[i].index)).\
                 intersection(df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index)).\
                 intersection(df_PE_tmp_T.loc[:,k].dropna().index)).\
                 intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index))
    
    if len(df_index) != 0:
        iv = IV2SLS(endog = df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values,\
                    exog = sm.add_constant(pd.concat([all_betas_ev[i].loc[df_index,:],\
                                                      df_ln_Size_tmp_T.loc[df_index,k],\
                                                      df_PE_tmp_T.loc[df_index,k]],axis = 1).values.astype(np.float64)),\
                    instrument = sm.add_constant(pd.concat([all_betas_iv[i].loc[df_index,:],\
                                                           df_ln_Size_tmp_T.loc[df_index,k],\
                                                           df_PE_tmp_T.loc[df_index,k]],axis = 1).values.astype(np.float64)))
        res = iv.fit()
        l = list(res.params)     
        lambdas.append(l)

all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 3948/3948 [00:23<00:00, 169.61it/s]

# %%
# Print all factor premiums and slope coefficients
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT',2:'SMB',3:'HML',4:'Size',5:'PE'})
# Out:
#       Intercept           MKT           SMB           HML          Size  \
# 0      0.012461  6.221141e-03  9.276940e-03  3.385038e-02 -1.627672e-03
# 1     -0.005477 -5.816805e-03  1.762486e-02 -4.773823e-03  1.373696e-03
# 2     -0.000196  6.268282e-17 -5.489032e-17  2.330698e-17 -6.983600e-18
# 3      0.031357  6.738775e-02 -8.684569e-02  1.505320e-03 -6.557786e-03
# 4      0.047131  4.032544e-02  3.343628e-03  1.221515e-01 -7.362618e-03
# ...         ...           ...           ...           ...           ...
# 3943   0.000351  9.306867e-03  3.292599e-03  6.331240e-03 -3.398741e-04
# 3944  -0.007128 -1.671485e-02 -1.585883e-03 -5.298941e-03  1.033824e-03
# 3945   0.002439  9.364604e-03  6.709894e-03 -7.823815e-03 -3.091488e-04
# 3946  -0.003458 -1.115178e-02 -2.107113e-03  6.596075e-03  3.850270e-04
# 3947  -0.002362  2.655272e-03  5.632228e-03 -1.159571e-03  4.321211e-04
#
#                 PE
# 0    -1.098045e-03
# 1     7.666732e-04
# 2    -2.840387e-18
# 3    -7.764574e-03
# 4    -3.281921e-03
# ...            ...
# 3943  2.588205e-05
# 3944  2.887104e-04
# 3945  9.072206e-04
# 3946 -2.695619e-03
# 3947  1.732789e-03
#
# [3948 rows x 6 columns]

# %%
np.mean(all_lambdas[0], axis = 0)*21*100
# Out:
# 0   -1.104525
# 1   -1.295987
# 2    0.021446
# 3   -0.330416
# 4    0.169838
# 5   -0.516085
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0].dropna(), 0.0)
# Out:
# Ttest_1sampResult(statistic=array([-3.96694153, -1.9010129 ,  0.04021185, -0.42317529,  3.30000006,
#        -7.13534745]), pvalue=array([7.40928797e-05, 5.73730930e-02, 9.67926262e-01, 6.72190426e-01,
#        9.75432806e-04, 1.14334514e-12]))

# %%
# Newey-West t-test
all_lambdas[0].dropna().apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.70321362,  0.68829068,  0.39576884,  0.01291935,  0.17671754])

# %% [markdown]
# ### The Carhart4-Factor Model

# %%
n = 3

# %%
holding = 21
rollingW = holding * n *12
lens = len(df_FF4)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 189 756

# %%
df_Ex_SR_trcnt = df_Ex_SR.loc[df_FF4.index,:]

all_betas_ev = []
all_betas_iv = []

# i is time
for i in tqdm(range(periods)):

    df_FF4_tmp = df_FF4.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trcnt.iloc[i*holding:i*holding+rollingW,:]
    

    if (i + 1) % 2 == 1:
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_FF4_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF4_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)


        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_FF4_tmp.iloc[21*k:21*(k+1),:]])
        
        betas_iv = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF4_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)


    if (i + 1) % 2 == 0:
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_FF4_tmp.iloc[21*k:21*(k+1),:]])

        betas_iv = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF4_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)
        

        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_FF4_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF4_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)
# Out:
# 100%|██████████| 189/189 [03:44<00:00,  1.19s/it]

# %%
all_betas_iv[0]
# Out:
#                               beta_1                 beta_2  \
# stock
# ABC.SJ.Equity     0.0656845569626169    -0.8699058368890427
# ABI.SJ.Equity    0.26707948127248565   -0.07241045551827295
# ABR.SJ.Equity    -0.4795801044035704     1.9057894646316478
# ACL.SJ.Equity     0.7706463652726757     1.1732282918786088
# ACP.SJ.Equity  -0.016920386656687835   -0.01049026612220319
# ...                              ...                    ...
# WTC.SJ.Equity   0.054390082964423464  -0.055516906448164205
# YRK.SJ.Equity   -0.06899731520465617    -0.1317826150230018
# ZPT.SJ.Equity    0.04773796186747457    -1.0492644000104407
# ZRR.SJ.Equity     0.3234916219347627      0.701062183911547
# ZSA.SJ.Equity   0.012526110058636549    0.22372929632583677
#
#                              beta_3                 beta_4
# stock
# ABC.SJ.Equity      1.22047780623036    0.11164566633025275
# ABI.SJ.Equity  -0.06176587041601211   -0.06614527486980788
# ABR.SJ.Equity  -0.15162748653778113     0.5509700968751177
# ACL.SJ.Equity   -0.6077852702344433    -0.3580881554110593
# ACP.SJ.Equity   0.19099885306394182  -0.012355055461858083
# ...                             ...                    ...
# WTC.SJ.Equity    -0.341291631075831     0.1364131330049344
# YRK.SJ.Equity    0.1757901993569013    0.11825865851026425
# ZPT.SJ.Equity  -0.08757487010402643     0.5184032714137832
# ZRR.SJ.Equity   0.03077876038596028   -0.11212116151580748
# ZSA.SJ.Equity  -0.08379362575357813    -0.0802700617308175
#
# [427 rows x 4 columns]

# %%
all_lambdas = []
# i is time

df_Ex_SR_tmp_T = df_Ex_SR_trcnt.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)

    df_index = ((all_betas_iv[i].index).intersection(all_betas_ev[i].index)).intersection(df_Ex_SR.loc[k,:].dropna().index)
    
    if len(df_index) != 0:
        
        iv = IV2SLS(endog = df_Ex_SR_tmp_T.loc[df_index,k].values,exog = sm.add_constant(all_betas_ev[i].loc[df_index,:].values.astype(np.float64)),instrument = sm.add_constant(all_betas_iv[i].loc[df_index,:].values.astype(np.float64)))
        res = iv.fit()
        l = list(res.params)
        lambdas.append(l)
        
all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 3969/3969 [00:13<00:00, 285.39it/s]

# %%
# all_lambdas[0] = all_lambdas[0][(np.abs((all_lambdas[0]-all_lambdas[0].mean())/all_lambdas[0].std()) <= 6).all(axis=1)]
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT',2:'SMB',3:'HML',4:'WML'})
# Out:
#       Intercept       MKT       SMB       HML       WML
# 0      0.002512  0.002120 -0.005909 -0.009939  0.006729
# 1      0.001559  0.010241 -0.015341  0.125449 -0.008744
# 2     -0.005763  0.037121 -0.154288  0.228174 -0.102053
# 3      0.007476 -0.041799  0.130826  0.081956  0.017403
# 4      0.000129 -0.004141 -0.004607  0.084875  0.009444
# ...         ...       ...       ...       ...       ...
# 3964  -0.001747  0.000135  0.006859  0.005418 -0.032765
# 3965  -0.001980 -0.005498 -0.002282 -0.005910 -0.002387
# 3966   0.000600  0.008267  0.004531 -0.009597  0.010169
# 3967  -0.000667 -0.008154 -0.001511  0.009456  0.001455
# 3968  -0.000052  0.008328  0.004488 -0.000341  0.003742
#
# [3969 rows x 5 columns]

# %%
np.mean(all_lambdas[0], axis = 0)*21*100
# Out:
# 0   -0.422155
# 1    3.677819
# 2    3.454856
# 3    0.134548
# 4    1.090033
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0].dropna(), 0.0)[0]
# Out:
# array([-1.15628798,  1.17017975,  0.63005322,  0.0221677 ,  0.28810931])

# %%
## Newey-West t-test 
all_lambdas[0].dropna().apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-0.70321362,  0.68829068,  0.39576884,  0.01291935,  0.17671754])

# %% [markdown]
# ### The FF5-Factor Model

# %%
n = 3

# %%
holding = 21
rollingW = holding * n *12
lens = len(df_FF5)
periods = int((lens - rollingW) / holding) - 1
print(periods, rollingW)
# Out:
# 189 756

# %%
df_Ex_SR_trnct = df_Ex_SR.loc[df_FF5.index,:]

all_betas_ev = []
all_betas_iv = []

# i is time
for i in tqdm(range(periods)):

    df_FF5_tmp = df_FF5.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    

    if (i + 1) % 2 == 1:
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_FF5_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF5_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'beta_5',5:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)


        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_FF5_tmp.iloc[21*k:21*(k+1),:]])
        
        betas_iv = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF5_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'beta_5',5:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)


    if (i + 1) % 2 == 0:
        rw_odd = pd.DataFrame()
        for k in range(0,n*12,2):
            rw_odd = pd.concat([rw_odd,df_FF5_tmp.iloc[21*k:21*(k+1),:]])

        betas_iv = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_odd.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF5_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_iv.append(b)
        df_betas_iv = pd.DataFrame(np.array(betas_iv)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'beta_5',5:'stock'}).set_index('stock')
        all_betas_iv.append(df_betas_iv)
        

        rw_even = pd.DataFrame()   
        for k in range(1,n*12,2):
            rw_even = pd.concat([rw_even,df_FF5_tmp.iloc[21*k:21*(k+1),:]])

        betas_ev = []
        # j is stock
        for j in df_Ex_SR.columns:
            df_index = df_Ex_SR_tmp.loc[rw_even.index,j].dropna().index
            
            if len(df_index) != 0:
                b = list(ols_model.fit(df_FF5_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
                b.append(j)
                betas_ev.append(b)
        df_betas_ev = pd.DataFrame(np.array(betas_ev)).rename(columns={0:'beta_1',1:'beta_2',2:'beta_3',3:'beta_4',4:'beta_5',5:'stock'}).set_index('stock')
        all_betas_ev.append(df_betas_ev)
# Out:
# 100%|██████████| 189/189 [04:03<00:00,  1.29s/it]

# %%
all_betas_ev[0]
# Out:
#                               beta_1                beta_2  \
# stock
# ABC.SJ.Equity   -0.32026364154411135   -0.4181741837058309
# ABI.SJ.Equity    0.24847943994035315  0.011119484477200708
# ABR.SJ.Equity    0.11937104282657346    0.5758286214434714
# ACL.SJ.Equity     1.0615496463833378    1.7939094217907783
# ACP.SJ.Equity   -0.06378454804467328  -0.06024213362694133
# ...                              ...                   ...
# WTC.SJ.Equity     0.0946709593702369  -0.20332179545616452
# YRK.SJ.Equity   -0.07237355472335277  -0.14796035618852368
# ZPT.SJ.Equity    0.14951797835353672   -1.1295336202057926
# ZRR.SJ.Equity  -0.021830370794504207    1.7346937195709407
# ZSA.SJ.Equity   -0.04094035681029784  -0.08501254043860207
#
#                              beta_3                beta_4  \
# stock
# ABC.SJ.Equity    0.5488704085016213  0.023409502726765417
# ABI.SJ.Equity   0.06035605543899004   0.20140005166349167
# ABR.SJ.Equity   -0.4399249058491614    0.5767834482162031
# ACL.SJ.Equity    0.5837673610259562   0.07241908602345482
# ACP.SJ.Equity    0.1066651777621522  -0.00490860206044824
# ...                             ...                   ...
# WTC.SJ.Equity   -0.0967683565271136   0.20088707524116356
# YRK.SJ.Equity  -0.01511637698018932   -0.1427082964245994
# ZPT.SJ.Equity   -0.6659625819969919    0.2411071247845945
# ZRR.SJ.Equity   -1.2160000619183249   -0.2074668945006488
# ZSA.SJ.Equity  0.008813817798161969  -0.17500779617782442
#
#                               beta_5
# stock
# ABC.SJ.Equity   -0.16448418940620343
# ABI.SJ.Equity    0.11843689923637599
# ABR.SJ.Equity    0.35677253136071907
# ACL.SJ.Equity     0.4572965633092674
# ACP.SJ.Equity   0.008412778577930092
# ...                              ...
# WTC.SJ.Equity  -0.044281378078856015
# YRK.SJ.Equity    0.07036236447171391
# ZPT.SJ.Equity     -0.949035606654641
# ZRR.SJ.Equity    -0.6912488015771603
# ZSA.SJ.Equity    0.13438947814118735
#
# [426 rows x 5 columns]

# %%
all_betas_iv[0]
# Out:
#                               beta_1                beta_2  \
# stock
# ABC.SJ.Equity   0.009288251786810298   -0.5591896365415504
# ABI.SJ.Equity    0.27530506678175554  0.014711343780721947
# ABR.SJ.Equity    -0.4694896362683001    2.4245703884001966
# ACL.SJ.Equity     0.7856942506923502    1.1738528590966966
# ACP.SJ.Equity  -0.015118550434149825  0.010521459372023367
# ...                              ...                   ...
# WTC.SJ.Equity    0.06168047582958554  -0.14795610599511141
# YRK.SJ.Equity   -0.07230129473263838  -0.05120638258682371
# ZPT.SJ.Equity    0.06689118792284816   -0.4171521366334328
# ZRR.SJ.Equity     0.3456172616019609    0.7562066050177876
# ZSA.SJ.Equity   0.011893101187111614    0.1983682478468622
#
#                              beta_3                beta_4  \
# stock
# ABC.SJ.Equity    1.2530991369535094    1.1206433821257957
# ABI.SJ.Equity  -0.04621184939348005  -0.19071143889388972
# ABR.SJ.Equity   -0.2217008632228077    0.4675457635689666
# ACL.SJ.Equity    -0.584940693717014  0.024841226328937926
# ACP.SJ.Equity   0.22083977179298386  -0.14343954868356942
# ...                             ...                   ...
# WTC.SJ.Equity   -0.3744724899159049  -0.19734848651882267
# YRK.SJ.Equity   0.12866643407330716   0.18072040276074602
# ZPT.SJ.Equity  -0.07757136645783973    -0.557699232672268
# ZRR.SJ.Equity  -0.06585628021272771   0.03828871114338628
# ZSA.SJ.Equity   -0.0886548285646107   0.11046426915873386
#
#                              beta_5
# stock
# ABC.SJ.Equity   0.32911809781571555
# ABI.SJ.Equity  0.027196075606529653
# ABR.SJ.Equity   -0.7346085224689812
# ACL.SJ.Equity  -0.05228612068052538
# ACP.SJ.Equity   0.16175437621685396
# ...                             ...
# WTC.SJ.Equity  -0.16604128332906137
# YRK.SJ.Equity  -0.40318939966505696
# ZPT.SJ.Equity  -0.20443139926802334
# ZRR.SJ.Equity   -1.0624526091078028
# ZSA.SJ.Equity  -0.07495016316524883
#
# [427 rows x 5 columns]

# %%
all_lambdas = []


df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
index_times = list(df_Ex_SR_tmp_T.columns)

for k in tqdm(df_Ex_SR_tmp_T.columns):
    
    i = int(index_times.index(k) / holding)

    df_index = ((all_betas_iv[i].index).intersection(all_betas_ev[i].index)).intersection(df_Ex_SR.loc[k,:].dropna().index)
    
    if len(df_index) != 0:
        
        iv = IV2SLS(endog = df_Ex_SR_tmp_T.loc[df_index,k].values,exog = sm.add_constant(all_betas_ev[i].loc[df_index,:].values.astype(np.float64)),instrument = sm.add_constant(all_betas_iv[i].loc[df_index,:].values.astype(np.float64)))
        res = iv.fit()
        l = list(res.params)
        lambdas.append(l)
        
all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 3969/3969 [00:16<00:00, 243.22it/s]

# %%
all_lambdas[0] = all_lambdas[0][(np.abs((all_lambdas[0]-all_lambdas[0].mean())/all_lambdas[0].std()) <= 3).all(axis=1)]
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT',2:'SMB',3:'HML',4:'RMW',5:'CMA'})
# Out:
#       Intercept       MKT       SMB       HML       RMW       CMA
# 0     -0.000736  0.017756 -0.052361 -0.049748  0.002751  0.031988
# 1      0.000120  0.006669 -0.021270  0.059547 -0.014553 -0.016758
# 2     -0.014751  0.037939 -0.167387 -0.057366 -0.013706 -0.033193
# 3      0.012175 -0.047488  0.136535  0.118425 -0.043197 -0.022410
# 4     -0.003919  0.009086 -0.057445  0.014345 -0.014498  0.013588
# ...         ...       ...       ...       ...       ...       ...
# 3964  -0.001163  0.002065  0.007467  0.007511 -0.004690  0.002219
# 3965  -0.001918 -0.004087 -0.006006 -0.007420  0.005648  0.003116
# 3966   0.000494  0.009785 -0.001885 -0.009238  0.013959  0.005915
# 3967  -0.000747 -0.006134 -0.008818  0.012110  0.024586 -0.003690
# 3968   0.000121  0.006562  0.006760 -0.003174 -0.011665  0.002179
#
# [3883 rows x 6 columns]

# %%
np.mean(all_lambdas[0], axis = 0)*21*100
# Out:
# 0   -0.224114
# 1    0.188517
# 2   -0.818950
# 3   -0.497722
# 4    1.058757
# 5    0.885507
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0].dropna(), 0.0)[0]
# Out:
# array([-1.83042429,  0.25249975, -0.54513419, -0.34095375,  0.79573623,
#         0.83114741])

# %%
## New-West Adjustment 
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-1.10560384,  0.15567656, -0.32884243, -0.2049036 ,  0.49279845,
#         0.53092225])

# %% [markdown]
# ### Adding Control Variables

# %%
df_OP_trnct = df_OP.loc[df_FF5.index,:]
df_INV_trnct = df_INV.loc[df_FF5.index,:]

# %%
len(df_ln_Size_trnct)==len(df_PE_trnct)==len(df_Ex_SR_trnct)==len(df_OP_trnct)==len(df_INV_trnct)==len(df_FF5)
# Out:
# True

# %%
Gap = 21

# %%
all_lambdas = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_OP_tmp_T = df_OP_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_INV_tmp_T = df_INV_trnct.iloc[rollingW:rollingW+periods*holding,:].T

lambdas = []
index_times = list(df_Ex_SR_tmp_T.columns)
# If Gap >0, the following should be 'for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):''
for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):

    i = int(index_times.index(k) / holding)

    # df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan), the -inf in ln_Size data dataframe would interrupt the regression
    df_index = ((((((all_betas_ev[i].index).intersection(df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index).\
                 intersection(df_PE_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index)).\
                  intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index)).\
                   intersection(df_OP_tmp_T.loc[:,k].dropna().index)).\
                    intersection(df_INV_tmp_T.loc[:,k].dropna().index)).\
                     intersection(all_betas_iv[i].index))
    
    if len(df_index) != 0:
        iv = IV2SLS(endog = df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]].values,\
                    exog = sm.add_constant(pd.concat([all_betas_ev[i].loc[df_index,:],\
                                                      df_ln_Size_tmp_T.loc[df_index,k],\
                                                      df_PE_tmp_T.loc[df_index,k],\
                                                      df_OP_tmp_T.loc[df_index,k],\
                                                      df_INV_tmp_T.loc[df_index,k]],axis = 1).values.astype(np.float64)),\
                    instrument = sm.add_constant(pd.concat([all_betas_iv[i].loc[df_index,:],\
                                                           df_ln_Size_tmp_T.loc[df_index,k],\
                                                           df_PE_tmp_T.loc[df_index,k],\
                                                           df_OP_tmp_T.loc[df_index,k],\
                                                           df_INV_tmp_T.loc[df_index,k]],axis = 1).values.astype(np.float64)))
        res = iv.fit()
        l = list(res.params)           
        lambdas.append(l)

all_lambdas.append(pd.DataFrame(lambdas))
# Out:
# 100%|██████████| 3948/3948 [00:31<00:00, 123.67it/s]

# %%
all_lambdas[0] = all_lambdas[0][(np.abs((all_lambdas[0]-all_lambdas[0].mean())/all_lambdas[0].std()) <= 3).all(axis=1)]
all_lambdas[0].rename(columns={0:'Intercept',1:'MKT',2:'SMB',3:'HML',4:'RMW',5:'CMA',6:'Size',7:'PE',8:'OP',9:'INV'})
# Out:
#       Intercept           MKT           SMB           HML           RMW  \
# 0      0.002882 -3.203740e-02  4.063585e-02  5.377724e-02  2.179188e-02
# 1     -0.021259 -4.851882e-02  5.798545e-02  2.403054e-02  2.445930e-02
# 2     -0.000196  1.095828e-16 -9.178089e-17 -3.723192e-17 -6.676822e-17
# 4     -0.010601 -1.033770e-01  1.138461e-01  1.471925e-01  5.006590e-02
# 5     -0.009625 -5.158992e-02  4.896105e-02  5.819617e-02  4.737014e-02
# ...         ...           ...           ...           ...           ...
# 3943  -0.000912  9.546371e-03  6.989650e-03  4.548776e-03 -7.722791e-03
# 3944  -0.007133 -1.656225e-02 -7.270620e-03 -1.429668e-03  1.521101e-02
# 3945   0.004583  1.088215e-02 -2.020555e-03 -7.457011e-03  9.777867e-03
# 3946  -0.004340 -1.107113e-02 -8.431077e-03  9.730512e-03  1.639626e-02
# 3947  -0.002514  2.861552e-03  9.697143e-03 -5.110766e-03 -1.667951e-02
#
#                CMA          Size            PE            OP           INV
# 0    -4.715364e-02  1.130874e-03  5.251107e-04  3.958948e-03 -2.326611e-04
# 1    -4.481786e-02  4.997242e-03 -7.911011e-05  2.072826e-03 -3.609786e-03
# 2     7.737957e-17 -1.007912e-17 -1.909638e-18 -2.013804e-18 -1.830244e-18
# 4    -1.839394e-01  5.978639e-03 -1.510789e-03 -2.303752e-03  7.756941e-04
# 5    -6.117162e-02  3.651936e-03 -1.580628e-03 -6.765344e-04  5.579345e-04
# ...            ...           ...           ...           ...           ...
# 3943 -4.327069e-03 -1.754188e-04 -1.297220e-04  4.058031e-04 -9.881525e-04
# 3944  3.482431e-03  9.778977e-04  6.225103e-04 -7.986016e-04  3.668618e-04
# 3945  9.744437e-03 -6.226551e-04  3.229791e-04  3.777887e-04 -8.273804e-04
# 3946  6.265878e-03  4.086144e-04 -2.711472e-03 -1.593937e-03 -3.257362e-03
# 3947 -3.003188e-03  4.677423e-04  1.244314e-03  7.406362e-04  1.200487e-03
#
# [3902 rows x 10 columns]

# %%
np.mean(all_lambdas[0], axis = 0)*21*100
# Out:
# 0   -0.878176
# 1   -1.100336
# 2    0.164529
# 3    0.562835
# 4    0.932494
# 5   -0.162485
# 6    0.146156
# 7   -0.542527
# 8    0.190085
# 9    0.140870
# dtype: float64

# %%
stats.ttest_1samp(all_lambdas[0].dropna(), 0.0)[0]
# Out:
# array([-3.19410516, -1.3240211 ,  0.24435517,  0.58163314,  1.43850581,
#        -0.19471938,  2.78854415, -6.85138594,  2.21110244,  1.71045743])

# %%
## Newey-West t-test
all_lambdas[0].apply(lambda x: NW_ttest(ret = x, h0=0), axis=0).values
# Out:
# array([-2.02833156, -0.83538512,  0.15906184,  0.37863244,  0.93575758,
#        -0.12583157,  1.76963785, -4.32594274,  1.41011403,  1.09776553])

# %% [markdown]
# ## IC & IR

# %%
len(df_ln_Size_trnct)==len(df_PE_trnct)==len(df_Ex_SR_trnct)==len(df_OP_trnct)==len(df_INV_trnct)==len(df_FF5)

# %%
all_betas = []

for i in tqdm(range(periods)):

    df_FF5_tmp = df_FF5.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR_trnct.iloc[i*holding:i*holding+rollingW,:]
    
    betas = []

    for j in df_Ex_SR.columns:
        df_index = df_Ex_SR_tmp.loc[:,j].dropna().index
        
        if len(df_index) != 0:
            b = list(ols_model.fit(df_FF5_tmp.loc[df_index,:].values, df_Ex_SR_tmp.loc[df_index,j].values).coef_)
            b.append(j)
            betas.append(b)
    df_betas = pd.DataFrame(np.array(betas)).rename(columns={0:'MKT',1:'SMB',2:'HML',3:'RMW',4:'CMA',5:'stock'}).set_index('stock')
    
    all_betas.append(df_betas)
# Out:
# 100%|██████████| 189/189 [01:50<00:00,  1.72it/s]

# %%
IC_Series = pd.DataFrame()
k_index = []

df_Ex_SR_tmp_T = df_Ex_SR_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_ln_Size_tmp_T = df_ln_Size_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_PE_tmp_T = df_PE_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_OP_tmp_T = df_OP_trnct.iloc[rollingW:rollingW+periods*holding,:].T
df_INV_tmp_T = df_INV_trnct.iloc[rollingW:rollingW+periods*holding,:].T

index_times = list(df_Ex_SR_tmp_T.columns)
 
for k in tqdm(df_Ex_SR_tmp_T.columns[:-Gap]):
    IC = []

    i = int(index_times.index(k) / holding)

    df_index = (((((all_betas[i].index).intersection(df_ln_Size_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index).\
                    intersection(df_PE_tmp_T.loc[:,k].replace(-np.inf,np.nan).dropna().index)).\
                    intersection(df_Ex_SR_tmp_T.loc[:,index_times[index_times.index(k)+Gap]].dropna().index)).\
                    intersection(df_OP_tmp_T.loc[:,k].dropna().index)).\
                    intersection(df_INV_tmp_T.loc[:,k].dropna().index))

    df_TS_CS = pd.concat([all_betas[i].loc[df_index,:].astype(np.float64), \
                                         df_ln_Size_tmp_T.loc[df_index,k],\
                                         df_PE_tmp_T.loc[df_index,k], df_OP_tmp_T.loc[df_index,k],\
                                         df_INV_tmp_T.loc[df_index,k]],axis = 1)

    if len(df_index) != 0:
        for j in range(len(df_TS_CS.columns)):
            ic = list(spearmanr(df_TS_CS.iloc[:,j].values,df_Ex_SR_tmp_T.loc[df_index,index_times[index_times.index(k)+Gap]]))[0]
            IC.append(ic)
        k_index.append(k)
    IC_Series = pd.concat([IC_Series, pd.DataFrame(IC)],axis=1)
# Out:
# 100%|██████████| 3948/3948 [01:19<00:00, 49.53it/s]

# %%
IC_Series_tmp = IC_Series.T.set_index([pd.Index(pd.Series(range(0,len(IC_Series.T))))])
IC_Series_tmp = pd.concat([IC_Series_tmp, pd.DataFrame(k_index)], axis = 1)
IC_Series_tmp.columns = ['MKT','SMB','HML','RMW','CMA','Size','PE','OP','INV','Dates']
IC_Series_tmp = IC_Series_tmp.set_index('Dates')
IC_Series_tmp
# Out:
#                  MKT       SMB       HML       RMW       CMA      Size  \
# Dates
# 2003-11-13 -0.079308 -0.022140 -0.028726 -0.138328  0.011337 -0.061218
# 2003-11-14  0.147583  0.034744 -0.001201 -0.076863 -0.006581  0.147324
# 2003-11-17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2003-11-18 -0.016021  0.064983  0.049302 -0.137799  0.034262  0.171072
# 2003-11-19  0.180753 -0.059813  0.030371 -0.091417 -0.069705  0.134507
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-25  0.005177  0.090264 -0.011360 -0.035602  0.021782  0.058714
# 2018-12-26 -0.114304 -0.017521 -0.034003  0.102865  0.013508 -0.055444
# 2018-12-27  0.163933 -0.070015 -0.080470  0.003141 -0.052075  0.121295
# 2018-12-28 -0.146859  0.078054 -0.027934  0.095278 -0.064957 -0.111885
# 2018-12-31  0.156800  0.066327  0.179581 -0.096778  0.084975  0.159491
#
#                   PE        OP       INV
# Dates
# 2003-11-13  0.027290  0.159819 -0.119245
# 2003-11-14 -0.121448  0.132668 -0.077161
# 2003-11-17  0.000000  0.000000  0.000000
# 2003-11-18 -0.133885 -0.013541  0.069178
# 2003-11-19 -0.192892 -0.050893 -0.065577
# ...              ...       ...       ...
# 2018-12-25 -0.019444 -0.067647  0.001734
# 2018-12-26  0.087302  0.058119 -0.055422
# 2018-12-27 -0.024359 -0.048854 -0.035295
# 2018-12-28 -0.120738  0.057023 -0.149950
# 2018-12-31  0.013129 -0.035681 -0.010199
#
# [3948 rows x 9 columns]

# %%
IC_Series = IC_Series_tmp
IC_Series
# Out:
#                  MKT       SMB       HML       RMW       CMA      Size  \
# Dates
# 2003-11-13 -0.079308 -0.022140 -0.028726 -0.138328  0.011337 -0.061218
# 2003-11-14  0.147583  0.034744 -0.001201 -0.076863 -0.006581  0.147324
# 2003-11-17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2003-11-18 -0.016021  0.064983  0.049302 -0.137799  0.034262  0.171072
# 2003-11-19  0.180753 -0.059813  0.030371 -0.091417 -0.069705  0.134507
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-25  0.005177  0.090264 -0.011360 -0.035602  0.021782  0.058714
# 2018-12-26 -0.114304 -0.017521 -0.034003  0.102865  0.013508 -0.055444
# 2018-12-27  0.163933 -0.070015 -0.080470  0.003141 -0.052075  0.121295
# 2018-12-28 -0.146859  0.078054 -0.027934  0.095278 -0.064957 -0.111885
# 2018-12-31  0.156800  0.066327  0.179581 -0.096778  0.084975  0.159491
#
#                   PE        OP       INV
# Dates
# 2003-11-13  0.027290  0.159819 -0.119245
# 2003-11-14 -0.121448  0.132668 -0.077161
# 2003-11-17  0.000000  0.000000  0.000000
# 2003-11-18 -0.133885 -0.013541  0.069178
# 2003-11-19 -0.192892 -0.050893 -0.065577
# ...              ...       ...       ...
# 2018-12-25 -0.019444 -0.067647  0.001734
# 2018-12-26  0.087302  0.058119 -0.055422
# 2018-12-27 -0.024359 -0.048854 -0.035295
# 2018-12-28 -0.120738  0.057023 -0.149950
# 2018-12-31  0.013129 -0.035681 -0.010199
#
# [3948 rows x 9 columns]

# %%
# Annualized the mean of IC_Series
all_ICs = IC_Series.apply(lambda x: x.mean()*np.sqrt(252), axis = 0) 
all_ICs
# Out:
# MKT    -0.036556
# SMB    -0.002672
# HML    -0.023002
# RMW    -0.018756
# CMA    -0.004478
# Size    0.076955
# PE     -0.125138
# OP      0.092540
# INV     0.014157
# dtype: float64

# %%
# Annualized ICIR
all_ICIRs = IC_Series.apply(lambda x: x.mean()/x.std()*np.sqrt(252), axis = 0) 
all_ICIRs
# Out:
# MKT    -0.203455
# SMB    -0.038310
# HML    -0.337852
# RMW    -0.282855
# CMA    -0.062658
# Size    0.456061
# PE     -1.735563
# OP      1.303562
# INV     0.222764
# dtype: float64

# %%
## Plot Cumsum IC_Series of MKT
ax = IC_Series[['MKT']].cumsum().plot(title = 'Cumulative Sum of MKT IC_Series',figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["MKT"]],all_ICIRs[["MKT"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# MKT -0.036556 -0.203455

# %%
## Plot Cumsum IC_Series of SMB & Size
ax = IC_Series[["SMB","Size"]].cumsum().plot(title = 'Cumulative Sum of SMB & Size IC_Series',figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["SMB","Size"]],all_ICIRs[["SMB","Size"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#             IC      ICIR
# SMB  -0.002672 -0.038310
# Size  0.076955  0.456061

# %%
## Plot Cumsum IC_Series of HML & PE
ax = IC_Series[["HML","PE"]].cumsum().plot(title = 'Cumulative Sum of HML & PE IC_Series',figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["HML","PE"]],all_ICIRs[["HML","PE"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# HML -0.023002 -0.337852
# PE  -0.125138 -1.735563

# %%
## Plot Cumsum IC_Series of RMW & OP
ax = IC_Series[["RMW","OP"]].cumsum().plot(title = 'Cumulative Sum of RMW & OP IC_Series',figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["RMW","OP"]],all_ICIRs[["RMW","OP"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# RMW -0.018756 -0.282855
# OP   0.092540  1.303562

# %%
## Plot Cumsum IC_Series of CMA & INV
ax = IC_Series[["CMA","INV"]].cumsum().plot(title = 'Cumulative Sum of CMA & INV IC_Series',figsize = (8,4))
plt.gcf().autofmt_xdate()
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.show()
pd.concat([all_ICs[["CMA","INV"]],all_ICIRs[["CMA","INV"]]],axis=1).rename(columns={0:'IC',1:'ICIR'})
# Out:
#            IC      ICIR
# CMA -0.004478 -0.062658
# INV  0.014157  0.222764

# %% [markdown]
# Overall speaking, the factor risks under the CAPM, FF3-factor model or FF5-factor model are all unpriced in the cross-section of individual stock returns, while the slope coefficients of SIZE, PE and OP are statistically significant under the OLS and IV estimation, respectively. These findings suggest that firm characteristics could be the better choice for proxying the true unknown factor loadings since they have stronger explanatory power than beta estimates. In the following section, this study evaluates the possibility of using firm characteristics as factor loadings in empirical asset pricing models to replace time-varying betas without causing the EIV problem in the second stage of FM regression when using individual stocks as test assets.

# %% [markdown]
# # Compare TS and CS models

# %% [markdown]
# This section use the cross-section regression approach of FM to construct cross-sectional factor (CS factors) corresponding to the time-series factors (TS factors) of Fama and French (2015).

# %% [markdown]
# ## TS Factor Model I

# %%
df_FF3
# Out:
#              MR_RF       SMB      HML
# Dates
# 2000-12-20 -0.0083  0.001267  0.00510
# 2000-12-21 -0.0062  0.001933 -0.00240
# 2000-12-22  0.0163  0.002433  0.00670
# 2000-12-25 -0.0003  0.000000  0.00000
# 2000-12-26 -0.0003  0.000000  0.00000
# ...            ...       ...      ...
# 2019-02-27  0.0008 -0.003700 -0.00155
# 2019-02-28 -0.0055  0.005000 -0.00145
# 2019-03-01  0.0034 -0.003433  0.00380
# 2019-03-04  0.0001  0.001267  0.00380
# 2019-03-05 -0.0074  0.006433 -0.00520
#
# [4750 rows x 3 columns]

# %%
# Plot the correlation among FF3-Factor
plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
corrMatrix = df_FF3.corr()
sn.heatmap(corrMatrix, annot=True, cmap="viridis")
plt.title('The Correlation Among TS Factors', fontsize=10)
plt.show()

# %% [markdown]
# TS factors are exactly the same as we used in FF5-Factor model

# %%
df_FF5
# Out:
#              MR_RF     SMB     HML     RMW     CMA
# Dates
# 2000-12-20 -0.0083 -0.0003  0.0052 -0.0016  0.0014
# 2000-12-21 -0.0062  0.0041 -0.0024  0.0004  0.0131
# 2000-12-22  0.0163  0.0027  0.0066 -0.0013 -0.0034
# 2000-12-25 -0.0003  0.0000  0.0000  0.0000  0.0000
# 2000-12-26 -0.0003  0.0000  0.0000  0.0000  0.0000
# ...            ...     ...     ...     ...     ...
# 2019-02-27  0.0008 -0.0033 -0.0015 -0.0005 -0.0010
# 2019-02-28 -0.0055  0.0032 -0.0015  0.0113 -0.0001
# 2019-03-01  0.0034 -0.0028  0.0037  0.0033  0.0052
# 2019-03-04  0.0001  0.0014  0.0038  0.0006  0.0014
# 2019-03-05 -0.0074  0.0056 -0.0053 -0.0032  0.0040
#
# [4750 rows x 5 columns]

# %% [markdown]
# Change the daily factor returns to monthly returns

# %%
m_df_FF5 = df_FF5
m_df_FF5['month'] = np.array(df_FF5.index.astype(str).str[:7])
m_df_FF5 = m_df_FF5.groupby('month').sum()
df_FF5 = df_FF5.drop(['month'], axis = 1)
# m_df_FF5 = m_df_FF5.iloc[:-1,:]
m_df_FF5
# Out:
#           MR_RF     SMB     HML     RMW     CMA
# month
# 2000-12  0.0107 -0.0029  0.0111 -0.0014  0.0021
# 2001-01  0.0851 -0.0018 -0.0045 -0.0324  0.0161
# 2001-02 -0.0068  0.0119  0.0353  0.0283  0.0519
# 2001-03 -0.0935  0.0192  0.0139 -0.0174  0.0412
# 2001-04  0.0921 -0.0157  0.0204 -0.0156  0.0160
# ...         ...     ...     ...     ...     ...
# 2018-11 -0.0365  0.0014 -0.0235  0.0024 -0.0124
# 2018-12  0.0375 -0.0033 -0.0123  0.0085  0.0050
# 2019-01  0.0234  0.0057  0.0154  0.0151  0.0042
# 2019-02  0.0297  0.0110 -0.0190  0.0419 -0.0161
# 2019-03 -0.0039  0.0042  0.0022  0.0007  0.0106
#
# [220 rows x 5 columns]

# %%
m_df_FF5.mean()*100
# Out:
# MR_RF    0.691045
# SMB      0.205318
# HML     -0.093909
# RMW     -0.086682
# CMA      0.052409
# dtype: float64

# %%
m_df_FF5.std()
# Out:
# MR_RF    0.046434
# SMB      0.013624
# HML      0.017510
# RMW      0.017026
# CMA      0.017630
# dtype: float64

# %%
m_df_FF5.apply(lambda x: stats.ttest_1samp(x,0))
# Out:
#       MR_RF       SMB       HML       RMW       CMA
# 0  2.207386  2.235227 -0.795491 -0.755142  0.440918
# 1  0.028325  0.026412  0.427189  0.450975  0.659708

# %%
m_df_FF5.iloc[:,4].plot(kind='density')
# df_FF5.iloc[:,4].hist()
plt.show()

# %%
plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
corrMatrix = df_FF5.corr()
sn.heatmap(corrMatrix, annot=True, cmap="viridis")
plt.title('The Correlation Among TS Factors', fontsize=10)
plt.show()

# %%
df_SR_tmp = df_SR.apply(replacer)
df_Ex_SR_tmp = df_SR_tmp - df_RF.values

# %% [markdown]
# Step-1: Use double-sorted portfolio return as regressors and then run time-series regression model to obtain factor loadings and interceptions, i.e. betas and alphas, with NW Adjustment

# %%
# Keep the excess stock returns and FF5-Factor returns have the same length
df_Ex_SR_trnct = df_Ex_SR_tmp.loc[df_FF5.index,:]

all_betas = []
all_cons_ts = []
all_std_errs = []
all_Rs = []
all_sd_res = []

betas = []
labels = []
cons_ts = []
std_errs = []
Rs = []
sd_res = []

for j in tqdm(df_Ex_SR.columns):

    df_index = (df_Ex_SR_trnct.loc[:, j].dropna().index).intersection(df_FF5.index)

    if len(df_index) > 10:
        lag = int(4*((len(df_Ex_SR_trnct.loc[df_index, j]))/100)**(1/9))
        ols = sm.OLS(df_Ex_SR_trnct.loc[df_index, j].astype(np.float64), sm.add_constant(
            df_FF5.loc[df_index, :].astype(np.float64)))
        res = ols.fit(cov_type='HAC', cov_kwds={'maxlags': lag})

        b = list(res.params)
        t = res.tvalues[0]
        se = res.bse[0]
        r = res.rsquared
        sr = res.resid.std()
        betas.append(b)
        cons_ts.append(t)
        std_errs.append(se)
        Rs.append(r)
        sd_res.append(sr)
        labels.append(j)

all_betas.append(pd.DataFrame(betas))
all_cons_ts.append(pd.DataFrame(cons_ts))
all_std_errs.append(pd.DataFrame(std_errs))
all_Rs.append(pd.DataFrame(Rs))
all_sd_res.append(pd.DataFrame(sd_res))
# Out:
# 100%|██████████| 740/740 [00:04<00:00, 163.99it/s]

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ZSA.SJ.Equity   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.204
# Date:                Mon, 02 May 2022   Prob (F-statistic):              0.305
# Time:                        02:35:14   Log-Likelihood:                 7115.7
# No. Observations:                2330   AIC:                        -1.422e+04
# Df Residuals:                    2324   BIC:                        -1.418e+04
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.000      0.684      0.494      -0.000       0.001
# MR_RF          0.0121      0.016      0.759      0.448      -0.019       0.043
# SMB            0.0624      0.066      0.945      0.345      -0.067       0.192
# HML            0.0199      0.051      0.391      0.696      -0.080       0.120
# RMW           -0.0233      0.046     -0.509      0.611      -0.113       0.066
# CMA            0.1010      0.048      2.120      0.034       0.008       0.194
# ==============================================================================
# Omnibus:                      411.302   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7222.062
# Skew:                           0.280   Prob(JB):                         0.00
# Kurtosis:                      11.607   Cond. No.                         267.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# """

# %%
TS_betas = pd.concat([all_betas[0], pd.DataFrame(labels)], axis = 1)
TS_betas.columns = ['Intercepts','MKT','SMB','HML','RMW','CMA','Stocks']
TS_betas = TS_betas.set_index('Stocks')
TS_betas
# Out:
#                   Intercepts       MKT       SMB       HML       RMW       CMA
# Stocks
# ABC.SJ.Equity      -0.003048 -0.334855 -1.038481  2.287313  1.736295  0.155451
# ABI.SJ.Equity       0.000293  0.250634 -0.027526 -0.026816 -0.052584  0.015525
# ABK.SJ.Equity      -0.002319  0.223503 -2.430166  2.617665  1.897113  0.505996
# ABR.SJ.Equity      -0.006584 -0.389331  3.760604 -0.545912  1.553621 -0.163119
# ABU.SJ.Equity      -0.000460  0.013298  0.056566  0.179378 -0.216206 -0.083836
# ...                      ...       ...       ...       ...       ...       ...
# ZGOVI.SJ.Equity     0.000053  0.048067 -0.005870 -0.025272 -0.036429 -0.027054
# ZPT.SJ.Equity      -0.002632  0.100060 -0.095590 -0.209509  0.405521 -0.727316
# ZRNHDG.SJ.Equity   -0.000383  0.030242  0.154120  0.025129 -0.110328 -0.119765
# ZRR.SJ.Equity       0.000437  0.200242  1.382998 -0.626178 -0.029967 -1.099765
# ZSA.SJ.Equity       0.000164  0.012068  0.062384  0.019905 -0.023266  0.100956
#
# [708 rows x 6 columns]

# %%
## The alphas are missing pricing errors of asset pricing model (FF5-Factor), which are also the intercepts of time series regression
TS_alphas = TS_betas.iloc[:,0]
TS_alphas.describe()
# Out:
# count    708.000000
# mean      -0.000724
# std        0.002416
# min       -0.019502
# 25%       -0.000787
# 50%       -0.000082
# 75%        0.000244
# max        0.006842
# Name: Intercepts, dtype: float64

# %%
TS_alphas.plot(kind='density')
TS_alphas.hist()
plt.show()

# %%
all_cons_ts[0]
# Out:
#             0
# 0   -1.128583
# 1    0.932694
# 2   -1.452077
# 3   -2.011185
# 4   -0.748997
# ..        ...
# 703  0.495672
# 704 -2.008599
# 705 -1.121602
# 706  0.333480
# 707  0.683831
#
# [708 rows x 1 columns]

# %%
all_ses = pd.DataFrame(all_std_errs[0])
all_ses.index = TS_alphas.index
all_ses.columns = ['std_errs']
all_ses
# Out:
#                   std_errs
# Stocks
# ABC.SJ.Equity     0.002701
# ABI.SJ.Equity     0.000314
# ABK.SJ.Equity     0.001597
# ABR.SJ.Equity     0.003274
# ABU.SJ.Equity     0.000614
# ...                    ...
# ZGOVI.SJ.Equity   0.000106
# ZPT.SJ.Equity     0.001310
# ZRNHDG.SJ.Equity  0.000342
# ZRR.SJ.Equity     0.001311
# ZSA.SJ.Equity     0.000240
#
# [708 rows x 1 columns]

# %%
TS_alphas_t = pd.concat([all_cons_ts[0], pd.DataFrame(labels)], axis = 1)
TS_alphas_t.columns = ['t-statistics','Stocks']
TS_alphas_t = TS_alphas_t.set_index('Stocks')
TS_alphas_t
# Out:
#                   t-statistics
# Stocks
# ABC.SJ.Equity        -1.128583
# ABI.SJ.Equity         0.932694
# ABK.SJ.Equity        -1.452077
# ABR.SJ.Equity        -2.011185
# ABU.SJ.Equity        -0.748997
# ...                        ...
# ZGOVI.SJ.Equity       0.495672
# ZPT.SJ.Equity        -2.008599
# ZRNHDG.SJ.Equity     -1.121602
# ZRR.SJ.Equity         0.333480
# ZSA.SJ.Equity         0.683831
#
# [708 rows x 1 columns]

# %% [markdown]
# ### Results_1

# %% [markdown]
# Step2: Calculate the absolute value of alphas and alphas_t, then calculate their mean respectively

# %%
print(np.mean(abs(TS_alphas))*21*100,np.nanmean(abs(TS_alphas_t)))
# Out:
# 2.4473105113330336 1.2311180418810375

# %% [markdown]
# Step3: Calculate the cross-sectional variance of LHS average returns and then divided by the mean of squared alphas

# %%
cs_var = np.var(df_SR_tmp.apply(lambda x: np.mean(x), axis = 0))
print(np.mean(np.square(TS_alphas))/cs_var)
# Out:
# 0.9212533564720019

# %% [markdown]
# Step4: Substract the squared standard error of each intercept to adjust for the noise in the Step-3

# %%
A_lamda = np.mean((pd.DataFrame(np.square(TS_alphas).values)-pd.DataFrame(np.square(all_ses).values)), axis = 0)
print(A_lamda/cs_var)
# Out:
# 0    0.732419
# dtype: float64

# %% [markdown]
# Step5: the average of the regression R^2; the average of the standard errors of the intercepts; the average of the standard deviations of the regression residuals.

# %%
print('AR^2: ' + str(np.mean(all_Rs)), 'As(a): ' + str(np.mean(all_ses.values)*np.sqrt(21)), \
      'As(e): ' + str(np.mean(all_sd_res)*np.sqrt(21)))
# Out:
# AR^2: 0.06929980236597638 As(a): 0.0035768601563833523 As(e): 0.12838075864403103

# %% [markdown]
# Step6: Calculate Cross-sectional R-squared, how much the total variance of expected stock returns can be explained by the model?

# %%
1-(np.var(TS_alphas)/np.var(df_Ex_SR_tmp.mean()))
# Out:
# 0.16185540585253944

# %% [markdown]
# ## CS Factor Model I

# %% [markdown]
# Import 18 double-sorted portfolios returns

# %%
df_18_PR
# Out:
#             B_Value  B_Neutral_PE  B_Growth  B_Robust  B_Neutral_OP  B_Weak  \
# Dates
# 2000-12-20  -0.0073       -0.0060   -0.0009   -0.0023       -0.0005 -0.0015
# 2000-12-21  -0.0117        0.0029   -0.0113   -0.0101       -0.0115 -0.0102
# 2000-12-22   0.0099        0.0028    0.0002   -0.0040        0.0139  0.0072
# 2000-12-25   0.0000        0.0000    0.0000    0.0000        0.0000  0.0000
# 2000-12-26   0.0000        0.0000    0.0000    0.0000        0.0000  0.0000
# ...             ...           ...       ...       ...           ...     ...
# 2019-02-27   0.0046       -0.0023    0.0026    0.0034        0.0008  0.0024
# 2019-02-28  -0.0065       -0.0079    0.0032    0.0003       -0.0054 -0.0055
# 2019-03-01   0.0093       -0.0046   -0.0010    0.0002        0.0056 -0.0022
# 2019-03-04  -0.0136       -0.0002   -0.0062   -0.0121       -0.0009 -0.0055
# 2019-03-05  -0.0053       -0.0172   -0.0050   -0.0045       -0.0159 -0.0072
#
#             B_Conservative  B_Neutral_INV  B_Aggressive  S_Value  \
# Dates
# 2000-12-20         -0.0062        -0.0036       -0.0100   0.0022
# 2000-12-21          0.0039        -0.0145       -0.0099  -0.0054
# 2000-12-22          0.0021        -0.0022        0.0051   0.0110
# 2000-12-25          0.0000         0.0000        0.0000   0.0000
# 2000-12-26          0.0000         0.0000        0.0000   0.0000
# ...                    ...            ...           ...      ...
# 2019-02-27          0.0046        -0.0011        0.0003  -0.0056
# 2019-02-28         -0.0038        -0.0009       -0.0054   0.0016
# 2019-03-01          0.0047        -0.0043        0.0013  -0.0059
# 2019-03-04         -0.0073        -0.0043       -0.0090   0.0035
# 2019-03-05         -0.0053        -0.0070       -0.0131  -0.0122
#
#             S_Neutral_PE  S_Growth  S_Robust  S_Neutral_OP  S_Weak  \
# Dates
# 2000-12-20        0.0018   -0.0145   -0.0047       -0.0025 -0.0024
# 2000-12-21       -0.0077   -0.0010   -0.0020       -0.0041 -0.0026
# 2000-12-22        0.0017    0.0075    0.0031        0.0043 -0.0055
# 2000-12-25        0.0000    0.0000    0.0000        0.0000  0.0000
# 2000-12-26        0.0000    0.0000    0.0000        0.0000  0.0000
# ...                  ...       ...       ...           ...     ...
# 2019-02-27       -0.0001   -0.0005   -0.0028       -0.0002 -0.0008
# 2019-02-28        0.0075   -0.0052    0.0064        0.0006 -0.0103
# 2019-03-01        0.0023   -0.0030    0.0004       -0.0006 -0.0037
# 2019-03-04       -0.0083   -0.0115   -0.0011       -0.0052 -0.0090
# 2019-03-05        0.0060   -0.0020   -0.0069       -0.0029  0.0021
#
#             S_Conservative  S_Neutral_INV  S_Aggressive
# Dates
# 2000-12-20         -0.0034        -0.0029       -0.0023
# 2000-12-21          0.0012        -0.0053       -0.0111
# 2000-12-22          0.0015         0.0107        0.0052
# 2000-12-25          0.0000         0.0000        0.0000
# 2000-12-26          0.0000         0.0000        0.0000
# ...                    ...            ...           ...
# 2019-02-27         -0.0011        -0.0087        0.0051
# 2019-02-28         -0.0023         0.0027       -0.0004
# 2019-03-01          0.0034        -0.0047       -0.0036
# 2019-03-04         -0.0004        -0.0115       -0.0015
# 2019-03-05         -0.0056         0.0035       -0.0058
#
# [4750 rows x 18 columns]

# %% [markdown]
# Import Firm Characteristics of 18 double-sorted portfolios

# %%
df_18_std_Size
# Out:
#              B_Value  B_Neutral_PE  B_Growth  B_Robust  B_Neutral_OP  \
# Dates
# 2000-12-20 -0.781312     -0.090458  1.848094  1.815374     -0.512456
# 2000-12-21 -0.781312     -0.090458  1.848094  1.815374     -0.512456
# 2000-12-22 -0.781312     -0.090458  1.848094  1.815374     -0.512456
# 2000-12-25 -0.781151     -0.079474  1.850319  1.826738     -0.513155
# 2000-12-26 -0.781046     -0.072916  1.851627  1.833502     -0.513567
# ...              ...           ...       ...       ...           ...
# 2019-02-27 -1.119487      1.546268  1.219728  1.561739     -1.873820
# 2019-02-28 -1.120516      1.545925  1.220317  1.561396     -1.874255
# 2019-03-01 -1.121537      1.545585  1.220903  1.561055     -1.874687
# 2019-03-04 -1.122582      1.545254  1.221491  1.560724     -1.875111
# 2019-03-05 -1.123620      1.544924  1.222074  1.560394     -1.875533
#
#               B_Weak  B_Conservative  B_Neutral_INV  B_Aggressive   S_Value  \
# Dates
# 2000-12-20 -0.539452       -0.085595       2.283493     -0.529163  0.053609
# 2000-12-21 -0.539452       -0.085595       2.283493     -0.529163  0.053609
# 2000-12-22 -0.539452       -0.085595       2.283493     -0.529163  0.053609
# 2000-12-25 -0.540065       -0.087661       2.273843     -0.529809  0.051098
# 2000-12-26 -0.540425       -0.088893       2.268058     -0.530188  0.049598
# ...              ...             ...            ...           ...       ...
# 2019-02-27  0.925591        0.794177       0.806161      0.257729 -0.307066
# 2019-02-28  0.925393        0.794072       0.805870      0.257367 -0.305990
# 2019-03-01  0.925196        0.793969       0.805582      0.257008 -0.304922
# 2019-03-04  0.924976        0.793833       0.805301      0.256658 -0.303856
# 2019-03-05  0.924758        0.793699       0.805023      0.256310 -0.302797
#
#             S_Neutral_PE  S_Growth  S_Robust  S_Neutral_OP    S_Weak  \
# Dates
# 2000-12-20     -0.920952 -0.266229 -0.185330     -1.305537 -0.221338
# 2000-12-21     -0.920952 -0.266229 -0.185330     -1.305537 -0.221338
# 2000-12-22     -0.920952 -0.266229 -0.185330     -1.305537 -0.221338
# 2000-12-25     -0.920344 -0.267716 -0.187077     -1.304010 -0.222969
# 2000-12-26     -0.919971 -0.268601 -0.188117     -1.303084 -0.223941
# ...                  ...       ...       ...           ...       ...
# 2019-02-27     -1.070146  0.035157 -0.631996     -0.982620 -0.504375
# 2019-02-28     -1.070054  0.034886 -0.631920     -0.982048 -0.504543
# 2019-03-01     -1.069963  0.034616 -0.631845     -0.981479 -0.504710
# 2019-03-04     -1.069868  0.034355 -0.631765     -0.980909 -0.504870
# 2019-03-05     -1.069773  0.034095 -0.631685     -0.980343 -0.505030
#
#             S_Conservative  S_Neutral_INV  S_Aggressive
# Dates
# 2000-12-20       -0.737976      -0.327963      0.503191
# 2000-12-21       -0.737976      -0.327963      0.503191
# 2000-12-22       -0.737976      -0.327963      0.503191
# 2000-12-25       -0.737953      -0.329854      0.499240
# 2000-12-26       -0.737932      -0.330980      0.496877
# ...                    ...            ...           ...
# 2019-02-27        0.158873      -0.905899      0.089987
# 2019-02-28        0.159395      -0.905694      0.090398
# 2019-03-01        0.159913      -0.905489      0.090807
# 2019-03-04        0.160433      -0.905281      0.091219
# 2019-03-05        0.160950      -0.905074      0.091628
#
# [4750 rows x 18 columns]

# %%
df_18_std_PE
# Out:
#              B_Value  B_Neutral_PE  B_Growth  B_Robust  B_Neutral_OP  \
# Dates
# 2000-12-20  0.474577     -0.596427  1.589434  1.332862     -0.036290
# 2000-12-21  0.488083     -0.579499  1.607375  1.319233     -0.018389
# 2000-12-22  0.529640     -0.589796  1.612475  1.280541      0.014783
# 2000-12-25  0.551065     -0.595016  1.614802  1.260246      0.031965
# 2000-12-26  0.564130     -0.598168  1.616119  1.247754      0.042469
# ...              ...           ...       ...       ...           ...
# 2019-02-27 -0.912531     -0.789055 -0.220451 -0.542673     -0.147525
# 2019-02-28 -0.912004     -0.789580 -0.221151 -0.542742     -0.148195
# 2019-03-01 -0.911462     -0.790103 -0.221840 -0.542804     -0.148841
# 2019-03-04 -0.910933     -0.790622 -0.222516 -0.542880     -0.149464
# 2019-03-05 -0.910411     -0.791154 -0.223149 -0.542956     -0.150114
#
#               B_Weak  B_Conservative  B_Neutral_INV  B_Aggressive   S_Value  \
# Dates
# 2000-12-20 -0.166038       -0.785416       2.553218     -1.192850  0.558439
# 2000-12-21 -0.133995       -0.780162       2.543136     -1.205060  0.544398
# 2000-12-22 -0.108110       -0.789886       2.512530     -1.225850  0.568047
# 2000-12-25 -0.094679       -0.794770       2.496185     -1.236381  0.580187
# 2000-12-26 -0.086460       -0.797704       2.486026     -1.242739  0.587572
# ...              ...             ...            ...           ...       ...
# 2019-02-27 -1.058409       -0.605954      -0.766705     -0.125978 -0.962525
# 2019-02-28 -1.058445       -0.605969      -0.767175     -0.126434 -0.959334
# 2019-03-01 -1.058479       -0.605974      -0.767637     -0.126874 -0.956164
# 2019-03-04 -1.058515       -0.605986      -0.768083     -0.127326 -0.952999
# 2019-03-05 -1.058512       -0.605991      -0.768487     -0.127812 -0.949922
#
#             S_Neutral_PE  S_Growth  S_Robust  S_Neutral_OP    S_Weak  \
# Dates
# 2000-12-20     -0.839326 -1.097937  0.077891     -0.655950 -0.763018
# 2000-12-21     -0.843136 -1.102449  0.090430     -0.652080 -0.797120
# 2000-12-22     -0.856767 -1.119877  0.102469     -0.660567 -0.814292
# 2000-12-25     -0.863662 -1.128686  0.108686     -0.664834 -0.823029
# 2000-12-26     -0.867821 -1.133999  0.112480     -0.667400 -0.828317
# ...                  ...       ...       ...           ...       ...
# 2019-02-27      1.547041  0.748977  2.423917     -0.225811 -0.722433
# 2019-02-28      1.548040  0.745663  2.425584     -0.226983 -0.722001
# 2019-03-01      1.549032  0.742338  2.427231     -0.228166 -0.721564
# 2019-03-04      1.550005  0.739033  2.428846     -0.229317 -0.721125
# 2019-03-05      1.551009  0.735763  2.430389     -0.230447 -0.720645
#
#             S_Conservative  S_Neutral_INV  S_Aggressive
# Dates
# 2000-12-20       -0.183795      -0.465047      0.195671
# 2000-12-21       -0.156331      -0.467808      0.143373
# 2000-12-22       -0.141778      -0.465314      0.151752
# 2000-12-25       -0.134212      -0.463931      0.156063
# 2000-12-26       -0.129576      -0.463055      0.158689
# ...                    ...            ...           ...
# 2019-02-27        1.450073       0.803500      0.106542
# 2019-02-28        1.445591       0.810998      0.104138
# 2019-03-01        1.441149       0.818401      0.101757
# 2019-03-04        1.436728       0.825737      0.099418
# 2019-03-05        1.432365       0.832983      0.097090
#
# [4750 rows x 18 columns]

# %%
df_18_std_OP
# Out:
#              B_Value  B_Neutral_PE  B_Growth  B_Robust  B_Neutral_OP  \
# Dates
# 2000-12-20  0.256084      0.237906  0.245898  0.241780      0.223827
# 2000-12-21  0.256084      0.237906  0.245898  0.241780      0.223827
# 2000-12-22  0.256084      0.237906  0.245898  0.241780      0.223827
# 2000-12-25  0.256059      0.237915  0.245878  0.241787      0.223802
# 2000-12-26  0.256044      0.237920  0.245866  0.241791      0.223787
# ...              ...           ...       ...       ...           ...
# 2019-02-27 -1.822343      0.190651  0.692564  0.233343     -1.633859
# 2019-02-28 -1.819476      0.192292  0.693698  0.234584     -1.630909
# 2019-03-01 -1.816610      0.193915  0.694811  0.235810     -1.627963
# 2019-03-04 -1.813740      0.195519  0.695903  0.237020     -1.625026
# 2019-03-05 -1.810874      0.197105  0.696976  0.238215     -1.622095
#
#               B_Weak  B_Conservative  B_Neutral_INV  B_Aggressive   S_Value  \
# Dates
# 2000-12-20  0.228190        0.221341       0.238552      0.236203  0.251100
# 2000-12-21  0.228190        0.221341       0.238552      0.236203  0.251100
# 2000-12-22  0.228190        0.221341       0.238552      0.236203  0.251100
# 2000-12-25  0.228165        0.221316       0.238527      0.236178  0.251075
# 2000-12-26  0.228150        0.221301       0.238512      0.236163  0.251060
# ...              ...             ...            ...           ...       ...
# 2019-02-27  0.126999        0.338755      -2.246118      0.197442  0.744658
# 2019-02-28  0.128631        0.340308      -2.242932      0.198849  0.745867
# 2019-03-01  0.130246        0.341842      -2.239745      0.200240  0.747055
# 2019-03-04  0.131851        0.343365      -2.236560      0.201613  0.748221
# 2019-03-05  0.133438        0.344869      -2.233376      0.202971  0.749366
#
#             S_Neutral_PE  S_Growth  S_Robust  S_Neutral_OP    S_Weak  \
# Dates
# 2000-12-20      0.256273  0.245066 -4.006389      0.218152  0.245097
# 2000-12-21      0.256273  0.245066 -4.006389      0.218152  0.245097
# 2000-12-22      0.256273  0.245066 -4.006389      0.218152  0.245097
# 2000-12-25      0.256248  0.245041 -4.006389      0.218247  0.245072
# 2000-12-26      0.256233  0.245026 -4.006389      0.218304  0.245057
# ...                  ...       ...       ...           ...       ...
# 2019-02-27     -0.061178  0.999833  0.669821     -0.491681  1.164673
# 2019-02-28     -0.069338  1.000860  0.671239     -0.498761  1.165169
# 2019-03-01     -0.077420  1.001863  0.672635     -0.505766  1.165644
# 2019-03-04     -0.085426  1.002843  0.674008     -0.512700  1.166099
# 2019-03-05     -0.093355  1.003800  0.675358     -0.519562  1.166533
#
#             S_Conservative  S_Neutral_INV  S_Aggressive
# Dates
# 2000-12-20        0.185385       0.236185      0.239349
# 2000-12-21        0.185385       0.236185      0.239349
# 2000-12-22        0.185385       0.236185      0.239349
# 2000-12-25        0.185360       0.236395      0.239324
# 2000-12-26        0.185346       0.236521      0.239309
# ...                    ...            ...           ...
# 2019-02-27        0.893887      -0.639183      0.641739
# 2019-02-28        0.894908      -0.647910      0.642919
# 2019-03-01        0.895907      -0.656544      0.644080
# 2019-03-04        0.896884      -0.665091      0.645219
# 2019-03-05        0.897839      -0.673547      0.646339
#
# [4750 rows x 18 columns]

# %%
df_18_std_INV
# Out:
#              B_Value  B_Neutral_PE  B_Growth  B_Robust  B_Neutral_OP  \
# Dates
# 2000-12-20  0.768570     -0.398832  1.031163  1.400032     -0.046577
# 2000-12-21  0.768570     -0.398832  1.031163  1.400032     -0.046577
# 2000-12-22  0.768570     -0.398832  1.031163  1.400032     -0.046577
# 2000-12-25  0.768539     -0.398856  1.031130  1.399997     -0.046603
# 2000-12-26  0.768520     -0.398870  1.031110  1.399975     -0.046619
# ...              ...           ...       ...       ...           ...
# 2019-02-27 -1.069522     -0.159000  0.448745  0.143181     -1.315148
# 2019-02-28 -1.068774     -0.158231  0.448903  0.143600     -1.314676
# 2019-03-01 -1.068033     -0.157469  0.449060  0.144016     -1.314207
# 2019-03-04 -1.067527     -0.156652  0.449246  0.144474     -1.313621
# 2019-03-05 -1.067025     -0.155842  0.449430  0.144927     -1.313039
#
#               B_Weak  B_Conservative  B_Neutral_INV  B_Aggressive   S_Value  \
# Dates
# 2000-12-20 -0.380944       -1.046655       1.388225      0.202530  0.412823
# 2000-12-21 -0.380944       -1.046655       1.388225      0.202530  0.412823
# 2000-12-22 -0.380944       -1.046655       1.388225      0.202530  0.412823
# 2000-12-25 -0.380968       -1.046675       1.388190      0.202502  0.412794
# 2000-12-26 -0.380983       -1.046687       1.388168      0.202485  0.412777
# ...              ...             ...            ...           ...       ...
# 2019-02-27 -0.636402       -0.887761      -0.243377     -0.581160  0.508384
# 2019-02-28 -0.635661       -0.887531      -0.242751     -0.580637  0.510198
# 2019-03-01 -0.634927       -0.887302      -0.242130     -0.580118  0.511996
# 2019-03-04 -0.634413       -0.887307      -0.241448     -0.579521  0.513805
# 2019-03-05 -0.633902       -0.887311      -0.240772     -0.578929  0.515598
#
#             S_Neutral_PE  S_Growth  S_Robust  S_Neutral_OP    S_Weak  \
# Dates
# 2000-12-20     -2.160876  0.963404  0.287319      0.334560 -1.796433
# 2000-12-21     -2.160876  0.963404  0.287319      0.334560 -1.796433
# 2000-12-22     -2.160876  0.963404  0.287319      0.334560 -1.796433
# 2000-12-25     -2.160889  0.963371  0.287290      0.334757 -1.796448
# 2000-12-26     -2.160897  0.963351  0.287273      0.334875 -1.796457
# ...                  ...       ...       ...           ...       ...
# 2019-02-27      0.064759 -0.671813  0.293570      2.396380 -0.387844
# 2019-02-28      0.062881 -0.672476  0.292775      2.396644 -0.389196
# 2019-03-01      0.061020 -0.673132  0.291987      2.396903 -0.390536
# 2019-03-04      0.059225 -0.673695  0.291245      2.397093 -0.391790
# 2019-03-05      0.057446 -0.674251  0.290509      2.397278 -0.393033
#
#             S_Conservative  S_Neutral_INV  S_Aggressive
# Dates
# 2000-12-20       -0.221710       0.134608     -0.871205
# 2000-12-21       -0.221710       0.134608     -0.871205
# 2000-12-22       -0.221710       0.134608     -0.871205
# 2000-12-25       -0.221735       0.134831     -0.871226
# 2000-12-26       -0.221750       0.134965     -0.871239
# ...                    ...            ...           ...
# 2019-02-27       -0.765149       0.754837      2.107319
# 2019-02-28       -0.765775       0.752663      2.108043
# 2019-03-01       -0.766394       0.750507      2.108759
# 2019-03-04       -0.766915       0.748386      2.109415
# 2019-03-05       -0.767431       0.746283      2.110063
#
# [4750 rows x 18 columns]

# %% [markdown]
# Step-1: Use 18 (3*6) doubt-sorted portfolios as test assets and run CS regression to obtain R_zt and four pure factor returns;

# %%
all_lambdas = []
all_intercepts = []

lambdas = []
intercepts = []
Dates = []
index_times = list(df_18_PR.T.columns)

for k in tqdm(df_18_PR.T.columns):

    df_index = ((((df_18_std_Size.T.loc[:, k].replace(-np.inf, np.nan).dropna().index).
                 intersection(df_18_std_PE.T.loc[:, k].replace(-np.inf, np.nan).dropna().index)).
                 intersection(df_18_PR.T.loc[:, index_times[index_times.index(k)]].dropna().index)).
                intersection(df_18_std_OP.T.loc[:, k].dropna().index)).\
        intersection(df_18_std_INV.T.loc[:, k].dropna().index)

    if len(df_index) > 10:

        l = list(ols_model.fit((pd.concat([df_18_std_Size.T.loc[df_index, k],
                                           df_18_std_PE.T.loc[df_index, k],
                                           df_18_std_OP.T.loc[df_index, k],
                                           df_18_std_INV.T.loc[df_index, k]], axis=1).values),
                               (df_18_PR.T.loc[df_index, index_times[index_times.index(k)]].values)).coef_)

        h = ols_model.fit((pd.concat([df_18_std_Size.T.loc[df_index, k],
                                      df_18_std_PE.T.loc[df_index, k],
                                      df_18_std_OP.T.loc[df_index, k],
                                      df_18_std_INV.T.loc[df_index, k]], axis=1).values),
                          (df_18_PR.T.loc[df_index, index_times[index_times.index(k)]].values)).intercept_

        lambdas.append(l)
        intercepts.append(h)
        Dates.append(k)

all_lambdas.append(pd.DataFrame(lambdas))
all_intercepts.append(pd.DataFrame(intercepts))
# Out:
# 100%|██████████| 4750/4750 [00:24<00:00, 192.04it/s]

# %%
## Through performing FM-2 at each time t, we got the pure factor return time-series for MC/PE/OP/INV and intercept (Rzt)
df_CS_FF4 = pd.concat([all_lambdas[0], pd.DataFrame(Dates)], axis = 1)
df_CS_FF4.columns = ['Size','PE','OP','INV','Dates']
df_CS_FF4 = df_CS_FF4.set_index(['Dates'])
df_CS_FF4
# Out:
#                 Size        PE        OP       INV
# Dates
# 2000-12-20 -0.002219  0.005138  0.000221 -0.003126
# 2000-12-21  0.001642 -0.004612 -0.001245 -0.000050
# 2000-12-22 -0.004914  0.001391  0.000704  0.002304
# 2000-12-25  0.000000  0.000000  0.000000  0.000000
# 2000-12-26  0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...
# 2019-02-27  0.000652 -0.000818 -0.000087 -0.000338
# 2019-02-28  0.001025  0.003372 -0.001396  0.002380
# 2019-03-01 -0.001015  0.000596 -0.000910 -0.001947
# 2019-03-04 -0.000076  0.000035  0.000647  0.000813
# 2019-03-05 -0.001038  0.001626  0.000551  0.001174
#
# [4750 rows x 4 columns]

# %%
df_Rzt = pd.concat([all_intercepts[0], pd.DataFrame(Dates)], axis = 1)
df_Rzt.columns = ['Rzt','Dates']
df_Rzt = df_Rzt.set_index(['Dates'])
df_Rzt
# Out:
#                  Rzt
# Dates
# 2000-12-20 -0.003722
# 2000-12-21 -0.006133
# 2000-12-22  0.004139
# 2000-12-25  0.000000
# 2000-12-26  0.000000
# ...              ...
# 2019-02-27  0.000033
# 2019-02-28 -0.001739
# 2019-03-01 -0.000356
# 2019-03-04 -0.005783
# 2019-03-05 -0.005794
#
# [4750 rows x 1 columns]

# %%
df_18_PR.T.mean()
# Out:
# Dates
# 2000-12-20   -0.003722
# 2000-12-21   -0.006133
# 2000-12-22    0.004139
# 2000-12-25    0.000000
# 2000-12-26    0.000000
#                 ...
# 2019-02-27    0.000033
# 2019-02-28   -0.001739
# 2019-03-01   -0.000356
# 2019-03-04   -0.005783
# 2019-03-05   -0.005794
# Length: 4750, dtype: float64

# %%
df_18_CS = pd.concat([df_Rzt, df_CS_FF4], axis = 1)
df_18_CS
# Out:
#                  Rzt      Size        PE        OP       INV
# Dates
# 2000-12-20 -0.003722 -0.002219  0.005138  0.000221 -0.003126
# 2000-12-21 -0.006133  0.001642 -0.004612 -0.001245 -0.000050
# 2000-12-22  0.004139 -0.004914  0.001391  0.000704  0.002304
# 2000-12-25  0.000000  0.000000  0.000000  0.000000  0.000000
# 2000-12-26  0.000000  0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...       ...
# 2019-02-27  0.000033  0.000652 -0.000818 -0.000087 -0.000338
# 2019-02-28 -0.001739  0.001025  0.003372 -0.001396  0.002380
# 2019-03-01 -0.000356 -0.001015  0.000596 -0.000910 -0.001947
# 2019-03-04 -0.005783 -0.000076  0.000035  0.000647  0.000813
# 2019-03-05 -0.005794 -0.001038  0.001626  0.000551  0.001174
#
# [4750 rows x 5 columns]

# %%
m_df_18_CS = df_18_CS
m_df_18_CS['month'] = np.array(df_18_CS.index.astype(str).str[:7])
m_df_18_CS = m_df_18_CS.groupby('month').sum()
df_18_CS = df_18_CS.drop(['month'], axis = 1)
m_df_18_CS
# Out:
#               Rzt      Size        PE        OP       INV
# month
# 2000-12  0.001094 -0.001173  0.006252 -0.000043 -0.005313
# 2001-01  0.016628 -0.000512 -0.002723  0.017843 -0.004205
# 2001-02 -0.040833 -0.005694 -0.006495  0.001204  0.007325
# 2001-03 -0.069833 -0.019823 -0.006094  0.004065  0.009242
# 2001-04  0.014544 -0.003783  0.001582  0.006713  0.001222
# ...           ...       ...       ...       ...       ...
# 2018-11 -0.013700  0.003682  0.002859 -0.002692 -0.000510
# 2018-12  0.000017  0.003689  0.002830  0.002037 -0.003744
# 2019-01 -0.006283  0.002958  0.000984 -0.004186  0.007980
# 2019-02 -0.013833  0.004127  0.010856 -0.001590  0.008939
# 2019-03 -0.011933 -0.002129  0.002257  0.000288  0.000040
#
# [220 rows x 5 columns]

# %%
m_df_18_CS.mean()*100
# Out:
# Rzt    -0.026467
# Size   -0.006001
# PE     -0.042715
# OP      0.072005
# INV    -0.055079
# dtype: float64

# %%
m_df_18_CS.std()
# Out:
# Rzt     0.029195
# Size    0.005752
# PE      0.005315
# OP      0.005658
# INV     0.005674
# dtype: float64

# %%
m_df_18_CS.apply(lambda x: stats.ttest_1samp(x,0))
# Out:
#         Rzt      Size        PE        OP       INV
# 0 -0.134466 -0.154748 -1.192146  1.887633 -1.439917
# 1  0.893157  0.877163  0.234494  0.060398  0.151319

# %%
df_18_CS.apply(lambda x: stats.ttest_1samp(x,0))
# Out:
#         Rzt      Size        PE        OP       INV
# 0 -0.193128 -0.130871 -0.940907  1.559667 -1.147775
# 1  0.846867  0.895883  0.346800  0.118905  0.251119

# %% [markdown]
# Step-2: (Mis-Pricing error at each time t)-> alpha,it = R,it - (Rz,t + firm characteristics,i*lambda,t), t=1,2,3,...,T,

# %%
df_ln_Size = df_ln_Size_trnct
df_std_PE = df_PE_trnct
df_std_OP = df_OP_trnct
df_std_INV = df_INV_trnct

# %%
len(df_ln_Size)==len(df_std_PE)==len(df_std_OP)==len(df_std_INV)
# Out:
# True

# %%
# Constant Version of CS factor model I
# (average beta) * lambda + Rz
# Prediction = df_ln_Size.apply(lambda x: np.mean(x) * df_CS_FF4.iloc[:,0])+\
# df_std_PE.apply(lambda x: np.mean(x) * df_CS_FF4.iloc[:,1])+\
# df_std_OP.apply(lambda x: np.mean(x) * df_CS_FF4.iloc[:,2])+\
# df_std_INV.apply(lambda x: np.mean(x) * df_CS_FF4.iloc[:,3])

# %%
# Time-varying Version of CS factor model I
# beta * lambda + Rz
Prediction = df_ln_Size.apply(lambda x: x * df_CS_FF4.iloc[:,0])+\
df_std_PE.apply(lambda x: x * df_CS_FF4.iloc[:,1])+\
df_std_OP.apply(lambda x: x * df_CS_FF4.iloc[:,2])+\
df_std_INV.apply(lambda x: x * df_CS_FF4.iloc[:,3])

# %%
intc_index = df_SR.index.intersection(Prediction.index)
intc_columns = df_SR.columns.intersection(Prediction.columns)

# %%
Prediction.loc[intc_index,intc_columns]
# Out:
#             ABC.SJ.Equity  ABI.SJ.Equity  ABK.SJ.Equity  ABR.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN            NaN            NaN
# 2000-12-21            NaN            NaN            NaN            NaN
# 2000-12-22            NaN            NaN            NaN            NaN
# 2000-12-25            NaN            NaN            NaN            NaN
# 2000-12-26            NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 2019-02-27            NaN       0.005886       0.002428            NaN
# 2019-02-28            NaN       0.011282       0.001122            NaN
# 2019-03-01            NaN      -0.009255      -0.003230            NaN
# 2019-03-04            NaN      -0.000810      -0.000303            NaN
# 2019-03-05            NaN      -0.009298      -0.004071            NaN
#
#             ABU.SJ.Equity  ACE.SJ.Equity  ACL.SJ.Equity  ACP.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN      -0.021909            NaN
# 2000-12-21            NaN            NaN       0.016398            NaN
# 2000-12-22            NaN            NaN      -0.039936            NaN
# 2000-12-25            NaN            NaN       0.000000            NaN
# 2000-12-26            NaN            NaN       0.000000            NaN
# ...                   ...            ...            ...            ...
# 2019-02-27       0.003191       0.003358       0.006450       0.006047
# 2019-02-28       0.006734       0.005714       0.002603       0.012185
# 2019-03-01      -0.003907      -0.000643      -0.006837      -0.011177
# 2019-03-04      -0.000978      -0.002586      -0.001470      -0.000310
# 2019-03-05      -0.005352      -0.006922      -0.011190      -0.009348
#
#             ACR.SJ.Equity  ACS.SJ.Equity  ...  WTC.SJ.Equity  WTL.SJ.Equity  \
# Dates                                     ...
# 2000-12-20            NaN            NaN  ...            NaN            NaN
# 2000-12-21            NaN            NaN  ...            NaN            NaN
# 2000-12-22            NaN            NaN  ...            NaN            NaN
# 2000-12-25            NaN            NaN  ...            NaN            NaN
# 2000-12-26            NaN            NaN  ...            NaN            NaN
# ...                   ...            ...  ...            ...            ...
# 2019-02-27            NaN       0.006470  ...            NaN       0.003154
# 2019-02-28            NaN       0.007034  ...            NaN       0.003272
# 2019-03-01            NaN      -0.010343  ...            NaN      -0.003470
# 2019-03-04            NaN      -0.000123  ...            NaN      -0.000866
# 2019-03-05            NaN      -0.009269  ...            NaN      -0.005473
#
#             YRK.SJ.Equity  ZED.SJ.Equity  ZGOVI.SJ.Equity  ZPT.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN              NaN            NaN
# 2000-12-21            NaN            NaN              NaN            NaN
# 2000-12-22            NaN            NaN              NaN            NaN
# 2000-12-25            NaN            NaN              NaN            NaN
# 2000-12-26            NaN            NaN              NaN            NaN
# ...                   ...            ...              ...            ...
# 2019-02-27       0.004823       0.006405              NaN       0.001652
# 2019-02-28       0.005834       0.001876              NaN       0.001008
# 2019-03-01      -0.004823      -0.005254              NaN      -0.001640
# 2019-03-04      -0.001676      -0.002427              NaN      -0.000486
# 2019-03-05      -0.008622      -0.012752              NaN      -0.002952
#
#             ZRNHDG.SJ.Equity  ZRNPLY.SJ.Equity  ZRR.SJ.Equity  ZSA.SJ.Equity
# Dates
# 2000-12-20               NaN               NaN      -0.006119            NaN
# 2000-12-21               NaN               NaN       0.000193            NaN
# 2000-12-22               NaN               NaN      -0.018782            NaN
# 2000-12-25               NaN               NaN       0.000000            NaN
# 2000-12-26               NaN               NaN       0.000000            NaN
# ...                      ...               ...            ...            ...
# 2019-02-27               NaN               NaN       0.000951            NaN
# 2019-02-28               NaN               NaN      -0.002639            NaN
# 2019-03-01               NaN               NaN      -0.000493            NaN
# 2019-03-04               NaN               NaN      -0.000146            NaN
# 2019-03-05               NaN               NaN      -0.001767            NaN
#
# [4750 rows x 740 columns]

# %%
df_SR_tmp.loc[intc_index,intc_columns]
# Out:
#             ABC.SJ.Equity  ABI.SJ.Equity  ABK.SJ.Equity  ABR.SJ.Equity  \
# Dates
# 2000-12-20      -0.117783       0.000000            NaN            0.0
# 2000-12-21       0.000000      -0.007168            NaN            0.0
# 2000-12-22       0.000000       0.002395            NaN            0.0
# 2000-12-25       0.000000       0.000000            NaN            0.0
# 2000-12-26       0.000000       0.000000            NaN            0.0
# ...                   ...            ...            ...            ...
# 2019-02-27            NaN            NaN            NaN            NaN
# 2019-02-28            NaN            NaN            NaN            NaN
# 2019-03-01            NaN            NaN            NaN            NaN
# 2019-03-04            NaN            NaN            NaN            NaN
# 2019-03-05            NaN            NaN            NaN            NaN
#
#             ABU.SJ.Equity  ACE.SJ.Equity  ACL.SJ.Equity  ACP.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN      -0.081238            NaN
# 2000-12-21            NaN            NaN       0.045124            NaN
# 2000-12-22            NaN            NaN       0.029003            NaN
# 2000-12-25            NaN            NaN       0.000000            NaN
# 2000-12-26            NaN            NaN       0.000000            NaN
# ...                   ...            ...            ...            ...
# 2019-02-27            NaN            0.0       0.002954            NaN
# 2019-02-28            NaN            0.0       0.000000            NaN
# 2019-03-01            NaN            0.0       0.054533            NaN
# 2019-03-04            NaN            0.0       0.005571            NaN
# 2019-03-05            NaN            0.0       0.035474            NaN
#
#             ACR.SJ.Equity  ACS.SJ.Equity  ...  WTC.SJ.Equity  WTL.SJ.Equity  \
# Dates                                     ...
# 2000-12-20            0.0            NaN  ...            0.0            NaN
# 2000-12-21            0.0            NaN  ...            NaN            NaN
# 2000-12-22            0.0            NaN  ...            NaN            NaN
# 2000-12-25            0.0            NaN  ...            NaN            NaN
# 2000-12-26            0.0            NaN  ...            NaN            NaN
# ...                   ...            ...  ...            ...            ...
# 2019-02-27            NaN            0.0  ...            NaN            NaN
# 2019-02-28            NaN            0.0  ...            NaN            NaN
# 2019-03-01            NaN            0.0  ...            NaN            NaN
# 2019-03-04            NaN            0.0  ...            NaN            NaN
# 2019-03-05            NaN            0.0  ...            NaN            NaN
#
#             YRK.SJ.Equity  ZED.SJ.Equity  ZGOVI.SJ.Equity  ZPT.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN              NaN       0.000000
# 2000-12-21            NaN            NaN              NaN       0.057158
# 2000-12-22            NaN            NaN              NaN      -0.057158
# 2000-12-25            NaN            NaN              NaN       0.000000
# 2000-12-26            NaN            NaN              NaN       0.000000
# ...                   ...            ...              ...            ...
# 2019-02-27       0.083382       0.014252              NaN            NaN
# 2019-02-28       0.000000      -0.002361              NaN            NaN
# 2019-03-01       0.000000       0.014085              NaN            NaN
# 2019-03-04       0.000000      -0.009368              NaN            NaN
# 2019-03-05       0.000000       0.002350              NaN            NaN
#
#             ZRNHDG.SJ.Equity  ZRNPLY.SJ.Equity  ZRR.SJ.Equity  ZSA.SJ.Equity
# Dates
# 2000-12-20               NaN               NaN            0.0            0.0
# 2000-12-21               NaN               NaN            0.0            0.0
# 2000-12-22               NaN               NaN            0.0            0.0
# 2000-12-25               NaN               NaN            0.0            NaN
# 2000-12-26               NaN               NaN            0.0            NaN
# ...                      ...               ...            ...            ...
# 2019-02-27               NaN               NaN            NaN            NaN
# 2019-02-28               NaN               NaN            NaN            NaN
# 2019-03-01               NaN               NaN            NaN            NaN
# 2019-03-04               NaN               NaN            NaN            NaN
# 2019-03-05               NaN               NaN            NaN            NaN
#
# [4750 rows x 740 columns]

# %% [markdown]
# After obtaining the return prediction of each stock i at each time t, we now can calculate the mis-pricing errors of CS factor models by using real stock time subtract its corresponding prediction return

# %%
df_alphas = df_SR_tmp.loc[intc_index,intc_columns].apply(lambda x: x - df_Rzt.iloc[:,0]) - Prediction.loc[intc_index,intc_columns]
df_alphas
# Out:
#             ABC.SJ.Equity  ABI.SJ.Equity  ABK.SJ.Equity  ABR.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN            NaN            NaN
# 2000-12-21            NaN            NaN            NaN            NaN
# 2000-12-22            NaN            NaN            NaN            NaN
# 2000-12-25            NaN            NaN            NaN            NaN
# 2000-12-26            NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 2019-02-27            NaN            NaN            NaN            NaN
# 2019-02-28            NaN            NaN            NaN            NaN
# 2019-03-01            NaN            NaN            NaN            NaN
# 2019-03-04            NaN            NaN            NaN            NaN
# 2019-03-05            NaN            NaN            NaN            NaN
#
#             ABU.SJ.Equity  ACE.SJ.Equity  ACL.SJ.Equity  ACP.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN      -0.055607            NaN
# 2000-12-21            NaN            NaN       0.034859            NaN
# 2000-12-22            NaN            NaN       0.064800            NaN
# 2000-12-25            NaN            NaN       0.000000            NaN
# 2000-12-26            NaN            NaN       0.000000            NaN
# ...                   ...            ...            ...            ...
# 2019-02-27            NaN      -0.003391      -0.003529            NaN
# 2019-02-28            NaN      -0.003975      -0.000864            NaN
# 2019-03-01            NaN       0.000999       0.061725            NaN
# 2019-03-04            NaN       0.008369       0.012824            NaN
# 2019-03-05            NaN       0.012717       0.052459            NaN
#
#             ACR.SJ.Equity  ACS.SJ.Equity  ...  WTC.SJ.Equity  WTL.SJ.Equity  \
# Dates                                     ...
# 2000-12-20            NaN            NaN  ...            NaN            NaN
# 2000-12-21            NaN            NaN  ...            NaN            NaN
# 2000-12-22            NaN            NaN  ...            NaN            NaN
# 2000-12-25            NaN            NaN  ...            NaN            NaN
# 2000-12-26            NaN            NaN  ...            NaN            NaN
# ...                   ...            ...  ...            ...            ...
# 2019-02-27            NaN      -0.006504  ...            NaN            NaN
# 2019-02-28            NaN      -0.005295  ...            NaN            NaN
# 2019-03-01            NaN       0.010699  ...            NaN            NaN
# 2019-03-04            NaN       0.005906  ...            NaN            NaN
# 2019-03-05            NaN       0.015064  ...            NaN            NaN
#
#             YRK.SJ.Equity  ZED.SJ.Equity  ZGOVI.SJ.Equity  ZPT.SJ.Equity  \
# Dates
# 2000-12-20            NaN            NaN              NaN            NaN
# 2000-12-21            NaN            NaN              NaN            NaN
# 2000-12-22            NaN            NaN              NaN            NaN
# 2000-12-25            NaN            NaN              NaN            NaN
# 2000-12-26            NaN            NaN              NaN            NaN
# ...                   ...            ...              ...            ...
# 2019-02-27       0.078526       0.007814              NaN            NaN
# 2019-02-28      -0.004096      -0.002498              NaN            NaN
# 2019-03-01       0.005179       0.019694              NaN            NaN
# 2019-03-04       0.007459      -0.001158              NaN            NaN
# 2019-03-05       0.014416       0.020897              NaN            NaN
#
#             ZRNHDG.SJ.Equity  ZRNPLY.SJ.Equity  ZRR.SJ.Equity  ZSA.SJ.Equity
# Dates
# 2000-12-20               NaN               NaN       0.009841            NaN
# 2000-12-21               NaN               NaN       0.005940            NaN
# 2000-12-22               NaN               NaN       0.014643            NaN
# 2000-12-25               NaN               NaN       0.000000            NaN
# 2000-12-26               NaN               NaN       0.000000            NaN
# ...                      ...               ...            ...            ...
# 2019-02-27               NaN               NaN            NaN            NaN
# 2019-02-28               NaN               NaN            NaN            NaN
# 2019-03-01               NaN               NaN            NaN            NaN
# 2019-03-04               NaN               NaN            NaN            NaN
# 2019-03-05               NaN               NaN            NaN            NaN
#
# [4750 rows x 740 columns]

# %% [markdown]
# Step-3: Use t.test to Calculate the time-series mean of alpha,it and obtain their corresponding t-statistics

# %%
TSmean_alphas = df_alphas.apply(lambda x: np.mean(x))
TSmean_alphas.describe()
# Out:
# count    467.000000
# mean      -0.000150
# std        0.001718
# min       -0.019841
# 25%       -0.000365
# 50%        0.000192
# 75%        0.000531
# max        0.004141
# dtype: float64

# %%
tstats_alphas = df_alphas.apply(lambda x: np.NaN if np.all(x!=x) else stats.ttest_1samp(x,0.0,nan_policy='omit')[0])
tstats_alphas = pd.DataFrame(tstats_alphas)
tstats_alphas.T
# Out:
#    ABC.SJ.Equity  ABI.SJ.Equity  ABK.SJ.Equity  ABR.SJ.Equity  ABU.SJ.Equity  \
# 0            NaN       1.153396      -0.814727            NaN       1.807498
#
#    ACE.SJ.Equity  ACL.SJ.Equity  ACP.SJ.Equity  ACR.SJ.Equity  ACS.SJ.Equity  \
# 0       0.138438       0.184006       1.109656            NaN      -0.496741
#
#    ...  WTC.SJ.Equity  WTL.SJ.Equity  YRK.SJ.Equity  ZED.SJ.Equity  \
# 0  ...            NaN      -1.970668      -0.013423       0.647801
#
#    ZGOVI.SJ.Equity  ZPT.SJ.Equity  ZRNHDG.SJ.Equity  ZRNPLY.SJ.Equity  \
# 0              NaN      -0.725099               NaN               NaN
#
#    ZRR.SJ.Equity  ZSA.SJ.Equity
# 0       0.731955            NaN
#
# [1 rows x 740 columns]

# %%
# calculate the percentage of NAs in Alphas
np.sum(df_alphas.apply(lambda x: np.isnan(x).sum()==len(x), axis = 0))/df_alphas.shape[1]
# Out:
# 0.3689189189189189

# %% [markdown]
# Step-4: Alpha Test: Calcualte the mean of abs(alphas,i) and abs(t.statistic_alphas,i)

# %% [markdown]
# ### Results_2

# %%
### Calculate the absolute value of alphas and alphas_t, then calculate their mean respectively
print(np.mean(abs(TSmean_alphas))*21*100,np.nanmean(abs(tstats_alphas)))
# Out:
# 1.9439936727986142 0.971466752424989

# %%
### Calculate the squared alphas and then divided by the cross-sectional variance of LHS average returns  
cs_var = np.var(df_SR_tmp.apply(lambda x: np.mean(x), axis = 0))
print(np.mean(np.square(TSmean_alphas))/cs_var)
# Out:
# 0.4305254247520458

# %%
### Substract the squared standard error of each intercept to adjust for the noise in the Step-3
alphas_se = df_alphas.apply(lambda x: np.std(x)/np.sqrt(len(x)))
A_lamda = np.mean((pd.DataFrame(np.square(TSmean_alphas).values)-pd.DataFrame(np.square(alphas_se).values)), axis = 0)
print(A_lamda/cs_var)
# Out:
# 0    0.384559
# dtype: float64

# %%
## calculate the time-series regression R-squared for model i (i <- 0~[N-1])
# SST1 = np.square(df_Ex_SR.iloc[:,1] - df_Ex_SR.iloc[:,1].mean()).sum()
# SS_res1 = np.square(df_alphas.iloc[:,1]).mean()
# R_sqr1 = 1 - (SS_res1/SST1)
# R_sqr1

# %%
## loop the above procedure
SST = np.square(df_SR_tmp.apply(lambda x: x-np.mean(x))).sum()
SS_res = np.square(df_alphas).mean()
R_sqr = 1 - SS_res/SST

# %%
#### calculate the time-series R^2 for CS factor model I
SST_1 = np.square(df_SR_tmp.apply(lambda x: x-np.mean(x))).sum()
R_sqrt = 1-((np.square(df_alphas).mean())/SST_1)

# %%
R_sqrt.describe()
# Out:
# count    467.000000
# mean       0.998797
# std        0.007095
# min        0.848803
# 25%        0.999019
# 50%        0.999519
# 75%        0.999722
# max        0.999943
# dtype: float64

# %%
alpha_ses = df_alphas.apply(lambda x: np.NaN if np.all(x!=x) else np.std(x)/np.sqrt(len(x)))
alpha_sds =  df_alphas.apply(lambda x: np.NaN if np.all(x!=x) else np.std(x))

# %%
### the average of the regression R^2; the average of the standard errors of the intercepts; 
### the average of the standard deviations of the regression residuals.
print('AR^2: ' + str(np.nanmean(R_sqr.values)), 'As(a): ' + str(np.mean(alpha_ses)*np.sqrt(21)), \
      'As(e): ' + str(np.mean(alpha_sds)*np.sqrt(21)))
# Out:
# AR^2: 0.9987971866058228 As(a): 0.002240386541736659 As(e): 0.15440798657412474

# %%
## Calculate Cross-sectional R-squared, how much the total variance of expected stock returns can be explained by the model?
1-(np.var(df_alphas.mean())/np.var(df_Ex_SR_tmp.mean()))
# Out:
# 0.5763419070005416

# %% [markdown]
# ### Cross-section Factor Model II

# %%
## Step-1: Use firm characteristics as factor loadings in FM-2 regression and get the pure factor returns 
## Step-2: Use pure factor return from step-1 and run time-series regression get cross-sectional betas and alphas(mis-pricing errors), with NW Adjustment
## Step-3: Alpha Test: Calcualte the mean of abs(alphas,i) and abs(t.statistic_alphas,i)

# %%
## Through FM cross-sectional regression, we got the pure factor return of MC/PE/OP/INV
df_CS_FF4
# Out:
#                 Size        PE        OP       INV
# Dates
# 2000-12-20 -0.002219  0.005138  0.000221 -0.003126
# 2000-12-21  0.001642 -0.004612 -0.001245 -0.000050
# 2000-12-22 -0.004914  0.001391  0.000704  0.002304
# 2000-12-25  0.000000  0.000000  0.000000  0.000000
# 2000-12-26  0.000000  0.000000  0.000000  0.000000
# ...              ...       ...       ...       ...
# 2019-02-27  0.000652 -0.000818 -0.000087 -0.000338
# 2019-02-28  0.001025  0.003372 -0.001396  0.002380
# 2019-03-01 -0.001015  0.000596 -0.000910 -0.001947
# 2019-03-04 -0.000076  0.000035  0.000647  0.000813
# 2019-03-05 -0.001038  0.001626  0.000551  0.001174
#
# [4750 rows x 4 columns]

# %%
## Test FF5CS-Factor Asset Pricing Models by using TS Regression

# %%
df_MR
# Out:
#              MR_RF
# Dates
# 2000-01-05 -0.0108
# 2000-01-06  0.0012
# 2000-01-07  0.0248
# 2000-01-10  0.0323
# 2000-01-11  0.0024
# ...            ...
# 2019-12-25 -0.0002
# 2019-12-26 -0.0002
# 2019-12-27  0.0031
# 2019-12-30  0.0046
# 2019-12-31 -0.0109
#
# [5215 rows x 1 columns]

# %%
df_CS_FF5 = pd.concat([df_MR.loc[df_CS_FF4.index,:], df_CS_FF4], axis = 1)
df_CS_FF5 = df_CS_FF5.rename(columns={'Size':'MC'})
df_CS_FF5
# Out:
#              MR_RF        MC        PE        OP       INV
# Dates
# 2000-12-20 -0.0083 -0.002219  0.005138  0.000221 -0.003126
# 2000-12-21 -0.0062  0.001642 -0.004612 -0.001245 -0.000050
# 2000-12-22  0.0163 -0.004914  0.001391  0.000704  0.002304
# 2000-12-25 -0.0003  0.000000  0.000000  0.000000  0.000000
# 2000-12-26 -0.0003  0.000000  0.000000  0.000000  0.000000
# ...            ...       ...       ...       ...       ...
# 2019-02-27  0.0008  0.000652 -0.000818 -0.000087 -0.000338
# 2019-02-28 -0.0055  0.001025  0.003372 -0.001396  0.002380
# 2019-03-01  0.0034 -0.001015  0.000596 -0.000910 -0.001947
# 2019-03-04  0.0001 -0.000076  0.000035  0.000647  0.000813
# 2019-03-05 -0.0074 -0.001038  0.001626  0.000551  0.001174
#
# [4750 rows x 5 columns]

# %%
m_df_CS_FF5 = df_CS_FF5
m_df_CS_FF5['month'] = np.array(df_CS_FF5.index.astype(str).str[:7])
m_df_CS_FF5 = m_df_CS_FF5.groupby('month').sum()
df_CS_FF5 = df_CS_FF5.drop(['month'], axis = 1)
m_df_CS_FF5
# Out:
#           MR_RF        MC        PE        OP       INV
# month
# 2000-12  0.0107 -0.001173  0.006252 -0.000043 -0.005313
# 2001-01  0.0851 -0.000512 -0.002723  0.017843 -0.004205
# 2001-02 -0.0068 -0.005694 -0.006495  0.001204  0.007325
# 2001-03 -0.0935 -0.019823 -0.006094  0.004065  0.009242
# 2001-04  0.0921 -0.003783  0.001582  0.006713  0.001222
# ...         ...       ...       ...       ...       ...
# 2018-11 -0.0365  0.003682  0.002859 -0.002692 -0.000510
# 2018-12  0.0375  0.003689  0.002830  0.002037 -0.003744
# 2019-01  0.0234  0.002958  0.000984 -0.004186  0.007980
# 2019-02  0.0297  0.004127  0.010856 -0.001590  0.008939
# 2019-03 -0.0039 -0.002129  0.002257  0.000288  0.000040
#
# [220 rows x 5 columns]

# %%
m_df_CS_FF5.mean()*100
# Out:
# MR_RF    0.691045
# MC      -0.006001
# PE      -0.042715
# OP       0.072005
# INV     -0.055079
# dtype: float64

# %%
m_df_CS_FF5.std()
# Out:
# MR_RF    0.046434
# MC       0.005752
# PE       0.005315
# OP       0.005658
# INV      0.005674
# dtype: float64

# %%
m_df_CS_FF5.apply(lambda x: stats.ttest_1samp(x,0))
# Out:
#       MR_RF        MC        PE        OP       INV
# 0  2.207386 -0.154748 -1.192146  1.887633 -1.439917
# 1  0.028325  0.877163  0.234494  0.060398  0.151319

# %%
df_CS_FF5.apply(lambda x: stats.ttest_1samp(x, 0), axis=0)
# Out:
#       MR_RF        MC        PE        OP       INV
# 0  1.898812 -0.130871 -0.940907  1.559667 -1.147775
# 1  0.057650  0.895883  0.346800  0.118905  0.251119

# %%
df_CS_FF5.corr()
# Out:
#           MR_RF        MC        PE        OP       INV
# MR_RF  1.000000  0.187262 -0.024436 -0.000558  0.015575
# MC     0.187262  1.000000 -0.053297 -0.093954 -0.014494
# PE    -0.024436 -0.053297  1.000000  0.011965 -0.123917
# OP    -0.000558 -0.093954  0.011965  1.000000 -0.305760
# INV    0.015575 -0.014494 -0.123917 -0.305760  1.000000

# %%
# Plot the correlation among CS factors
plt.figure(figsize=(6, 4), dpi=150, tight_layout=True)
corrMatrix = df_CS_FF5.corr()
sn.heatmap(corrMatrix, annot=True, cmap="viridis")
plt.title('The Correlation Among CS Factors', fontsize=10)
plt.show()

# %%
# FF5CS-Factor Time Series Regression with Newey-West Adjustment
df_Ex_SR_trnct = df_Ex_SR_tmp.loc[df_CS_FF5.index,:]

all_betas = []
all_std_errs = []
all_Rs_CS = []
all_sd_res_CS = []

betas = []
labels = []
std_errs = []
Rs = []
sd_res = []

for j in tqdm(df_Ex_SR.columns):

    df_index = (df_Ex_SR_trnct.loc[:, j].dropna(
    ).index).intersection(df_CS_FF5.index)

    if len(df_index) > 10:
        lag = int(4*((len(df_Ex_SR_trnct.loc[df_index, j]))/100)**(1/9))
        ols = sm.OLS(df_Ex_SR_trnct.loc[df_index, j].astype(np.float64), sm.add_constant(
            df_CS_FF5.loc[df_index, :].astype(np.float64)))
        res = ols.fit()
        res = ols.fit(cov_type='HAC', cov_kwds={'maxlags': lag})
        b = list(res.params)
        se = list(res.bse)
        r = res.rsquared
        sr = res.resid.std()
        betas.append(b)
        std_errs.append(se)
        Rs.append(r)
        sd_res.append(sr)
        labels.append(j)

all_betas.append(pd.DataFrame(betas))
all_std_errs.append(pd.DataFrame(std_errs))
all_Rs_CS.append(pd.DataFrame(Rs))
all_sd_res_CS.append(pd.DataFrame(sd_res))
# Out:
# 100%|██████████| 740/740 [00:04<00:00, 181.45it/s]

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ZSA.SJ.Equity   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     3.194
# Date:                Mon, 02 May 2022   Prob (F-statistic):            0.00706
# Time:                        03:14:42   Log-Likelihood:                 7119.8
# No. Observations:                2330   AIC:                        -1.423e+04
# Df Residuals:                    2324   BIC:                        -1.419e+04
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.000      0.756      0.449      -0.000       0.001
# MR_RF          0.0023      0.016      0.141      0.888      -0.030       0.034
# MC             0.4594      0.148      3.096      0.002       0.169       0.750
# PE            -0.2250      0.147     -1.530      0.126      -0.513       0.063
# OP             0.1526      0.162      0.944      0.345      -0.164       0.469
# INV           -0.2272      0.170     -1.337      0.181      -0.560       0.106
# ==============================================================================
# Omnibus:                      403.554   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7124.507
# Skew:                           0.247   Prob(JB):                         0.00
# Kurtosis:                      11.552   Cond. No.                         857.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 5 lags and without small sample correction
# """

# %%
df_betas = pd.concat([all_betas[0], pd.DataFrame(labels)], axis = 1)
df_betas.columns = ['Intercepts','MKT','Size','PE','OP','INV','Stocks']
df_betas = df_betas.set_index('Stocks')
df_betas
# Out:
#                   Intercepts       MKT      Size         PE         OP  \
# Stocks
# ABC.SJ.Equity      -0.004325 -0.248432 -2.730005  10.159118  -2.269599
# ABI.SJ.Equity       0.000279  0.257368 -0.257265   0.107787  -0.032924
# ABK.SJ.Equity      -0.002682  0.358309 -1.164554   1.546209  -2.253111
# ABR.SJ.Equity      -0.005241 -0.274367  1.832379  -2.094345 -11.149353
# ABU.SJ.Equity      -0.000561  0.015447  0.098374  -1.003282   0.494684
# ...                      ...       ...       ...        ...        ...
# ZGOVI.SJ.Equity     0.000049  0.048153 -0.091700  -0.018617  -0.084377
# ZPT.SJ.Equity      -0.002852  0.057928  0.596077  -1.840239   1.077203
# ZRNHDG.SJ.Equity   -0.000359  0.035943 -0.134916  -0.047623   0.139875
# ZRR.SJ.Equity       0.000010  0.167268  1.685416  -1.800475   3.160082
# ZSA.SJ.Equity       0.000182  0.002301  0.459383  -0.224966   0.152596
#
#                        INV
# Stocks
# ABC.SJ.Equity     3.260497
# ABI.SJ.Equity    -0.005279
# ABK.SJ.Equity     5.235294
# ABR.SJ.Equity    -3.270059
# ABU.SJ.Equity    -0.768725
# ...                    ...
# ZGOVI.SJ.Equity  -0.100206
# ZPT.SJ.Equity    -0.058892
# ZRNHDG.SJ.Equity  0.187090
# ZRR.SJ.Equity    -0.693760
# ZSA.SJ.Equity    -0.227208
#
# [708 rows x 6 columns]

# %%
## The alphas are missing pricing errors of asset pricing model (FF5-Factor), which are also the intercepts of time series regression
alphas = df_betas.iloc[:,0]
alphas.describe()
# Out:
# count    708.000000
# mean      -0.000730
# std        0.002423
# min       -0.019595
# 25%       -0.000807
# 50%       -0.000082
# 75%        0.000254
# max        0.006763
# Name: Intercepts, dtype: float64

# %%
df_SE = pd.concat([all_std_errs[0], pd.DataFrame(labels)], axis = 1)
df_SE.columns = ['Intercepts','MKT','Size','PE','OP','INV','Stocks']
df_SE = df_SE.set_index('Stocks')
df_SE
# Out:
#                   Intercepts       MKT      Size        PE        OP       INV
# Stocks
# ABC.SJ.Equity       0.002707  0.337316  2.272346  2.443091  2.353905  2.168639
# ABI.SJ.Equity       0.000314  0.036232  0.245011  0.249669  0.250772  0.248737
# ABK.SJ.Equity       0.001615  0.144007  1.681711  1.700741  1.917492  2.282287
# ABR.SJ.Equity       0.003541  0.402458  4.029085  3.114477  3.913463  3.427452
# ABU.SJ.Equity       0.000615  0.044076  0.437086  0.608929  0.581706  0.508304
# ...                      ...       ...       ...       ...       ...       ...
# ZGOVI.SJ.Equity     0.000106  0.011292  0.082367  0.080439  0.079980  0.072178
# ZPT.SJ.Equity       0.001317  0.162495  1.399618  1.422461  1.512068  1.315880
# ZRNHDG.SJ.Equity    0.000341  0.020035  0.193914  0.242580  0.275241  0.265581
# ZRR.SJ.Equity       0.001335  0.131170  1.043363  1.137473  1.049327  0.970897
# ZSA.SJ.Equity       0.000241  0.016368  0.148363  0.147064  0.161646  0.169931
#
# [708 rows x 6 columns]

# %%
alphas_se = df_SE.iloc[:,0]
alphas_se.describe()
# Out:
# count    708.000000
# mean       0.000781
# std        0.000836
# min        0.000008
# 25%        0.000287
# 50%        0.000514
# 75%        0.000963
# max        0.009188
# Name: Intercepts, dtype: float64

# %%
## Alpha Test (Fama & French, 2020)
### Step 1: Calculate t-statistics of alphas by using the formula: t-stats,i = alphas,i/s.e.(alphas,i)
alphas_t = alphas/alphas_se
alphas_t = alphas_t.replace(-np.inf,np.nan)
alphas_t.describe()
# Out:
# count    708.000000
# mean      -0.337431
# std        1.696897
# min       -9.297348
# 25%       -1.155181
# 50%       -0.259634
# 75%        0.649072
# max        7.757986
# Name: Intercepts, dtype: float64

# %%
pd.DataFrame(alphas_t)
# Out:
#                   Intercepts
# Stocks
# ABC.SJ.Equity      -1.597882
# ABI.SJ.Equity       0.887984
# ABK.SJ.Equity      -1.660541
# ABR.SJ.Equity      -1.480029
# ABU.SJ.Equity      -0.912694
# ...                      ...
# ZGOVI.SJ.Equity     0.461231
# ZPT.SJ.Equity      -2.166085
# ZRNHDG.SJ.Equity   -1.053322
# ZRR.SJ.Equity       0.007280
# ZSA.SJ.Equity       0.756429
#
# [708 rows x 1 columns]

# %% [markdown]
# #### Results_3

# %%
### Calculate the absolute value of alphas and alphas_t, then calculate their mean respectively
print(np.mean(abs(alphas))*21*100,np.nanmean(abs(alphas_t)))
# Out:
# 2.446357442083511 1.2328176016475354

# %%
### Calculate the cross-sectional variance of LHS average returns and then divided by the mean of squared alphas
cs_var = np.var(df_SR_tmp.apply(lambda x: np.mean(x), axis = 0))
print(np.mean(np.square(alphas))/cs_var)
# Out:
# 0.9278182908207693

# %%
### Substract the squared standard error of each intercept to adjust for the noise in the Step-3
A_lamda = np.mean((pd.DataFrame(np.square(alphas).values)-pd.DataFrame(np.square(alphas_se).values)), axis = 0)
print(A_lamda/cs_var)
# Out:
# 0    0.738165
# dtype: float64

# %%
### The average of the regression R^2; the average of the standard errors of the intercepts; 
### The average of the standard deviations of the regression residuals.
print('AR^2: ' + str(np.mean(all_Rs_CS)), 'As(a): ' + str(np.nanmean(alphas_se.values)*np.sqrt(21)), \
      'As(e): ' + str(np.mean(all_sd_res_CS)*np.sqrt(21)))
# Out:
# AR^2: 0.07052810174866636 As(a): 0.0035780121170143437 As(e): 0.12830883906608437

# %%
## Calculate Cross-sectional R-squared, how much the total variance of expected stock returns can be explained by the model?
1-(np.var(alphas)/np.var(df_Ex_SR_tmp.mean()))
# Out:
# 0.156721273543302
